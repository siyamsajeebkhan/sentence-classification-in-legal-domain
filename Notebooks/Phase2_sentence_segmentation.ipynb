# %%
import sys
sys.path.append(r"C:\Users\siyam\Desktop\Legal DS\project\venv\Lib\site-packages")
import os
from pathlib import Path
import json
import random
import numpy as np
import spacy


from tqdm import tqdm
import spacy
import json
import random
import re
import pandas as pd
import numpy as np
from copy import deepcopy
from sklearn import model_selection
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
from spacy.symbols import ORTH
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import tree
import matplotlib.pyplot as plt
from spacy.language import Language
from luima_sbd import sbd_utils as luima

# %% [markdown]
# ## Load Data

# %%
CURATED_ANN_PATH = "../Data/ldsi_w2021-20220221T223611Z-001/ldsi_w2021/ldsi_w21_curated_annotations_v2.json"

# %%
with open(CURATED_ANN_PATH, 'r') as j:
     data = json.loads(j.read())

# %%
data.keys()
# Out:
# dict_keys(['documents', 'annotations', 'types'])

# %%
annotations = data['annotations']
documents_by_id = {d['_id']: d for d in data['documents']}
types_by_id = {t['_id']: t for t in data['types']}
type_ids_by_name = {t['name']: t['_id'] for t in data['types']}
type_names_by_id = {t['_id']: t['name'] for t in data['types']}
doc_id_by_name = {d['name']: d['_id'] for d in data['documents']}
doc_name_by_id = {d['_id']: d['name'] for d in data['documents']}

# %% [markdown]
# ### Common functions

# %%
# get all sentences assuming every annotation is a sentence
def make_span_data(documents_by_id, types_by_id, annotations):
    span_data = []
    for a in annotations:
        start = a['start']
        end = a['end']
        document_txt = documents_by_id[a['document']]['plainText']
        atype = a['type']
        sd = {'txt': document_txt[start:end],
              'document': a['document'],
              'type': types_by_id[atype]['name'],
              'start': a['start'],
              'start_normalized': a['start'] / len(document_txt),
              'end': a['end']}
        span_data.append(sd)
    return span_data

# %%
def prepare_ann_span_by_doc(spans, doc_id):
    start = []
    end = []
    for span in spans:
        if span['document'] == doc_id:
            start.append(span['start'])
            end.append(span['end'])
    return start, end

# %%
def generate_ann_span_by_doc_with_spacy(train_doc_ids, nlp):
    gen_ann_span_by_doc = {}
    for train_id in tqdm(train_doc_ids, disable=True):
        text = documents_by_id[train_id]['plainText']
        doc = nlp(text)
        sentences = list(doc.sents)
        sentence_starts = [sent.start_char for sent in sentences]
        sentence_ends = [sent.end_char for sent in sentences]
        gen_ann_span_by_doc[train_id] = {'start': sentence_starts, 'end': sentence_ends}
    return gen_ann_span_by_doc

# %%
def generate_ann_span_by_doc_with_luima(train_doc_ids):
    gen_ann_span_by_doc = {}
    for train_id in tqdm(train_doc_ids, disable=True):
        text = documents_by_id[train_id]['plainText']
        doc = luima.text2sentences(text, offsets=False)
        indices = luima.text2sentences(text, offsets=True)
        
        sentence_starts = [ind[0] for ind in indices]
        sentence_ends = [ind[1] for ind in indices]
        gen_ann_span_by_doc[train_id] = {'start': sentence_starts, 'end': sentence_ends}
    return gen_ann_span_by_doc

# %%
def find_closest_start_point(train_doc_ids, true_ann_span_by_doc, gen_ann_span_by_doc):
    closest_by_id = {}
    for train_id in train_doc_ids:
        true_starts = []
        closest_neighbors = []
        for true_start in true_ann_span_by_doc[train_id]['start']:
            dist = 7000000
            for gen_start in gen_ann_span_by_doc[train_id]['start']:
                cal_dist = abs(true_start - gen_start)
                if cal_dist < dist:
                    dist = cal_dist
                    closest_neighbor = gen_start
            true_starts.append(true_start)
            closest_neighbors.append(closest_neighbor)
        closest_by_id[train_id] = {'true': true_starts, 'pred': closest_neighbors}
    return closest_by_id

# %%
def calculate_error_metrics(train_doc_ids, true_ann_span_by_doc, gen_ann_span_by_doc, closest_by_id):
    TP = 0
    FP = 0
    FN = 0
    
    tot_true_splits = 0
    tot_gen_splits = 0
    for train_id in train_doc_ids:
        true_split_len = len(true_ann_span_by_doc[train_id]['start'])
        gen_split_len = len(gen_ann_span_by_doc[train_id]['start'])
        
        tot_true_splits += true_split_len
        tot_gen_splits += gen_split_len
        
        tp_doc = (abs(np.array(closest_by_id[train_id]['true']) - np.array(closest_by_id[train_id]['pred'])) <= 3).sum()
        fn_doc = true_split_len - tp_doc
        fp_doc = gen_split_len - tp_doc
        
        TP += tp_doc
        FP += fp_doc
        FN += fn_doc
        
    precision = TP / (TP + FP)
    recall = TP / (TP + FN)
    f1_score = 2 * (precision * recall) / (precision + recall)
    
#     print(f"True split length: {tot_true_splits}")
#     print(f"Generated split length: {tot_gen_splits}")
#     print(f"TP: {TP}, FP: {FP}, FN: {FN}\n")
    return precision, recall, f1_score

# %% [markdown]
# ## Create Corpus

# %%
spans = make_span_data(documents_by_id, types_by_id, annotations)
span_labels = [s['type'] for s in spans]

# %%
train_doc_ids = np.load('../Data/train.npy')

# %%
train_doc_ids.shape
# Out:
# (113,)

# %%
true_ann_span_by_doc = {}
for train_id in train_doc_ids:
    ann_span_starts, ann_span_ends = prepare_ann_span_by_doc(spans, train_id)
    true_ann_span_by_doc[train_id] = {'start': ann_span_starts, 'end': ann_span_ends}

# %% [markdown]
# ### Phase 2.1: Using standard sentence segmenter

# %% [markdown]
# #### List spans of annotations of each document

# %%
# %time 
# nlp = spacy.load("en_core_web_sm")
# gen_ann_span_by_doc = generate_ann_span_by_doc_with_spacy(train_doc_ids, nlp)

# %%
# %time closest_by_id = find_closest_start_point(train_doc_ids, true_ann_span_by_doc, gen_ann_span_by_doc)

# %%
# precision, recall, f1_score = calculate_error_metrics(train_doc_ids, true_ann_span_by_doc, gen_ann_span_by_doc, closest_by_id)
# print(f'Precision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')

# %% [markdown]
# ### Phase 2.2: Extending spacy

# %%
single_word_headers = ["REPRESENTATION",
#                        "WITNESS",
#                        "ATTORNEY",
#                        "REASONS",
                       "____________________________________________",
                       "ORDER",
                       "INTRODUCTION",
#                        "CONCLUSION",
#                        "FINDINGS"
                      ]


other_headers = ["THE ISSUE",
                 "WITNESS AT HEARING ON APPEAL",
                 "ATTORNEY FOR THE BOARD",
                 "FINDINGS OF FACT",
                 "CONCLUSION OF LAW",
                 "REASONS AND BASES FOR FINDING AND CONCLUSION",
                ]

# %%
# EXTEND SPACY CELL
@Language.component("set_custom_boundaries_original")
def set_custom_boundaries_original(doc):
    for i, token in enumerate(doc):
        if token.text in ("’s", "'s"):
            doc[i].is_sent_start = False
        elif token.text in ("“", "‘") and i < len(doc) - 1:
            doc[i+1].is_sent_start = False
        elif token.text in ("”", "’"):
            doc[i].is_sent_start = False
        elif token.text in ("\n","\t","\r"," ","  ","   ","    ","DC.","Archive", "NO."):
            doc[i].is_sent_start = False
        elif token.text =="DOCKET":
            doc[i].is_sent_start = False
        elif token.text in ("THE","REPRESENTATION","WITNESS","ATTORNEY","REASONS","____________________________________________","ORDER","INTRODUCTION","CONCLUSION","FINDINGS", "FINDING"):
            doc[i].is_sent_start = True
    return doc

# %%
# EXTEND SPACY CELL
@Language.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    for i in range(len(doc)):
        if doc[i].text in ("’s", "'s"):
            doc[i].is_sent_start = False
#         elif doc[i].text in ("“", "‘") and i < len(doc) - 1:
#             doc[i+1].is_sent_start = False
            
#         elif doc[i].text in ("”", "’"):
#             doc[i].is_sent_start = False
            
#         elif doc[i].text in ("\n","\t","\r"," ","  ","   ","    ","DC.","Archive", "NO."):
#             doc[i].is_sent_start = False
        elif doc[i].text in ("\n", "\t", "\r", "DC.","Archive", "NO."):
            doc[i].is_sent_start = False    
            
        elif doc[i].text =="DOCKET" and doc[i+1:i+3].text =="NO.":
            doc[i].is_sent_start = False
            end = i+3
            while i+1<=end:
                doc[i+1].is_sent_start = False
                i += 1
            
        elif doc[i].text in single_word_headers:
#             print(doc[i].text)
            doc[i].is_sent_start = True
            i += 1
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True
            
        # Fixed    
        elif doc[i].text == "THE" and doc[i+1].text == "ISSUE":
            doc[i].is_sent_start = True
            i += 2
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True
        # Fixed
        elif doc[i].text == "WITNESS" and doc[i+1: i+5].text == "AT HEARING ON APPEAL":
            doc[i].is_sent_start = True
            end = i + 5
            while i+1<=end:
                doc[i+1].is_sent_start = False
                i += 1
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True
    
        # Fixed    
        elif doc[i].text == "ATTORNEY" and doc[i+1: i+4].text == "FOR THE BOARD":
            doc[i].is_sent_start = True
            end = i + 4
            while i+1 <= end:
                doc[i+1].is_sent_start = False
                i += 1
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True            
            
        # Fixed
        elif (doc[i].text == "FINDINGS" or doc[i].text == "FINDING") and doc[i+1: i+3].text == "OF FACT":
            doc[i].is_sent_start = True
            end = i + 3
            while i+1 <= end:
                doc[i+1].is_sent_start = False
                i += 1
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True      
            
        # Fixed    
        elif doc[i].text == "CONCLUSION" and doc[i+1: i+3].text == "OF LAW":
            doc[i].is_sent_start = True
            end = i + 3
            while i+1 <= end:
                doc[i+1].is_sent_start = False
                i += 1
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True  
            
#         elif doc[i].text == "Vet" and doc[i+1: i+3].text == "OF LAW":
#             doc[i].is_sent_start = True
#             end = i + 3
#             while i+1 <= end:
#                 doc[i+1].is_sent_start = False
#                 i += 1
#             while (doc[i].text.isspace()):
#                 i += 1
#             doc[i].is_sent_start = True  
            
        # Fixed    
        elif doc[i].text == "REASONS" and (doc[i+1: i+7].text == "AND BASES FOR FINDING AND CONCLUSION" or doc[i+1: i+7].text == "AND BASES FOR FINDINGS AND CONCLUSION"):
            doc[i].is_sent_start = True
            end = i + 7
            while i+1 <= end:
                doc[i+1].is_sent_start = False
                i += 1
            while (doc[i].text.isspace()):
                i += 1
            doc[i].is_sent_start = True      

        elif doc[i].text.lower() == "on" and doc[i+1:i+4].text == "appeal from the":
            doc[i].is_sent_start = True
            end = i + 4
            while i+1 <= end:
                doc[i+1].is_sent_start = False
                i += 1
            

    return doc

# %% [markdown]
# ### Test the splits for a single document

# %%
doc_id = '61aea55c97ad59b4cfc4129f'

# %% [markdown]
# ##### View the originally splitted sentences

# %%
# Original split
doc_id = doc_id
df = pd.DataFrame([true_ann_span_by_doc[doc_id]['start'], true_ann_span_by_doc[doc_id]['end']]).T
df.columns = ['start', 'end']
df = df.sort_values('start').reset_index(drop=True)
df_true = np.array(df)

test_doc = documents_by_id[doc_id]['plainText']
print(f"Total true splits: {df_true.shape[0]}")
print(f"True splits for the document: {doc_id}")
print("---------------------------------------------------------")
for i, true_span in enumerate(df_true):
    print(f"Sentence {i+1}: {test_doc[true_span[0]: true_span[1]]}\n\n")
# Out:
# Total true splits: 185
# True splits for the document: 61aea55c97ad59b4cfc4129f
# ---------------------------------------------------------
# Sentence 1: Citation Nr: 0610579
# Decision Date: 04/13/06    Archive Date: 04/26/06
#
# DOCKET NO.  04-19 577	)	DATE
# 	)
# 	)
#
#
# Sentence 2: On appeal from the
# Department of Veterans Affairs Regional Office in Manila, the
# Republic of the Philippines
#
#
# Sentence 3: THE ISSUE
#
#
# Sentence 4: Entitlement to a higher initial rating for service-connected
# lumbosacral strain with lumbar disc disease, currently
# evaluated as 10 percent disabling.
#
#
# Sentence 5: REPRESENTATION
#
#
# Sentence 6: Appellant represented by:	Veterans of Foreign Wars of
# the United States
#
#
# Sentence 7: WITNESS AT HEARING ON APPEAL
#
#
# Sentence 8: Veteran
#
#
# Sentence 9: ATTORNEY FOR THE BOARD
#
#
# Sentence 10: Tanya A. Smith, Counsel
#
#
# Sentence 11: INTRODUCTION
#
#
# Sentence 12: The veteran had active service from December 1998 to April
# 2003.
#
#
# Sentence 13: This matter comes before the Board of Veterans' Appeals
# (Board) on appeal from a July 2003 rating decision of the
# Department of Veterans Affairs (VA) Regional Office (RO) in
# Manila, the Republic of the Philippines.
#
#
# Sentence 14: FINDINGS OF FACT
#
#
# Sentence 15: 1.	The veteran has been notified of the evidence necessary to
# substantiate his
# claims, and all relevant evidence necessary for an equitable
# disposition of this appeal has been obtained.
#
#
# Sentence 16: 2.  Under the old schedule for rating spine disabilities, the
# evidence shows that the veteran's service-connected low back
# disability is productive of slight limitation of motion, but
# with pain and repetitive motion, and resolution of reasonable
# doubt in favor of the veteran, it is more moderately
# disabling.
#
#
# Sentence 17: 3.  Under the amended schedule for rating spine disabilities,
# the medical evidence shows that the veteran's low back
# disability is only productive of forward flexion to 85
# degrees or more and absent any separately ratable compensable
# neurologic deficits associated with disc disease; no
# physician prescribed the veteran bed rest and treatment for
# incapacitating episodes of intervertebral disc syndrome
# having a total duration of at least two weeks over the course
# of 12 months.
#
#
# Sentence 18: CONCLUSION OF LAW
#
#
# Sentence 19: The schedular criteria for a higher initial rating of 20
# percent for service-connected lumbosacral strain with lumbar
# disc disease have been approximated under the old schedule
# for rating spine disabilities.
#
#
# Sentence 20: 38 U.S.C.A. �� 1155, 5103,
# 5103A, 5107(b) (West 2002 & Supp. 2005); 38 C.F.R. �� 3.102,
# 3.159, 4.1-4.14, 4.27, 4.71a, Diagnostic Code 5292 (2003).
#
#
# Sentence 21: REASONS AND BASES FOR FINDINGS AND CONCLUSION
#
#
# Sentence 22: Veterans Claims Assistance Act of 2000
#
#
# Sentence 23: The Veterans Claims Assistance Act of 2000, Pub. L. No. 106-
# 475, 114 Stat. 2096 (2000) (VCAA) redefines the obligations
# of VA with respect to the duty to assist and includes an
# enhanced duty to notify a claimant as to the information and
# evidence necessary to substantiate a claim for VA benefits.
#
#
# Sentence 24: 38 U.S.C.A. �� 5103, 5103A (West 2002 & Supp. 2005); 38
# C.F.R. � 3.159 (2005).
#
#
# Sentence 25: VA is required to provide the
# claimant with notice of what information or evidence is to be
# provided by the Secretary and what information or evidence is
# to be provided by the claimant with respect to the
# information and evidence necessary to substantiate the claim
# for VA benefits.
#
#
# Sentence 26: Quartuccio v. Principi, 16 Vet. App. 183,
# 187 (2002).
#
#
# Sentence 27: The Board finds that VA's enhanced duty to notify under the
# VCAA has been met.
#
#
# Sentence 28: In this regard, the Board notes that in correspondence dated
# in June 2003, the RO advised the veteran of VA's duties under
# the VCAA and the delegation of responsibility between VA and
# the veteran in procuring the evidence relevant to the claim,
# including which portion of the information and evidence
# necessary to substantiate the claim was to be provided by the
# veteran and which portion VA would attempt to obtain on
# behalf of the veteran.
#
#
# Sentence 29: Quartuccio, 16 Vet. App. at 187.
#
#
# Sentence 30: The
# June 2003 VCAA notice advised the veteran of what the
# evidence must show to establish entitlement to service-
# connected compensation benefits.
#
#
# Sentence 31: During the course of this appeal, on March 3, 2006, the
# United States Court of Appeals for Veterans Claims (Court)
# issued a decision in the consolidated appeal of
# Dingess/Hartman v. Nicholson, Nos. 01-1917 and 02-1506, which
# held that the VCAA notice requirements of 38 U.S.C.A.
# � 5103(a) and 38 C.F.R. � 3.159(b) apply to all five elements
# of a service connection claim.
#
#
# Sentence 32: Those five elements include:
# 1) veteran status; 2) existence of a disability; (3) a
# connection between the veteran's service and the disability;
# 4) degree of disability; and 5) effective date of the
# disability.
#
#
# Sentence 33: In addition to the notice described above, the
# Court also held that upon receipt of an application for a
# service-connection claim, 38 U.S.C.A.               � 5103(a)
# and 38 C.F.R. � 3.159(b) require VA to provide the claimant
# with
# notice that a disability rating and an effective date for the
# award of benefits will be assigned if service connection is
# awarded and the claimant should be notified of the type of
# evidence necessary to establish a disability rating or
# effective date for the disability(ies) on appeal.
#
#
# Sentence 34: Dingess/Hartman, slip op. at 14.
#
#
# Sentence 35: In the instant appeal, the veteran was not provided with
# notice of the type of evidence necessary to establish a
# disability rating or effective date for his service-connected
# low back disability.
#
#
# Sentence 36: Despite the inadequate notice provided
# to the veteran on these latter two elements, the Board finds
# no prejudice to the veteran in proceeding with the issuance
# of a final decision.
#
#
# Sentence 37: See Bernard v. Brown, 4 Vet. App. 384,
# 394 (1993) (providing that where the Board addresses a
# question that has not been addressed by the agency of
# original jurisdiction, the Board must consider whether the
# veteran has been prejudiced thereby).
#
#
# Sentence 38: In this regard, the
# Board notes that in the veteran's Notice of Disagreement
# (NOD), he contended that he was entitled to a higher initial
# rating of 20 percent or more because of his "occasional
# severe lower back pain and limited range of motion," and he
# subsequently thereafter submitted additional medical evidence
# in support of his claim in October 2003.
#
#
# Sentence 39: Thus, it is clearly
# demonstrated that the veteran understood that lay evidence
# describing his symptoms and medical evidence showing a higher
# degree of severity in symptomatology associated with his low
# back disability were the types of evidence necessary to
# substantiate his claim.
#
#
# Sentence 40: The Board also notes that the RO
# afforded the veteran a new VA examination in January 2004 in
# response to the veteran's NOD and additional medical evidence
# and for purposes of generating the type of evidence needed to
# substantiate the veteran's claim.
#
#
# Sentence 41: Additionally, the April
# 2004 Statement of the Case (SOC) sets forth the rating
# criteria for all ratings in excess of 10 percent under the
# diagnostic codes assigned this disability.
#
#
# Sentence 42: As the Board
# concludes below that the veteran is entitled to a partial
# grant and that staged ratings are not appropriate, the
# effective date of the higher rating most likely will be the
# day following the veteran's discharge from service, which is
# the earliest date available under VA law and regulations.
#
#
# Sentence 43: For these reasons, the Board finds no prejudice to the
# veteran despite the inadequate notice provided him on these
# last two elements.
#
#
# Sentence 44: The Board acknowledges that the June 2003 VCAA notice
# contained no specific request for the veteran to provide any
# evidence in the veteran's possession that pertained to the
# claim or something to the effect that the veteran give VA
# everything he had that pertained to his claim.
#
#
# Sentence 45: 38 C.F.R.
# � 3.159(b)(1) (2005).
#
#
# Sentence 46: A complying notice, however, need not necessarily use the
# exact language of the regulation so long as that notice
# properly conveys to a claimant the essence of the regulation.
#
#
# Sentence 47: Mayfield v. Nicholson, 19 Vet. App. 103 (2005).
#
#
# Sentence 48: The RO asked
# the veteran for all the information and evidence necessary to
# substantiate his claim-that is, evidence of the type that
# should be considered by VA in assessing his claim.
#
#
# Sentence 49: Throughout the course of this appeal, the veteran has set
# forth his contentions and submitted pertinent medical
# evidence.
#
#
# Sentence 50: Therefore, it can be concluded, based on the
# particular facts and circumstances of the case, the omission
# of the request for "any evidence in the claimant's
# possession that pertains to the claim" in the notice did not
# harm the veteran, and it would be legally proper to render a
# decision in the case without further notice under the
# regulation.
#
#
# Sentence 51: Id.
#
#
# Sentence 52: In further regard to VA's duty to notify, the Board notes
# that the RO provided the veteran with a copy of the July 2003
# rating decision and April 2004 SOC, which included a
# discussion of the facts of the claim, notification of the
# basis of the decision, and a summary of the evidence used to
# reach the decision.
#
#
# Sentence 53: The SOC provided the veteran with notice
# of all the laws and regulations pertinent to his claim,
# including the law and implementing regulations of the VCAA.
#
#
# Sentence 54: The Board notes that the schedule for rating spine
# disabilities was amended in August 2003, effective September
# 26, 2003.
#
#
# Sentence 55: Amendment to Part 4, Schedule for Rating
# Disabilities, 68 Fed. Reg. 51454-51458 (August 27, 2003)
# (codified at 38 C.F.R. � 4.71a, Diagnostic Codes 5235, 5236,
# 5237, 5238, 5239, 5240, 5241, 5242, 5243 (2005)).
#
#
# Sentence 56: Prior to
# that, the rating criteria for evaluating intervertebral disc
# syndrome were changed, effective September 23, 2002.
#
#
# Sentence 57: Amendment to Part 4, Schedule for Rating Disabilities, 67
# Fed. Reg. 54345-54349 (August 22, 2002) (codified at 38
# C.F.R. � 4.71a, Diagnostic Code 5293 (2003)).
#
#
# Sentence 58: The new rating
# criteria for intervertebral disc syndrome were subsumed in
# the aforementioned amended rating schedule for spine
# disabilities.
#
#
# Sentence 59: When the regulations concerning entitlement to
# a higher rating are changed during the course of an appeal,
# the veteran is entitled to resolution of his or her claim
# under the criteria that are more to his or her advantage.
#
#
# Sentence 60: VAOPGCPREC 3-00.
#
#
# Sentence 61: The April 2004 SOC shows that the RO
# considered the veteran's low back disability under the
# applicable old and new diagnostic rating criteria.
#
#
# Sentence 62: In
# addition, the veteran was provided with notice of the
# applicable old and revised rating criteria.
#
#
# Sentence 63: The Board concludes that the requirements of the notice
# provisions of the VCAA have been met, and there is no
# outstanding duty to inform the veteran that any additional
# information or evidence is needed.
#
#
# Sentence 64: Quartuccio, 16 Vet. App.
# at 187.
#
#
# Sentence 65: In regard to VA's duty to assist, the Board notes that in
# addition to the January 2004 VA examination, the RO had also
# afforded the veteran an examination in July 2003.
#
#
# Sentence 66: Lastly,
# the RO scheduled the veteran for a videoconference hearing,
# which was held in January 2006.
#
#
# Sentence 67: The veteran has not made the
# RO or the Board aware of any other evidence relevant to his
# appeal that needs to be obtained.
#
#
# Sentence 68: Based on the foregoing,
# the Board finds that all relevant facts have been properly
# and sufficiently developed in this appeal and no further
# development is required to comply with the duty to assist the
# veteran in developing the facts pertinent to his claim.
#
#
# Sentence 69: Accordingly, the Board will proceed with appellate review.
#
#
# Sentence 70: Procedural History and Evidence
#
#
# Sentence 71: In a July 2003 rating decision, the RO awarded service
# connection for lumbosacral sprain with limitation of motion
# and assigned a 10 percent rating under Diagnostic Codes 5295-
# 5292, effective from April 4, 2003, the day following the
# veteran's discharge from service.
#
#
# Sentence 72: In the SOC, the RO
# recharacterized the issue as 'lumbosacral strain with lumbar
# disc disease' and continued the assigned disability rating.
#
#
# Sentence 73: The service medical records show that the veteran was
# followed for complaints of intermittent low back pain
# exacerbated with "work," lifting, and prolonged sitting,
# standing, and walking.
#
#
# Sentence 74: A March 2001 computerized tomography
# scan (CT) scan revealed spinal stenosis at L2 through L4,
# degenerative disc disease at L4-5 and L5-S1, and posterior
# facet degenerative joint disease affecting left L-4 and
# bilateral L-5 roots.
#
#
# Sentence 75: A March 2003 record noted an assessment
# of recurrent low back pain, possible bilateral mutated sacrum
# (posterior) versus left "ant" mutated "FRSR" lumbar at L5.
#
#
# Sentence 76: The July 2003 VA examination report shows that the examiner
# reviewed the claims file.
#
#
# Sentence 77: The examiner related that the
# veteran complained of pain, discomfort, and decreased range
# of motion.
#
#
# Sentence 78: The physical examination revealed tenderness of
# L4 and L5.
#
#
# Sentence 79: On range of motion of the lumbar spine, flexion
# was 0 to 85 degrees, extension was 0 to 30 degrees, lateral
# bending to the left was 0 to 35 degrees, and lateral bending
# to the right was 0 to 30 degrees.
#
#
# Sentence 80: The examiner noted that
# the veteran had a slight decrease in lateral bending to the
# right and that the veteran had good effort but pain and
# discomfort were noted of the lower back upon movement.
#
#
# Sentence 81: The
# examiner provided a diagnosis of lumbosacral sprain with mild
# decreased range of motion, pain, and discomfort.
#
#
# Sentence 82: The
# radiographic report noted an impression of narrowing of the
# L5-S1 intervertebral disk space.
#
#
# Sentence 83: VA treatment records dated in October 2003 showed an
# examination revealed mild tenderness over the lumbar spine
# and mild paraspinal spasm.
#
#
# Sentence 84: The examiner noted an assessment
# of chronic low back pain.
#
#
# Sentence 85: It was noted that the veteran was
# unemployed.
#
#
# Sentence 86: The examiner reported that he impressed on the
# veteran the importance of weight loss and how it might
# alleviate his back pain.
#
#
# Sentence 87: In an October 2003 letter, J.L., DC reported on clinical
# findings not centered on the veteran's service-connected low
# back disability.
#
#
# Sentence 88: The January 2004 VA examination report shows that the
# examiner reviewed the claims file.
#
#
# Sentence 89: The examiner noted that
# x-rays, a CT scan, and magnetic resonance imaging scans have
# revealed some disc degenerations at L4 and L5 with some
# protrusions, bulging, and some stenosis.
#
#
# Sentence 90: The veteran
# complained of problems associated with repetitive bending and
# lifting; he indicated that heavy bending, lifting, and work
# aggravated his back.
#
#
# Sentence 91: The veteran
# complained of problems associated with repetitive bending and
# lifting; he indicated that heavy bending, lifting, and work
# aggravated his back.
#
#
# Sentence 92: He complained of flare-ups once or
# twice a year during which time he had to spend time in bed
# for four or five days; other times he experienced only
# chronic backache.
#
#
# Sentence 93: He indicated that the pain went into his
# buttock area and legs or feet, but he denied that he
# experienced radicular pain.
#
#
# Sentence 94: During flare-ups, he used a back
# brace or cane to move around; otherwise, he could stand or
# walk all day long, but the problem was he could not do
# repetitive bending or lifting activities.
#
#
# Sentence 95: He maintained that
# he currently was not working because he could not perform
# heavy labor activities; he could perform normal daily
# activity and he had normal mobility.
#
#
# Sentence 96: The examiner observed that the veteran was not wearing a
# brace or using a cane at the exam.
#
#
# Sentence 97: The examiner indicated
# that there was no systemic symptoms or bladder or bowel
# dysfunction noted.
#
#
# Sentence 98: The examiner observed that the veteran
# could ambulate without aid or assistance and that he had a
# normal stance and gait.
#
#
# Sentence 99: The exam of the spine did not show
# any deformity; there was no increased kyphosis or scoliosis.
# He had some lumbosacral tenderness to palpation.
#
#
# Sentence 100: There were
# no muscle spasms.
#
#
# Sentence 101: He could forward flex 90 out of 90
# degrees, and extend and rotate 25 out of 30 degrees with pain
# at the extremes of motion.
#
#
# Sentence 102: There was no sciatica present.
#
#
# Sentence 103: He could rise up from his toes and heels.
#
#
# Sentence 104: Leg raise was
# negative in the seated position.
#
#
# Sentence 105: Reflexes were 1-2+ and
# equal at the knee and at the ankle.
#
#
# Sentence 106: He had normal strength
# and normal sensation in the lower extremities.
#
#
# Sentence 107: The examiner
# provided a diagnosis of lumbosacral strain with lumbar disc
# disease.
#
#
# Sentence 108: In the veteran's May 2004 Substantive Appeal, he additionally
# complained that he experienced occasional locking of the
# lower back.
#
#
# Sentence 109: At the January 2006 videoconference hearing, the veteran
# presented testimony on his symptoms that was similar to
# previously discussed complaints.
#
#
# Sentence 110: In addition, he denied ever
# having surgery or that a physician had recommended that
# surgery be performed.
#
#
# Sentence 111: He indicated that he was currently
# studying for purposes of finding employment.
#
#
# Sentence 112: He maintained
# that he experienced only one episode of pain that radiated
# down to his thigh.
#
#
# Sentence 113: He initially denied that he experienced
# numbness in his legs or tingling, but then added that he
# experienced shooting pain that radiated to his legs that he
# confirmed started as a result of his injury.
#
#
# Sentence 114: Analysis
#
#
#
# Sentence 115: As previously noted, the veteran's low back disability is
# currently assigned a 10 percent rating under Diagnostic Codes
# 5295-5292 of the old schedule for rating spine disabilities.
#
#
# Sentence 116: The medical evidence shows that a mild paraspinal spasm was
# objectively demonstrated on examination in October 2003, but
# not reproduced at the January 2004 VA examination nor noted
# to be present at the July 2003 VA examination.
#
#
# Sentence 117: The July 2003
# VA examination revealed normal (defined below) range of
# motion on lateral bending to the left and right.
#
#
# Sentence 118: The Board
# finds that the evidence fails to show that the veteran's low
# back disability is primarily productive of muscle spasm on
# extreme forward bending with unilateral loss of lateral spine
# motion, the criteria associated with the next higher rating
# of 20 percent under Diagnostic Code 5295 of the old schedule.
#
#
# Sentence 119: As for Diagnostic Code 5292, 38 C.F.R. � 4.71a, Diagnostic
# Codes 5290 through 5292 (2003) of the old schedule rated
# limitation of motion of the spine according to whether it was
# slight, moderate, or severe.
#
#
# Sentence 120: The words "slight,"
# "moderate," and "severe" are not defined in the VA
# Schedule for Rating Disabilities.
#
#
# Sentence 121: Guidance can be obtained
# from the amended regulations.
#
#
# Sentence 122: The current definition of
# normal range of motion for the spine is based on medical
# guidelines in existence since 1984; therefore, the Board will
# apply the current ranges of motion to rating spine
# disabilities under the old criteria.
#
#
# Sentence 123: Normal forward flexion
# of the thoracolumbar spine is zero to 90 degrees, extension
# is zero to 30 degrees, left and right lateral flexion are
# zero to 30 degrees, and left and right lateral rotation are
# zero to 30 degrees.
#
#
# Sentence 124: 38 C.F.R. � 4.71a, General Rating
# Formula for Diseases and Injuries of the Spine, Note (2)
# (2005).
#
#
# Sentence 125: Under Diagnostic Code 5292, a 20 percent rating is assigned
# for moderate limitation of motion of the lumbar spine, and a
# 40 percent rating is assigned for severe limitation of
# motion.
#
#
# Sentence 126: 38 C.F.R. � 4.71a, Diagnostic Code 5292 (2003).
#
#
# Sentence 127: A slight loss of motion on flexion, extension, and rotation
# was demonstrated at the July 2003 and January 2004 VA
# examinations.
#
#
# Sentence 128: Thus, the veteran's low back disability is not
# productive of moderate limitation of motion of the lumbar
# spine.
#
#
# Sentence 129: The Board, however, notes that the veteran primarily
# complains of pain and fatigue with repetitive motion
# resulting in decreased motion.
#
#
# Sentence 130: His current complaints are
# similar to complaints well documented in the service medical
# records.
#
#
# Sentence 131: In determining the degree of limitation of motion,
# the provisions of 38 C.F.R. �� 4.10, 4.40, and 4.45 are for
# consideration.
#
#
# Sentence 132: DeLuca v. Brown, 8 Vet. App. 202 (1995).
#
#
# Sentence 133: The
# factors involved in evaluating and rating disabilities of the
# joints include, weakness, fatigability, incoordination,
# restricted or excess movement of the joint, or pain on
# movement.
#
#
# Sentence 134: 38 C.F.R. � 4.45 (2005).
#
#
# Sentence 135: The Board resolves
# reasonable doubt in favor of the veteran that with pain and
# repetitive motion of his lower back, it is more moderately
# disabling, such that a 20 percent rating under Diagnostic
# Code 5292 of the old schedule is appropriate.
#
#
# Sentence 136: 38 C.F.R.
# �� 3.102, 4.7 (2005).
#
#
# Sentence 137: The veteran, however, is not entitled
# to the next higher rating of 40 percent as the medical
# evidence does not show severe limitation of motion or severe
# impairment associated with the back disability.
#
#
# Sentence 138: The Board is required to consider other diagnostic codes
# under the old schedule to determine whether the veteran is
# entitled to a rating in excess of 20 percent under any of
# them.
#
#
# Sentence 139: The Board is required to consider other diagnostic codes
# under the old schedule to determine whether the veteran is
# entitled to a rating in excess of 20 percent under any of
# them.
#
#
# Sentence 140: The Board is required to consider other diagnostic codes
# under the old schedule to determine whether the veteran is
# entitled to a rating in excess of 20 percent under any of
# them.
#
#
# Sentence 141: The medical evidence shows that there is no x-ray evidence of
# residuals of a fracture of the vertebra attributable to the
# service-connected low back disability.
#
#
# Sentence 142: The medical evidence
# also shows that the veteran does not have ankylosis of the
# lumbar spine.
#
#
# Sentence 143: Service connection is in effect for
# degenerative disc disease of the lumbar spine, but the
# medical evidence shows that the disc disease does not
# currently manifest any separately ratable compensable
# neurologic deficits.
#
#
# Sentence 144: Thus, the veteran is precluded from an
# evaluation under Diagnostic Codes 5285 and 5289 of the old
# schedule and Diagnostic Code 8520.
#
#
# Sentence 145: 38 C.F.R. � 4.71a,
# Diagnostic Codes 5285, 5289 (2003); 38 C.F.R. � 4.124a,
# Diagnostic Code 8520 (2005).
#
#
# Sentence 146: Accordingly, the Board concludes that the veteran is entitled
# to a higher initial rating of 20 percent, but not higher, for
# service-connected lumbosacral strain with lumbar disc disease
# under the old schedule for rating spine disabilities.
#
#
# Sentence 147: The Board now considers the veteran's service-connected low
# back disability under the schedule for rating spine
# disabilities as amended in August 2003, effective September
# 26, 2003.
#
#
# Sentence 148: Under the amended schedule, any associated
# objective neurologic abnormalities, including, but not
# limited to bowel or bladder impairment are to be evaluated
# separately under an appropriate diagnostic code.
#
#
# Sentence 149: 38 C.F.R.
# � 4.71a, General Rating Formula, Note 1 (2005).
#
#
# Sentence 150: Intervertebral disc syndrome is to be evaluated either under
# the General Rating Formula for Diseases and Injuries of the
# Spine or under the Formula for Rating Intervertebral Disc
# Syndrome Based on Incapacitating Episodes, whichever method
# results in the higher evaluation when all disabilities are
# combined under � 4.25.
#
#
# Sentence 151: Under the General Rating Formula for Diseases and Injuries of
# the Spine, with or without symptoms such as pain (whether or
# not it radiates), stiffness, or aching in the area of the
# spine affected by residuals of injury or disease, a 10
# percent rating is assigned for forward flexion of the
# thoracolumbar spine greater than 60 degrees but not greater
# than 85 degrees; or, combined range of motion of the
# thoracolumbar spine greater than 120 degrees but not greater
# than 235 degrees; or, muscle spasm, guarding, or localized
# tenderness not resulting in abnormal gait or abnormal spinal
# contour; or, vertebral body fracture with loss of 50 percent
# or more of the height.
#
#
# Sentence 152: 38 C.F.R. � 4.71a (2005).
#
#
# Sentence 153: A 20
# percent rating is assigned for forward flexion of the
# thoracolumbar spine greater than 30 degrees but not greater
# than 60 degrees; or, the combined range of motion of the
# thoracolumbar spine not greater than 120 degrees; or, muscle
# spasm or guarding severe enough to result in an abnormal gait
# or abnormal spinal contour such as scoliosis, reversed
# lordosis, or abnormal kyphosis.
#
#
# Sentence 154: Id.
#
#
# Sentence 155: A 40 percent rating is
# assigned for forward flexion of the thoracolumbar spine 30
# degrees or less; or, favorable ankylosis of the entire
# thoracolumbar spine.
#
#
# Sentence 156: Id.
#
#
# Sentence 157: A 50 percent rating is assigned
# for unfavorable ankylosis of the entire thoracolumbar spine.
#
#
# Sentence 158: Id.
#
#
# Sentence 159: A 100 percent rating is assigned for unfavorable
# ankylosis of the entire spine.
#
#
# Sentence 160: Id.
#
#
# Sentence 161: The medical evidence shows that the veteran's low back
# disability is only productive of the criteria associated with
# a 10 percent rating for forward flexion to 85 degrees or
# more.
#
#
# Sentence 162: Therefore, the veteran is only entitled to a 10
# percent rating under the amended schedule for rating spine
# disabilities with respect to the orthopedic manifestations of
# the low back disability.
#
#
# Sentence 163: As for neurologic manifestations associated with the low back
# disability, the Board previously noted that the medical
# evidence shows that the disc disease of the lumbar spine does
# not currently manifest any separately ratable compensable
# neurologic deficits such that an evaluation under Diagnostic
# Code 8520 would be appropriate.
#
#
# Sentence 164: As for the Formula for Rating Intervertebral Disc Syndrome
# Based on Incapacitating Episodes, it would not be to the
# veteran's advantage for his disability to be evaluated there
# under.
#
#
# Sentence 165: There is no documented evidence that a physician
# prescribed the veteran bed rest and treatment for a certain
# duration of time at any time during the appeal period.
#
#
# Sentence 166: Moreover, even by the veteran's own description at the
# January 2004 VA examination, he does not experience
# incapacitating episodes having a total duration of at least 2
# weeks over the course of 12 months, which is the minimum
# criterion associated with a 20 percent rating under the
# formula.
#
#
# Sentence 167: Thus, evaluation of the veteran's low back
# disability on the basis of the total duration of
# incapacitating episodes over the course of 12 months would
# not be to his advantage.
#
#
# Sentence 168: The Board concludes that as between the old schedule for
# rating spine disabilities and the amended schedule for rating
# spine disabilities, evaluation of the veteran's low back
# disability under the old schedule results in a higher rating
# of 20 percent, and therefore, he is entitled to resolution of
# his claim there under.
#
#
# Sentence 169: The veteran's low back disability has not been shown to be
# manifested by greater than the criteria associated with a 20
# percent rating during any portion of the appeal period.
#
#
# Sentence 170: Accordingly, a staged rating is not in order and a 20 percent
# rating is appropriate for the entire period of the veteran's
# appeal.
#
#
# Sentence 171: Fenderson v. West, 12 Vet. App. 119 (1999).
#
#
# Sentence 172: An increased rating may also be granted on an extraschedular
# basis when it is demonstrated that the particular disability
# presents such an exceptional or unusual disability picture
# with such related factors as marked interference with
# employment or frequent periods of hospitalization as to
# render impractical the application of the regular schedular
# standards.
#
#
# Sentence 173: 38 C.F.R. � 3.321(b)(1) (2005).
#
#
# Sentence 174:  The Board finds
# no evidence that the veteran's low back disability presented
# such an unusual or exceptional disability picture at any time
# so as to require consideration of an extraschedular
# evaluation pursuant to the provisions of 38 C.F.R. �
# 3.321(b)(1).
#
#
# Sentence 175: The veteran contends that he is precluded from certain types
# of employment involving heavy labor, but he also indicated
# that he was currently studying to enable him to find other
# types of employment-presumably, less labor intensive work or
# sedentary work.
#
#
# Sentence 176: More significantly, the veteran's contention
# is at odds with the objective medical evidence of record that
# shows that manifestations of his low back disability do not
# result in a marked functional impairment in a way or to a
# degree other than that addressed by VA's Rating Schedule.
#
#
# Sentence 177: The schedular rating criteria are designed to compensate for
# average impairments in earning capacity resulting from
# service-connected disability in civil occupations.
#
#
# Sentence 178: 38
# U.S.C.A. � 1155 (West 2002).
#
#
# Sentence 179: Generally, the degrees of
# disability specified in the rating schedule are considered
# adequate to compensate for considerable loss of working time
# from exacerbations or illnesses proportionate to the severity
# of the several grades of disability.
#
#
# Sentence 180: 38 C.F.R. � 4.1 (2005).
#
#
# Sentence 181: Consequently, the Board concludes that referral of this case
# for consideration of an extraschedular rating is not
# warranted.
#
#
# Sentence 182: Bagwell v. Brown, 9 Vet. App. 337, 338-39 (1996);
# Floyd v. Brown, 9 Vet. App. 88, 96 (1996).
#
#
# Sentence 183: ORDER
#
#
#
# Sentence 184: A higher initial rating of 20 percent for service-connected
# lumbosacral strain with lumbar disc disease is granted,
# subject to the law and regulations controlling the award of
# monetary benefits.
#
#
# Sentence 185: ____________________________________________
# John E. Ormond, Jr.
# Veterans Law Judge, Board of Veterans' Appeals
#
#
#
#
#  Department of Veterans Affairs

# %% [markdown]
# ##### View the generated splits using standard segmenter

# %%
# Generated splits
doc_id = doc_id
nlp = spacy.load("en_core_web_sm")
gen_ann_span_std = generate_ann_span_by_doc_with_spacy([doc_id], nlp)

df = pd.DataFrame([gen_ann_span_std[doc_id]['start'], gen_ann_span_std[doc_id]['end']]).T
df.columns = ['start', 'end']
df = df.sort_values('start').reset_index(drop=True)
df_gen = np.array(df)

test_doc = documents_by_id[doc_id]['plainText']

print(f"Generated splits with standard segmenter for the document: {doc_id}")
print("-------------------------------------------------------------------------------------")

for i, gen_span in enumerate(df_gen):
    print(f"Sentence {i+1}: {(test_doc[gen_span[0]: gen_span[1]]).strip()}\n\n")
# Out:
# Generated splits with standard segmenter for the document: 61aea55c97ad59b4cfc4129f
# -------------------------------------------------------------------------------------
# Sentence 1: Citation Nr: 0610579
# Decision Date: 04/13/06    Archive Date: 04/26/06
#
# DOCKET NO.
#
#
# Sentence 2: 04-19 577	)	DATE
# 	)
# 	)
#
# On appeal from the
# Department of Veterans Affairs Regional Office in Manila, the
# Republic of the Philippines
#
#
# THE ISSUE
#
# Entitlement to a higher initial rating for service-connected
# lumbosacral strain with lumbar disc disease, currently
# evaluated as 10 percent disabling.
#
#
# Sentence 3: REPRESENTATION
#
# Appellant represented by:	Veterans of Foreign Wars of
# the United States
#
#
# WITNESS AT HEARING ON APPEAL
#
# Veteran
#
#
#
# ATTORNEY FOR THE BOARD
#
# Tanya A. Smith, Counsel
#
#
# INTRODUCTION
#
#
# Sentence 4: The veteran had active service from December 1998 to April
# 2003.
#
#
# Sentence 5: This matter comes before the Board of Veterans' Appeals
# (Board) on appeal from a July 2003 rating decision of the
# Department of Veterans Affairs (VA) Regional Office (RO) in
# Manila, the Republic of the Philippines.
#
#
# Sentence 6: FINDINGS OF FACT
#
# 1.
#
#
# Sentence 7: The veteran has been notified of the evidence necessary to
# substantiate his
# claims, and all relevant evidence necessary for an equitable
# disposition of this appeal has been obtained.
#
#
# Sentence 8: 2.
#
#
# Sentence 9: Under the old schedule for rating spine disabilities, the
# evidence shows that the veteran's service-connected low back
# disability is productive of slight limitation of motion, but
# with pain and repetitive motion, and resolution of reasonable
# doubt in favor of the veteran, it is more moderately
# disabling.
#
#
# Sentence 10: 3.
#
#
# Sentence 11: Under the amended schedule for rating spine disabilities,
# the medical evidence shows that the veteran's low back
# disability is only productive of forward flexion to 85
# degrees or more and absent any separately ratable compensable
# neurologic deficits associated with disc disease; no
# physician prescribed the veteran bed rest and treatment for
# incapacitating episodes of intervertebral disc syndrome
# having a total duration of at least two weeks over the course
# of 12 months.
#
#
# Sentence 12: CONCLUSION OF LAW
#
# The schedular criteria for a higher initial rating of 20
# percent for service-connected lumbosacral strain with lumbar
# disc disease have been approximated under the old schedule
# for rating spine disabilities.
#
#
# Sentence 13: 38 U.S.C.A. �� 1155, 5103,
# 5103A, 5107(b)
#
#
# Sentence 14: (West 2002 & Supp. 2005); 38 C.F.R. �� 3.102,
# 3.159, 4.1-4.14, 4.27, 4.71a, Diagnostic Code 5292 (2003).
#
#
# Sentence 15: REASONS AND BASES FOR FINDINGS AND CONCLUSION
#
# Veterans Claims Assistance Act of 2000
#
# The Veterans Claims Assistance Act of 2000, Pub.
#
#
# Sentence 16: L. No. 106-
# 475, 114 Stat.
#
#
# Sentence 17: 2096 (2000)
#
#
# Sentence 18: (VCAA) redefines the obligations
# of VA with respect to the duty to assist and includes an
# enhanced duty to notify a claimant as to the information and
# evidence necessary to substantiate a claim for VA benefits.
#
#
# Sentence 19: 38 U.S.C.A. �� 5103, 5103A (West 2002 & Supp. 2005); 38
# C.F.R. � 3.159 (2005).
#
#
# Sentence 20: VA is required to provide the
# claimant with notice of what information or evidence is to be
# provided by the Secretary and what information or evidence is
# to be provided by the claimant with respect to the
# information and evidence necessary to substantiate the claim
# for VA benefits.
#
#
# Sentence 21: Quartuccio v. Principi, 16 Vet. App.
#
#
# Sentence 22: 183,
# 187 (2002).
#
#
# Sentence 23: The Board finds that VA's enhanced duty to notify under the
# VCAA has been met.
#
#
# Sentence 24: In this regard, the Board notes that in correspondence dated
# in June 2003, the RO advised the veteran of VA's duties under
# the VCAA and the delegation of responsibility between VA and
# the veteran in procuring the evidence relevant to the claim,
# including which portion of the information and evidence
# necessary to substantiate the claim was to be provided by the
# veteran and which portion VA would attempt to obtain on
# behalf of the veteran.
#
#
# Sentence 25: Quartuccio, 16 Vet. App.
#
#
# Sentence 26: at 187.
#
#
# Sentence 27: The
# June 2003 VCAA notice advised the veteran of what the
# evidence must show to establish entitlement to service-
# connected compensation benefits.
#
#
# Sentence 28: During the course of this appeal, on March 3, 2006, the
# United States Court of Appeals for Veterans Claims (Court)
# issued a decision in the consolidated appeal of
# Dingess/Hartman v. Nicholson, Nos. 01-1917 and 02-1506, which
# held that the VCAA notice requirements of 38 U.S.C.A.
# � 5103(a) and 38 C.F.R. � 3.159(b) apply to all five elements
# of a service connection claim.
#
#
# Sentence 29: Those five elements include:
# 1) veteran status; 2) existence of a disability; (3) a
# connection between the veteran's service and the disability;
# 4) degree of disability; and 5) effective date of the
# disability.
#
#
# Sentence 30: In addition to the notice described above, the
# Court also held that upon receipt of an application for a
# service-connection claim, 38 U.S.C.A.               � 5103(a)
# and 38 C.F.R. � 3.159(b) require VA to provide the claimant
# with
# notice that a disability rating and an effective date for the
# award of benefits will be assigned if service connection is
# awarded and the claimant should be notified of the type of
# evidence necessary to establish a disability rating or
# effective date for the disability(ies) on appeal.
#
#
# Sentence 31: Dingess/Hartman, slip op.
#
#
# Sentence 32: at 14.
#
#
# Sentence 33:
#
#
# Sentence 34: In the instant appeal, the veteran was not provided with
# notice of the type of evidence necessary to establish a
# disability rating or effective date for his service-connected
# low back disability.
#
#
# Sentence 35: Despite the inadequate notice provided
# to the veteran on these latter two elements, the Board finds
# no prejudice to the veteran in proceeding with the issuance
# of a final decision.
#
#
# Sentence 36: See Bernard v. Brown, 4 Vet. App.
#
#
# Sentence 37: 384,
# 394 (1993)
#
#
# Sentence 38: (providing that where the Board addresses a
# question that has not been addressed by the agency of
# original jurisdiction, the Board must consider whether the
# veteran has been prejudiced thereby).
#
#
# Sentence 39: In this regard, the
# Board notes that in the veteran's Notice of Disagreement
# (NOD), he contended that he was entitled to a higher initial
# rating of 20 percent or more because of his "occasional
# severe lower back pain and limited range of motion," and he
# subsequently thereafter submitted additional medical evidence
# in support of his claim in October 2003.
#
#
# Sentence 40: Thus, it is clearly
# demonstrated that the veteran understood that lay evidence
# describing his symptoms and medical evidence showing a higher
# degree of severity in symptomatology associated with his low
# back disability were the types of evidence necessary to
# substantiate his claim.
#
#
# Sentence 41: The Board also notes that the RO
# afforded the veteran a new VA examination in January 2004 in
# response to the veteran's NOD and additional medical evidence
# and for purposes of generating the type of evidence needed to
# substantiate the veteran's claim.
#
#
# Sentence 42: Additionally, the April
# 2004 Statement of the Case (SOC) sets forth the rating
# criteria for all ratings in excess of 10 percent under the
# diagnostic codes assigned this disability.
#
#
# Sentence 43: As the Board
# concludes below that the veteran is entitled to a partial
# grant and that staged ratings are not appropriate, the
# effective date of the higher rating most likely will be the
# day following the veteran's discharge from service, which is
# the earliest date available under VA law and regulations.
#
#
# Sentence 44:
#
#
# Sentence 45: For these reasons, the Board finds no prejudice to the
# veteran despite the inadequate notice provided him on these
# last two elements.
#
#
# Sentence 46: The Board acknowledges that the June 2003 VCAA notice
# contained no specific request for the veteran to provide any
# evidence in the veteran's possession that pertained to the
# claim or something to the effect that the veteran give VA
# everything he had that pertained to his claim.
#
#
# Sentence 47: 38 C.F.R.
# � 3.159(b)(1) (2005).
#
#
# Sentence 48: A complying notice, however, need not necessarily use the
# exact language of the regulation so long as that notice
# properly conveys to a claimant the essence of the regulation.
#
#
# Sentence 49: Mayfield v. Nicholson, 19 Vet. App. 103 (2005).
#
#
# Sentence 50: The RO asked
# the veteran for all the information and evidence necessary to
# substantiate his claim-that is, evidence of the type that
# should be considered by VA in assessing his claim.
#
#
# Sentence 51: Throughout the course of this appeal, the veteran has set
# forth his contentions and submitted pertinent medical
# evidence.
#
#
# Sentence 52: Therefore, it can be concluded, based on the
# particular facts and circumstances of the case, the omission
# of the request for "any evidence in the claimant's
# possession that pertains to the claim" in the notice did not
# harm the veteran, and it would be legally proper to render a
# decision in the case without further notice under the
# regulation.
#
#
# Sentence 53: Id.
#
#
# Sentence 54: In further regard to VA's duty to notify, the Board notes
# that the RO provided the veteran with a copy of the July 2003
#
#
# Sentence 55: rating decision and April 2004 SOC, which included a
# discussion of the facts of the claim, notification of the
# basis of the decision, and a summary of the evidence used to
# reach the decision.
#
#
# Sentence 56: The SOC provided the veteran with notice
# of all the laws and regulations pertinent to his claim,
# including the law and implementing regulations of the VCAA.
#
#
# Sentence 57: The Board notes that the schedule for rating spine
# disabilities was amended in August 2003, effective September
# 26, 2003.
#
#
# Sentence 58: Amendment to Part 4, Schedule for Rating
# Disabilities, 68 Fed.
#
#
# Sentence 59: Reg. 51454-51458 (August 27, 2003)
# (codified at 38 C.F.R. � 4.71a, Diagnostic Codes 5235, 5236,
# 5237, 5238, 5239, 5240, 5241, 5242, 5243 (2005)).
#
#
# Sentence 60: Prior to
# that, the rating criteria for evaluating intervertebral disc
# syndrome were changed, effective September 23, 2002.
#
#
# Sentence 61: Amendment to Part 4, Schedule for Rating Disabilities, 67
# Fed.
#
#
# Sentence 62: Reg.
#
#
# Sentence 63: 54345-54349 (August 22, 2002) (codified at 38
# C.F.R. � 4.71a, Diagnostic Code 5293 (2003)).
#
#
# Sentence 64: The new rating
# criteria for intervertebral disc syndrome were subsumed in
# the aforementioned amended rating schedule for spine
# disabilities.
#
#
# Sentence 65: When the regulations concerning entitlement to
# a higher rating are changed during the course of an appeal,
# the veteran is entitled to resolution of his or her claim
# under the criteria that are more to his or her advantage.
#
#
# Sentence 66: VAOPGCPREC 3-00.
#
#
# Sentence 67: The April 2004 SOC shows that the RO
# considered the veteran's low back disability under the
# applicable old and new diagnostic rating criteria.
#
#
# Sentence 68: In
# addition, the veteran was provided with notice of the
# applicable old and revised rating criteria.
#
#
# Sentence 69: The Board concludes that the requirements of the notice
# provisions of the VCAA have been met, and there is no
# outstanding duty to inform the veteran that any additional
# information or evidence is needed.
#
#
# Sentence 70: Quartuccio, 16 Vet. App.
#
#
# Sentence 71: at 187.
#
#
# Sentence 72: In regard to VA's duty to assist, the Board notes that in
# addition to the January 2004 VA examination, the RO had also
# afforded the veteran an examination in July 2003.
#
#
# Sentence 73: Lastly,
# the RO scheduled the veteran for a videoconference hearing,
# which was held in January 2006.
#
#
# Sentence 74: The veteran has not made the
# RO or the Board aware of any other evidence relevant to his
# appeal that needs to be obtained.
#
#
# Sentence 75: Based on the foregoing,
# the Board finds that all relevant facts have been properly
# and sufficiently developed in this appeal and no further
# development is required to comply with the duty to assist the
# veteran in developing the facts pertinent to his claim.
#
#
# Sentence 76: Accordingly, the Board will proceed with appellate review.
#
#
# Sentence 77: Procedural History and Evidence
#
# In a July 2003 rating decision, the RO awarded service
# connection for lumbosacral sprain with limitation of motion
# and assigned a 10 percent rating under Diagnostic Codes 5295-
# 5292, effective from April 4, 2003, the day following the
# veteran's discharge from service.
#
#
# Sentence 78: In the SOC, the RO
# recharacterized the issue as 'lumbosacral strain with lumbar
# disc disease' and continued the assigned disability rating.
#
#
# Sentence 79: The service medical records show that the veteran was
# followed for complaints of intermittent low back pain
# exacerbated with "work," lifting, and prolonged sitting,
# standing, and walking.
#
#
# Sentence 80: A March 2001 computerized tomography
# scan (CT) scan revealed spinal stenosis at L2 through L4,
# degenerative disc disease at L4-5 and L5-S1, and posterior
# facet degenerative joint disease affecting left L-4 and
# bilateral L-5 roots.
#
#
# Sentence 81: A March 2003 record noted an assessment
# of recurrent low back pain, possible bilateral mutated sacrum
# (posterior) versus left "ant" mutated "FRSR" lumbar at L5.
#
#
# Sentence 82:
#
#
# Sentence 83: The July 2003 VA examination report shows that the examiner
# reviewed the claims file.
#
#
# Sentence 84: The examiner related that the
# veteran complained of pain, discomfort, and decreased range
# of motion.
#
#
# Sentence 85: The physical examination revealed tenderness of
# L4 and L5.
#
#
# Sentence 86: On range of motion of the lumbar spine, flexion
# was 0 to 85 degrees, extension was 0 to 30 degrees, lateral
# bending to the left was 0 to 35 degrees, and lateral bending
# to the right was 0 to 30 degrees.
#
#
# Sentence 87: The examiner noted that
# the veteran had a slight decrease in lateral bending to the
# right
#
#
# Sentence 88: and that the veteran had good effort but pain and
# discomfort were noted of the lower back upon movement.
#
#
# Sentence 89: The
# examiner provided a diagnosis of lumbosacral sprain with mild
# decreased range of motion, pain, and discomfort.
#
#
# Sentence 90: The
# radiographic report noted an impression of narrowing of the
# L5-S1 intervertebral disk space.
#
#
# Sentence 91: VA treatment records dated in October 2003 showed an
# examination revealed mild tenderness over the lumbar spine
# and mild paraspinal spasm.
#
#
# Sentence 92: The examiner noted an assessment
# of chronic low back pain.
#
#
# Sentence 93: It was noted that the veteran was
# unemployed.
#
#
# Sentence 94: The examiner reported that he impressed on the
# veteran the importance of weight loss and how it might
# alleviate his back pain.
#
#
# Sentence 95: In an October 2003 letter, J.L., DC reported on clinical
# findings not centered on the veteran's service-connected low
# back disability.
#
#
# Sentence 96: The January 2004 VA examination report shows that the
# examiner reviewed the claims file.
#
#
# Sentence 97: The examiner noted that
# x-rays, a CT scan, and magnetic resonance imaging scans have
# revealed some disc degenerations at L4 and L5 with some
# protrusions, bulging, and some stenosis.
#
#
# Sentence 98: The veteran
# complained of problems associated with repetitive bending and
# lifting; he indicated that heavy bending, lifting, and work
# aggravated his back.
#
#
# Sentence 99: He complained of flare-ups once or
# twice a year during which time he had to spend time in bed
# for four or five days; other times he experienced only
# chronic backache.
#
#
# Sentence 100: He indicated that the pain went into his
# buttock area and legs or feet, but he denied that he
# experienced radicular pain.
#
#
# Sentence 101: During flare-ups, he used a back
# brace or cane to move around; otherwise, he could stand or
# walk all day long, but the problem was he could not do
# repetitive bending or lifting activities.
#
#
# Sentence 102: He maintained that
# he currently was not working because he could not perform
# heavy labor activities; he could perform normal daily
# activity and he had normal mobility.
#
#
# Sentence 103: The examiner observed that the veteran was not wearing a
# brace or using a cane at the exam.
#
#
# Sentence 104: The examiner indicated
# that there was no systemic symptoms or bladder or bowel
# dysfunction noted.
#
#
# Sentence 105: The examiner observed that the veteran
# could ambulate without aid or assistance and that he had a
# normal stance and gait.
#
#
# Sentence 106: The exam of the spine did not show
# any deformity; there was no increased kyphosis or scoliosis.
#
#
# Sentence 107:
#
#
# Sentence 108: He had some lumbosacral tenderness to palpation.
#
#
# Sentence 109: There were
# no muscle spasms.
#
#
# Sentence 110: He could forward flex 90 out of 90
# degrees, and extend and rotate 25 out of 30 degrees with pain
# at the extremes of motion.
#
#
# Sentence 111: There was no sciatica present.
#
#
# Sentence 112: He could rise up from his toes and heels.
#
#
# Sentence 113: Leg raise was
# negative in the seated position.
#
#
# Sentence 114: Reflexes were 1-2+ and
# equal at the knee and at the ankle.
#
#
# Sentence 115: He had normal strength
# and normal sensation in the lower extremities.
#
#
# Sentence 116: The examiner
# provided a diagnosis of lumbosacral strain with lumbar disc
# disease.
#
#
# Sentence 117: In the veteran's May 2004 Substantive Appeal, he additionally
# complained that he experienced occasional locking of the
# lower back.
#
#
# Sentence 118: At the January 2006 videoconference hearing, the veteran
# presented testimony on his symptoms that was similar to
# previously discussed complaints.
#
#
# Sentence 119: In addition, he denied ever
# having surgery or that a physician had recommended that
# surgery be performed.
#
#
# Sentence 120: He indicated that he was currently
# studying for purposes of finding employment.
#
#
# Sentence 121: He maintained
# that he experienced only one episode of pain that radiated
# down to his thigh.
#
#
# Sentence 122: He initially denied that he experienced
# numbness in his legs or tingling, but then added that he
# experienced shooting pain that radiated to his legs that he
# confirmed started as a result of his injury.
#
#
# Sentence 123: Analysis
#
# As previously noted, the veteran's low back disability is
# currently assigned a 10 percent rating under Diagnostic Codes
# 5295-5292 of the old schedule for rating spine disabilities.
#
#
# Sentence 124: The medical evidence shows that a mild paraspinal spasm was
# objectively demonstrated on examination in October 2003, but
# not reproduced at the January 2004 VA examination nor noted
# to be present at the July 2003 VA examination.
#
#
# Sentence 125: The July 2003
# VA examination revealed normal (defined below) range of
# motion on lateral bending to the left and right.
#
#
# Sentence 126: The Board
# finds that the evidence fails to show that the veteran's low
# back disability is primarily productive of muscle spasm on
# extreme forward bending with unilateral loss of lateral spine
# motion, the criteria associated with the next higher rating
# of 20 percent under Diagnostic Code 5295 of the old schedule.
#
#
# Sentence 127: As for Diagnostic Code 5292, 38 C.F.R. � 4.71a, Diagnostic
# Codes 5290 through 5292 (2003) of the old schedule rated
# limitation of motion of the spine according to whether it was
# slight, moderate, or severe.
#
#
# Sentence 128: The words "slight,"
# "moderate," and "severe" are not defined in the VA
# Schedule for Rating Disabilities.
#
#
# Sentence 129: Guidance can be obtained
# from the amended regulations.
#
#
# Sentence 130: The current definition of
# normal range of motion for the spine is based on medical
# guidelines in existence since 1984; therefore, the Board will
# apply the current ranges of motion to rating spine
# disabilities under the old criteria.
#
#
# Sentence 131: Normal forward flexion
# of the thoracolumbar spine is zero to 90 degrees, extension
# is zero to 30 degrees, left and right lateral flexion are
# zero to 30 degrees, and left and right lateral rotation are
# zero to 30 degrees.
#
#
# Sentence 132: 38 C.F.R. � 4.71a, General Rating
# Formula for Diseases and Injuries of the Spine, Note (2)
# (2005).
#
#
# Sentence 133: Under Diagnostic Code 5292, a 20 percent rating is assigned
# for moderate limitation of motion of the lumbar spine, and a
# 40 percent rating is assigned for severe limitation of
# motion.
#
#
# Sentence 134: 38 C.F.R. � 4.71a, Diagnostic Code 5292 (2003).
#
#
# Sentence 135: A slight loss of motion on flexion, extension, and rotation
# was demonstrated at the July 2003 and January 2004 VA
#
#
# Sentence 136: examinations.
#
#
# Sentence 137: Thus, the veteran's low back disability is not
# productive of moderate limitation of motion of the lumbar
# spine.
#
#
# Sentence 138: The Board, however, notes that the veteran primarily
# complains of pain and fatigue with repetitive motion
# resulting in decreased motion.
#
#
# Sentence 139: His current complaints are
# similar to complaints well documented in the service medical
# records.
#
#
# Sentence 140: In determining the degree of limitation of motion,
# the provisions of 38 C.F.R. �� 4.10, 4.40, and 4.45 are for
# consideration.
#
#
# Sentence 141: DeLuca v. Brown, 8 Vet. App.
#
#
# Sentence 142: 202 (1995).
#
#
# Sentence 143: The
# factors involved in evaluating and rating disabilities of the
# joints include, weakness, fatigability, incoordination,
# restricted or excess movement of the joint, or pain on
# movement.
#
#
# Sentence 144: 38 C.F.R. � 4.45 (2005).
#
#
# Sentence 145: The Board resolves
# reasonable doubt in favor of the veteran that with pain and
# repetitive motion of his lower back, it is more moderately
# disabling, such that a 20 percent rating under Diagnostic
# Code 5292 of the old schedule is appropriate.
#
#
# Sentence 146: 38 C.F.R.
# �� 3.102, 4.7 (2005).
#
#
# Sentence 147: The veteran, however, is not entitled
# to the next higher rating of 40 percent as the medical
# evidence does not show severe limitation of motion or severe
# impairment associated with the back disability.
#
#
# Sentence 148: The Board is required to consider other diagnostic codes
# under the old schedule to determine whether the veteran is
# entitled to a rating in excess of 20 percent under any of
# them.
#
#
# Sentence 149: The medical evidence shows that there is no x-ray evidence of
# residuals of a fracture of the vertebra attributable to the
# service-connected low back disability.
#
#
# Sentence 150: The medical evidence
# also shows that the veteran does not have ankylosis of the
# lumbar spine.
#
#
# Sentence 151: Service connection is in effect for
# degenerative disc disease of the lumbar spine, but the
# medical evidence shows that the disc disease does not
# currently manifest any separately ratable compensable
# neurologic deficits.
#
#
# Sentence 152: Thus, the veteran is precluded from an
# evaluation under Diagnostic Codes 5285 and 5289 of the old
# schedule and Diagnostic Code 8520.
#
#
# Sentence 153: 38 C.F.R. � 4.71a,
# Diagnostic Codes 5285, 5289 (2003); 38 C.F.R. � 4.124a,
# Diagnostic Code 8520 (2005).
#
#
# Sentence 154: Accordingly, the Board concludes that the veteran is entitled
# to a higher initial rating of 20 percent, but not higher, for
# service-connected lumbosacral strain with lumbar disc disease
# under the old schedule for rating spine disabilities.
#
#
# Sentence 155: The Board now considers the veteran's service-connected low
# back disability under the schedule for rating spine
# disabilities as amended in August 2003, effective September
# 26, 2003.
#
#
# Sentence 156: Under the amended schedule, any associated
# objective neurologic abnormalities, including, but not
# limited to bowel or bladder impairment are to be evaluated
# separately under an appropriate diagnostic code.
#
#
# Sentence 157: 38 C.F.R.
# � 4.71a, General Rating Formula, Note 1 (2005).
#
#
# Sentence 158: Intervertebral disc syndrome is to be evaluated either under
# the General Rating Formula for Diseases and Injuries of the
# Spine or under the Formula for Rating Intervertebral Disc
# Syndrome Based on Incapacitating Episodes, whichever method
# results in the higher evaluation when all disabilities are
# combined under � 4.25.
#
#
# Sentence 159: Under the General Rating Formula for Diseases and Injuries of
# the Spine, with or without symptoms such as pain (whether or
# not it radiates), stiffness, or aching in the area of the
# spine affected by residuals of injury or disease, a 10
# percent rating is assigned for forward flexion of the
# thoracolumbar spine greater than 60 degrees but not greater
# than 85 degrees; or, combined range of motion of the
# thoracolumbar spine greater than 120 degrees but not greater
# than 235 degrees; or, muscle spasm, guarding, or localized
# tenderness not resulting in abnormal gait or abnormal spinal
# contour; or, vertebral body fracture with loss of 50 percent
# or more of the height.
#
#
# Sentence 160: 38 C.F.R. � 4.71a (2005).
#
#
# Sentence 161: A 20
# percent rating is assigned for forward flexion of the
# thoracolumbar spine greater than 30 degrees but not greater
# than 60 degrees; or, the combined range of motion of the
# thoracolumbar spine not greater than 120 degrees; or, muscle
# spasm or guarding severe enough to result in an abnormal gait
# or abnormal spinal contour such as scoliosis, reversed
# lordosis, or abnormal kyphosis.
#
#
# Sentence 162: Id.  A 40 percent rating is
# assigned for forward flexion of the thoracolumbar spine 30
# degrees or less; or, favorable ankylosis of the entire
# thoracolumbar spine.
#
#
# Sentence 163: Id.  A 50 percent rating is assigned
# for unfavorable ankylosis of the entire thoracolumbar spine.
#
#
# Sentence 164: Id.  A 100 percent rating is assigned for unfavorable
# ankylosis of the entire spine.
#
#
# Sentence 165: Id.
#
# The medical evidence shows that the veteran's low back
# disability is only productive of the criteria associated with
# a 10 percent rating for forward flexion to 85 degrees or
# more.
#
#
# Sentence 166: Therefore, the veteran is only entitled to a 10
# percent rating under the amended schedule for rating spine
# disabilities with respect to the orthopedic manifestations of
# the low back disability.
#
#
# Sentence 167: As for neurologic manifestations associated with the low back
# disability, the Board previously noted that the medical
# evidence shows that the disc disease of the lumbar spine does
# not currently manifest any separately ratable compensable
# neurologic deficits such that an evaluation under Diagnostic
# Code 8520 would be appropriate.
#
#
# Sentence 168: As for the Formula for Rating Intervertebral Disc Syndrome
# Based on Incapacitating Episodes, it would not be to the
# veteran's advantage for his disability to be evaluated there
# under.
#
#
# Sentence 169: There is no documented evidence that a physician
# prescribed the veteran bed rest and treatment for a certain
# duration of time at any time during the appeal period.
#
#
# Sentence 170: Moreover, even by the veteran's own description at the
# January 2004 VA examination, he does not experience
# incapacitating episodes having a total duration of at least 2
# weeks over the course of 12 months, which is the minimum
# criterion associated with a 20 percent rating under the
# formula.
#
#
# Sentence 171: Thus, evaluation of the veteran's low back
# disability on the basis of the total duration of
# incapacitating episodes over the course of 12 months would
# not be to his advantage.
#
#
# Sentence 172: The Board concludes that as between the old schedule for
# rating spine disabilities and the amended schedule for rating
# spine disabilities, evaluation of the veteran's low back
# disability under the old schedule results in a higher rating
# of 20 percent, and therefore, he is entitled to resolution of
# his claim there under.
#
#
# Sentence 173:
#
#
# Sentence 174: The veteran's low back disability has not been shown to be
# manifested by greater than the criteria associated with a 20
# percent rating during any portion of the appeal period.
#
#
# Sentence 175: Accordingly, a staged rating is not in order and a 20 percent
# rating is appropriate for the entire period of the veteran's
# appeal.
#
#
# Sentence 176: Fenderson v. West, 12 Vet. App.
#
#
# Sentence 177: 119 (1999).
#
#
# Sentence 178: An increased rating may also be granted on an extraschedular
# basis when it is demonstrated that the particular disability
# presents such an exceptional or unusual disability picture
# with such related factors as marked interference with
# employment or frequent periods of hospitalization as to
# render impractical the application of the regular schedular
# standards.
#
#
# Sentence 179: 38 C.F.R. � 3.321(b)(1) (2005).
#
#
# Sentence 180: The Board finds
# no evidence that the veteran's low back disability presented
# such an unusual or exceptional disability picture at any time
# so as to require consideration of an extraschedular
# evaluation pursuant to the provisions of 38 C.F.R. �
# 3.321(b)(1).
#
#
# Sentence 181: The veteran contends that he is precluded from certain types
# of employment involving heavy labor, but he also indicated
# that he was currently studying to enable him to find other
# types of employment-presumably, less labor intensive work or
# sedentary work.
#
#
# Sentence 182: More significantly, the veteran's contention
# is at odds with the objective medical evidence of record that
# shows that manifestations of his low back disability do not
# result in a marked functional impairment in a way or to a
# degree other than that addressed by VA's Rating Schedule.
#
#
# Sentence 183:
#
#
# Sentence 184: The schedular rating criteria are designed to compensate for
# average impairments in earning capacity resulting from
# service-connected disability in civil occupations.
#
#
# Sentence 185: 38
# U.S.C.A. � 1155 (West 2002).
#
#
# Sentence 186: Generally, the degrees of
# disability specified in the rating schedule are considered
# adequate to compensate for considerable loss of working time
# from exacerbations or illnesses proportionate to the severity
# of the several grades of disability.
#
#
# Sentence 187: 38 C.F.R. � 4.1 (2005).
#
#
# Sentence 188:
#
#
# Sentence 189: Consequently, the Board concludes that referral of this case
# for consideration of an extraschedular rating is not
# warranted.
#
#
# Sentence 190: Bagwell v. Brown, 9 Vet. App.
#
#
# Sentence 191: 337, 338-39 (1996);
# Floyd v. Brown, 9 Vet. App. 88, 96 (1996).
#
#
# Sentence 192: ORDER
#
# A higher initial rating of 20 percent for service-connected
# lumbosacral strain with lumbar disc disease is granted,
# subject to the law and regulations controlling the award of
# monetary benefits.
#
#
# Sentence 193: ____________________________________________
# John E. Ormond, Jr.
#
#
# Sentence 194: Veterans Law Judge, Board of Veterans' Appeals
#
#
#
#
#  Department of Veterans Affairs

# %% [markdown]
# ##### View the generated splits using the extended segmenter

# %%
# Generated splits
doc_id = doc_id
nlp = spacy.load("en_core_web_sm")
# nlp.add_pipe("set_custom_boundaries_original", before="parser")
nlp.add_pipe("set_custom_boundaries", before="parser")
gen_ann_span_ext = generate_ann_span_by_doc_with_spacy([doc_id], nlp)

df = pd.DataFrame([gen_ann_span_ext[doc_id]['start'], gen_ann_span_ext[doc_id]['end']]).T
df.columns = ['start', 'end']
df = df.sort_values('start').reset_index(drop=True)
df_gen = np.array(df)

test_doc = documents_by_id[doc_id]['plainText']

print(f"Generated splits with standard segmenter for the document: {doc_id}")
print("-------------------------------------------------------------------------------------")

for i, gen_span in enumerate(df_gen):
    print(f"Sentence {i+1}: {(test_doc[gen_span[0]: gen_span[1]]).strip()}\n\n")
# Out:
# Generated splits with standard segmenter for the document: 61aea55c97ad59b4cfc4129f
# -------------------------------------------------------------------------------------
# Sentence 1: Citation Nr: 0610579
# Decision Date: 04/13/06    Archive Date: 04/26/06
#
# DOCKET NO.  04-19 577	)	DATE
# 	)
# 	)
#
#
# Sentence 2: On appeal from the
# Department of Veterans Affairs Regional Office in Manila, the
# Republic of the Philippines
#
#
# Sentence 3: THE ISSUE
#
#
# Sentence 4: Entitlement to a higher initial rating for service-connected
# lumbosacral strain with lumbar disc disease, currently
# evaluated as 10 percent disabling.
#
#
# Sentence 5:
#
#
# Sentence 6: REPRESENTATION
#
#
# Sentence 7: Appellant represented by:	Veterans of Foreign Wars of
# the United States
#
#
# Sentence 8: WITNESS AT HEARING ON APPEAL
#
#
# Sentence 9: Veteran
#
#
# Sentence 10: ATTORNEY FOR THE BOARD
#
#
# Sentence 11: Tanya A. Smith, Counsel
#
#
# Sentence 12: INTRODUCTION
#
#
# Sentence 13: The veteran had active service from December 1998 to April
# 2003.
#
#
# Sentence 14: This matter comes before the Board of Veterans' Appeals
# (Board) on appeal from a July 2003 rating decision of the
# Department of Veterans Affairs (VA) Regional Office (RO) in
# Manila, the Republic of the Philippines.
#
#
# Sentence 15:
#
#
# Sentence 16: FINDINGS OF FACT
#
#
# Sentence 17: 1
#
#
# Sentence 18: .	The veteran has been notified of the evidence necessary to
# substantiate his
# claims, and all relevant evidence necessary for an equitable
# disposition of this appeal has been obtained.
#
#
# Sentence 19: 2.
#
#
# Sentence 20: Under the old schedule for rating spine disabilities, the
# evidence shows that the veteran's service-connected low back
# disability is productive of slight limitation of motion, but
# with pain and repetitive motion, and resolution of reasonable
# doubt in favor of the veteran, it is more moderately
# disabling.
#
#
# Sentence 21: 3.
#
#
# Sentence 22: Under the amended schedule for rating spine disabilities,
# the medical evidence shows that the veteran's low back
# disability is only productive of forward flexion to 85
# degrees or more and absent any separately ratable compensable
# neurologic deficits associated with disc disease; no
# physician prescribed the veteran bed rest and treatment for
# incapacitating episodes of intervertebral disc syndrome
# having a total duration of at least two weeks over the course
# of 12 months.
#
#
# Sentence 23:
#
#
# Sentence 24: CONCLUSION OF LAW
#
#
# Sentence 25: The schedular criteria for a higher initial rating of 20
# percent for service-connected lumbosacral strain with lumbar
# disc disease have been approximated under the old schedule
# for rating spine disabilities.
#
#
# Sentence 26: 38 U.S.C.A. �� 1155, 5103,
# 5103A, 5107(b)
#
#
# Sentence 27: (West 2002 & Supp. 2005); 38 C.F.R. �� 3.102,
# 3.159, 4.1-4.14, 4.27, 4.71a, Diagnostic Code 5292 (2003).
#
#
# Sentence 28:
#
#
# Sentence 29: REASONS AND BASES FOR FINDINGS AND CONCLUSION
#
#
# Sentence 30: Veterans Claims Assistance Act of 2000
#
# The Veterans Claims Assistance Act of 2000, Pub.
#
#
# Sentence 31: L. No. 106-
# 475, 114 Stat.
#
#
# Sentence 32: 2096 (2000)
#
#
# Sentence 33: (VCAA) redefines the obligations
# of VA with respect to the duty to assist and includes an
# enhanced duty to notify a claimant as to the information and
# evidence necessary to substantiate a claim for VA benefits.
#
#
# Sentence 34: 38 U.S.C.A. �� 5103, 5103A (West 2002 & Supp. 2005); 38
# C.F.R. � 3.159 (2005).
#
#
# Sentence 35: VA is required to provide the
# claimant with notice of what information or evidence is to be
# provided by the Secretary and what information or evidence is
# to be provided by the claimant with respect to the
# information and evidence necessary to substantiate the claim
# for VA benefits.
#
#
# Sentence 36: Quartuccio v. Principi, 16 Vet. App.
#
#
# Sentence 37: 183,
# 187 (2002).
#
#
# Sentence 38: The Board finds that VA's enhanced duty to notify under the
# VCAA has been met.
#
#
# Sentence 39: In this regard, the Board notes that in correspondence dated
# in June 2003, the RO advised the veteran of VA's duties under
# the VCAA and the delegation of responsibility between VA and
# the veteran in procuring the evidence relevant to the claim,
# including which portion of the information and evidence
# necessary to substantiate the claim was to be provided by the
# veteran and which portion VA would attempt to obtain on
# behalf of the veteran.
#
#
# Sentence 40: Quartuccio, 16 Vet. App.
#
#
# Sentence 41: at 187.
#
#
# Sentence 42: The
# June 2003 VCAA notice advised the veteran of what the
# evidence must show to establish entitlement to service-
# connected compensation benefits.
#
#
# Sentence 43: During the course of this appeal, on March 3, 2006, the
# United States Court of Appeals for Veterans Claims (Court)
# issued a decision in the consolidated appeal of
# Dingess/Hartman v. Nicholson, Nos. 01-1917 and 02-1506, which
# held that the VCAA notice requirements of 38 U.S.C.A.
# � 5103(a) and 38 C.F.R. � 3.159(b) apply to all five elements
# of a service connection claim.
#
#
# Sentence 44: Those five elements include:
# 1) veteran status; 2) existence of a disability; (3) a
# connection between the veteran's service and the disability;
# 4) degree of disability; and 5) effective date of the
# disability.
#
#
# Sentence 45: In addition to the notice described above, the
# Court also held that upon receipt of an application for a
# service-connection claim, 38 U.S.C.A.               � 5103(a)
# and 38 C.F.R. � 3.159(b) require VA to provide the claimant
# with
# notice that a disability rating and an effective date for the
# award of benefits will be assigned if service connection is
# awarded and the claimant should be notified of the type of
# evidence necessary to establish a disability rating or
# effective date for the disability(ies) on appeal.
#
#
# Sentence 46: Dingess/Hartman, slip op.
#
#
# Sentence 47: at 14.
#
#
# Sentence 48:
#
#
# Sentence 49: In the instant appeal, the veteran was not provided with
# notice of the type of evidence necessary to establish a
# disability rating or effective date for his service-connected
# low back disability.
#
#
# Sentence 50: Despite the inadequate notice provided
# to the veteran on these latter two elements, the Board finds
# no prejudice to the veteran in proceeding with the issuance
# of a final decision.
#
#
# Sentence 51: See Bernard v. Brown, 4 Vet. App.
#
#
# Sentence 52: 384,
# 394 (1993)
#
#
# Sentence 53: (providing that where the Board addresses a
# question that has not been addressed by the agency of
# original jurisdiction, the Board must consider whether the
# veteran has been prejudiced thereby).
#
#
# Sentence 54: In this regard, the
# Board notes that in the veteran's Notice of Disagreement
# (NOD), he contended that he was entitled to a higher initial
# rating of 20 percent or more because of his "occasional
# severe lower back pain and limited range of motion," and he
# subsequently thereafter submitted additional medical evidence
# in support of his claim in October 2003.
#
#
# Sentence 55: Thus, it is clearly
# demonstrated that the veteran understood that lay evidence
# describing his symptoms and medical evidence showing a higher
# degree of severity in symptomatology associated with his low
# back disability were the types of evidence necessary to
# substantiate his claim.
#
#
# Sentence 56: The Board also notes that the RO
# afforded the veteran a new VA examination in January 2004 in
# response to the veteran's NOD and additional medical evidence
# and for purposes of generating the type of evidence needed to
# substantiate the veteran's claim.
#
#
# Sentence 57: Additionally, the April
# 2004 Statement of the Case (SOC) sets forth the rating
# criteria for all ratings in excess of 10 percent under the
# diagnostic codes assigned this disability.
#
#
# Sentence 58: As the Board
# concludes below that the veteran is entitled to a partial
# grant and that staged ratings are not appropriate, the
# effective date of the higher rating most likely will be the
# day following the veteran's discharge from service, which is
# the earliest date available under VA law and regulations.
#
#
# Sentence 59:
#
#
# Sentence 60: For these reasons, the Board finds no prejudice to the
# veteran despite the inadequate notice provided him on these
# last two elements.
#
#
# Sentence 61: The Board acknowledges that the June 2003 VCAA notice
# contained no specific request for the veteran to provide any
# evidence in the veteran's possession that pertained to the
# claim or something to the effect that the veteran give VA
# everything he had that pertained to his claim.
#
#
# Sentence 62: 38 C.F.R.
# � 3.159(b)(1) (2005).
#
#
# Sentence 63: A complying notice, however, need not necessarily use the
# exact language of the regulation so long as that notice
# properly conveys to a claimant the essence of the regulation.
#
#
# Sentence 64: Mayfield v. Nicholson, 19 Vet. App. 103 (2005).
#
#
# Sentence 65: The RO asked
# the veteran for all the information and evidence necessary to
# substantiate his claim-that is, evidence of the type that
# should be considered by VA in assessing his claim.
#
#
# Sentence 66: Throughout the course of this appeal, the veteran has set
# forth his contentions and submitted pertinent medical
# evidence.
#
#
# Sentence 67: Therefore, it can be concluded, based on the
# particular facts and circumstances of the case, the omission
# of the request for "any evidence in the claimant's
# possession that pertains to the claim" in the notice did not
# harm the veteran, and it would be legally proper to render a
# decision in the case without further notice under the
# regulation.
#
#
# Sentence 68: Id.
#
#
# Sentence 69: In further regard to VA's duty to notify, the Board notes
# that the RO provided the veteran with a copy of the July 2003
#
#
# Sentence 70: rating decision and April 2004 SOC, which included a
# discussion of the facts of the claim, notification of the
# basis of the decision, and a summary of the evidence used to
# reach the decision.
#
#
# Sentence 71: The SOC provided the veteran with notice
# of all the laws and regulations pertinent to his claim,
# including the law and implementing regulations of the VCAA.
#
#
# Sentence 72: The Board notes that the schedule for rating spine
# disabilities was amended in August 2003, effective September
# 26, 2003.
#
#
# Sentence 73: Amendment to Part 4, Schedule for Rating
# Disabilities, 68 Fed.
#
#
# Sentence 74: Reg. 51454-51458 (August 27, 2003)
# (codified at 38 C.F.R. � 4.71a, Diagnostic Codes 5235, 5236,
# 5237, 5238, 5239, 5240, 5241, 5242, 5243 (2005)).
#
#
# Sentence 75: Prior to
# that, the rating criteria for evaluating intervertebral disc
# syndrome were changed, effective September 23, 2002.
#
#
# Sentence 76: Amendment to Part 4, Schedule for Rating Disabilities, 67
# Fed.
#
#
# Sentence 77: Reg.
#
#
# Sentence 78: 54345-54349 (August 22, 2002) (codified at 38
# C.F.R. � 4.71a, Diagnostic Code 5293 (2003)).
#
#
# Sentence 79: The new rating
# criteria for intervertebral disc syndrome were subsumed in
# the aforementioned amended rating schedule for spine
# disabilities.
#
#
# Sentence 80: When the regulations concerning entitlement to
# a higher rating are changed during the course of an appeal,
# the veteran is entitled to resolution of his or her claim
# under the criteria that are more to his or her advantage.
#
#
# Sentence 81: VAOPGCPREC 3-00.
#
#
# Sentence 82: The April 2004 SOC shows that the RO
# considered the veteran's low back disability under the
# applicable old and new diagnostic rating criteria.
#
#
# Sentence 83: In
# addition, the veteran was provided with notice of the
# applicable old and revised rating criteria.
#
#
# Sentence 84: The Board concludes that the requirements of the notice
# provisions of the VCAA have been met, and there is no
# outstanding duty to inform the veteran that any additional
# information or evidence is needed.
#
#
# Sentence 85: Quartuccio, 16 Vet. App.
#
#
# Sentence 86: at 187.
#
#
# Sentence 87: In regard to VA's duty to assist, the Board notes that in
# addition to the January 2004 VA examination, the RO had also
# afforded the veteran an examination in July 2003.
#
#
# Sentence 88: Lastly,
# the RO scheduled the veteran for a videoconference hearing,
# which was held in January 2006.
#
#
# Sentence 89: The veteran has not made the
# RO or the Board aware of any other evidence relevant to his
# appeal that needs to be obtained.
#
#
# Sentence 90: Based on the foregoing,
# the Board finds that all relevant facts have been properly
# and sufficiently developed in this appeal and no further
# development is required to comply with the duty to assist the
# veteran in developing the facts pertinent to his claim.
#
#
# Sentence 91: Accordingly, the Board will proceed with appellate review.
#
#
# Sentence 92: Procedural History and Evidence
#
# In a July 2003 rating decision, the RO awarded service
# connection for lumbosacral sprain with limitation of motion
# and assigned a 10 percent rating under Diagnostic Codes 5295-
# 5292, effective from April 4, 2003, the day following the
# veteran's discharge from service.
#
#
# Sentence 93: In the SOC, the RO
# recharacterized the issue as 'lumbosacral strain with lumbar
# disc disease' and continued the assigned disability rating.
#
#
# Sentence 94: The service medical records show that the veteran was
# followed for complaints of intermittent low back pain
# exacerbated with "work," lifting, and prolonged sitting,
# standing, and walking.
#
#
# Sentence 95: A March 2001 computerized tomography
# scan (CT) scan revealed spinal stenosis at L2 through L4,
# degenerative disc disease at L4-5 and L5-S1, and posterior
# facet degenerative joint disease affecting left L-4 and
# bilateral L-5 roots.
#
#
# Sentence 96: A March 2003 record noted an assessment
# of recurrent low back pain, possible bilateral mutated sacrum
# (posterior) versus left "ant" mutated "FRSR" lumbar at L5.
#
#
# Sentence 97:
#
#
# Sentence 98: The July 2003 VA examination report shows that the examiner
# reviewed the claims file.
#
#
# Sentence 99: The examiner related that the
# veteran complained of pain, discomfort, and decreased range
# of motion.
#
#
# Sentence 100: The physical examination revealed tenderness of
# L4 and L5.
#
#
# Sentence 101: On range of motion of the lumbar spine, flexion
# was 0 to 85 degrees, extension was 0 to 30 degrees, lateral
# bending to the left was 0 to 35 degrees, and lateral bending
# to the right was 0 to 30 degrees.
#
#
# Sentence 102: The examiner noted that
# the veteran had a slight decrease in lateral bending to the
# right
#
#
# Sentence 103: and that the veteran had good effort but pain and
# discomfort were noted of the lower back upon movement.
#
#
# Sentence 104: The
# examiner provided a diagnosis of lumbosacral sprain with mild
# decreased range of motion, pain, and discomfort.
#
#
# Sentence 105: The
# radiographic report noted an impression of narrowing of the
# L5-S1 intervertebral disk space.
#
#
# Sentence 106: VA treatment records dated in October 2003 showed an
# examination revealed mild tenderness over the lumbar spine
# and mild paraspinal spasm.
#
#
# Sentence 107: The examiner noted an assessment
# of chronic low back pain.
#
#
# Sentence 108: It was noted that the veteran was
# unemployed.
#
#
# Sentence 109: The examiner reported that he impressed on the
# veteran the importance of weight loss and how it might
# alleviate his back pain.
#
#
# Sentence 110: In an October 2003 letter, J.L., DC reported on clinical
# findings not centered on the veteran's service-connected low
# back disability.
#
#
# Sentence 111: The January 2004 VA examination report shows that the
# examiner reviewed the claims file.
#
#
# Sentence 112: The examiner noted that
# x-rays, a CT scan, and magnetic resonance imaging scans have
# revealed some disc degenerations at L4 and L5 with some
# protrusions, bulging, and some stenosis.
#
#
# Sentence 113: The veteran
# complained of problems associated with repetitive bending and
# lifting; he indicated that heavy bending, lifting, and work
# aggravated his back.
#
#
# Sentence 114: He complained of flare-ups once or
# twice a year during which time he had to spend time in bed
# for four or five days; other times he experienced only
# chronic backache.
#
#
# Sentence 115: He indicated that the pain went into his
# buttock area and legs or feet, but he denied that he
# experienced radicular pain.
#
#
# Sentence 116: During flare-ups, he used a back
# brace or cane to move around; otherwise, he could stand or
# walk all day long, but the problem was he could not do
# repetitive bending or lifting activities.
#
#
# Sentence 117: He maintained that
# he currently was not working because he could not perform
# heavy labor activities; he could perform normal daily
# activity and he had normal mobility.
#
#
# Sentence 118: The examiner observed that the veteran was not wearing a
# brace or using a cane at the exam.
#
#
# Sentence 119: The examiner indicated
# that there was no systemic symptoms or bladder or bowel
# dysfunction noted.
#
#
# Sentence 120: The examiner observed that the veteran
# could ambulate without aid or assistance and that he had a
# normal stance and gait.
#
#
# Sentence 121: The exam of the spine did not show
# any deformity; there was no increased kyphosis or scoliosis.
#
#
# Sentence 122:
#
#
# Sentence 123: He had some lumbosacral tenderness to palpation.
#
#
# Sentence 124: There were
# no muscle spasms.
#
#
# Sentence 125: He could forward flex 90 out of 90
# degrees, and extend and rotate 25 out of 30 degrees with pain
# at the extremes of motion.
#
#
# Sentence 126: There was no sciatica present.
#
#
# Sentence 127: He could rise up from his toes and heels.
#
#
# Sentence 128: Leg raise was
# negative in the seated position.
#
#
# Sentence 129: Reflexes were 1-2+ and
# equal at the knee and at the ankle.
#
#
# Sentence 130: He had normal strength
# and normal sensation in the lower extremities.
#
#
# Sentence 131: The examiner
# provided a diagnosis of lumbosacral strain with lumbar disc
# disease.
#
#
# Sentence 132: In the veteran's May 2004 Substantive Appeal, he additionally
# complained that he experienced occasional locking of the
# lower back.
#
#
# Sentence 133: At the January 2006 videoconference hearing, the veteran
# presented testimony on his symptoms that was similar to
# previously discussed complaints.
#
#
# Sentence 134: In addition, he denied ever
# having surgery or that a physician had recommended that
# surgery be performed.
#
#
# Sentence 135: He indicated that he was currently
# studying for purposes of finding employment.
#
#
# Sentence 136: He maintained
# that he experienced only one episode of pain that radiated
# down to his thigh.
#
#
# Sentence 137: He initially denied that he experienced
# numbness in his legs or tingling, but then added that he
# experienced shooting pain that radiated to his legs that he
# confirmed started as a result of his injury.
#
#
# Sentence 138: Analysis
#
# As previously noted, the veteran's low back disability is
# currently assigned a 10 percent rating under Diagnostic Codes
# 5295-5292 of the old schedule for rating spine disabilities.
#
#
# Sentence 139: The medical evidence shows that a mild paraspinal spasm was
# objectively demonstrated on examination in October 2003, but
# not reproduced at the January 2004 VA examination nor noted
# to be present at the July 2003 VA examination.
#
#
# Sentence 140: The July 2003
# VA examination revealed normal (defined below) range of
# motion on lateral bending to the left and right.
#
#
# Sentence 141: The Board
# finds that the evidence fails to show that the veteran's low
# back disability is primarily productive of muscle spasm on
# extreme forward bending with unilateral loss of lateral spine
# motion, the criteria associated with the next higher rating
# of 20 percent under Diagnostic Code 5295 of the old schedule.
#
#
# Sentence 142: As for Diagnostic Code 5292, 38 C.F.R. � 4.71a, Diagnostic
# Codes 5290 through 5292 (2003) of the old schedule rated
# limitation of motion of the spine according to whether it was
# slight, moderate, or severe.
#
#
# Sentence 143: The words "slight,"
# "moderate," and "severe" are not defined in the VA
# Schedule for Rating Disabilities.
#
#
# Sentence 144: Guidance can be obtained
# from the amended regulations.
#
#
# Sentence 145: The current definition of
# normal range of motion for the spine is based on medical
# guidelines in existence since 1984; therefore, the Board will
# apply the current ranges of motion to rating spine
# disabilities under the old criteria.
#
#
# Sentence 146: Normal forward flexion
# of the thoracolumbar spine is zero to 90 degrees, extension
# is zero to 30 degrees, left and right lateral flexion are
# zero to 30 degrees, and left and right lateral rotation are
# zero to 30 degrees.
#
#
# Sentence 147: 38 C.F.R. � 4.71a, General Rating
# Formula for Diseases and Injuries of the Spine, Note (2)
# (2005).
#
#
# Sentence 148: Under Diagnostic Code 5292, a 20 percent rating is assigned
# for moderate limitation of motion of the lumbar spine, and a
# 40 percent rating is assigned for severe limitation of
# motion.
#
#
# Sentence 149: 38 C.F.R. � 4.71a, Diagnostic Code 5292 (2003).
#
#
# Sentence 150: A slight loss of motion on flexion, extension, and rotation
# was demonstrated at the July 2003 and January 2004 VA
#
#
# Sentence 151: examinations.
#
#
# Sentence 152: Thus, the veteran's low back disability is not
# productive of moderate limitation of motion of the lumbar
# spine.
#
#
# Sentence 153: The Board, however, notes that the veteran primarily
# complains of pain and fatigue with repetitive motion
# resulting in decreased motion.
#
#
# Sentence 154: His current complaints are
# similar to complaints well documented in the service medical
# records.
#
#
# Sentence 155: In determining the degree of limitation of motion,
# the provisions of 38 C.F.R. �� 4.10, 4.40, and 4.45 are for
# consideration.
#
#
# Sentence 156: DeLuca v. Brown, 8 Vet. App.
#
#
# Sentence 157: 202 (1995).
#
#
# Sentence 158: The
# factors involved in evaluating and rating disabilities of the
# joints include, weakness, fatigability, incoordination,
# restricted or excess movement of the joint, or pain on
# movement.
#
#
# Sentence 159: 38 C.F.R. � 4.45 (2005).
#
#
# Sentence 160: The Board resolves
# reasonable doubt in favor of the veteran that with pain and
# repetitive motion of his lower back, it is more moderately
# disabling, such that a 20 percent rating under Diagnostic
# Code 5292 of the old schedule is appropriate.
#
#
# Sentence 161: 38 C.F.R.
# �� 3.102, 4.7 (2005).
#
#
# Sentence 162: The veteran, however, is not entitled
# to the next higher rating of 40 percent as the medical
# evidence does not show severe limitation of motion or severe
# impairment associated with the back disability.
#
#
# Sentence 163: The Board is required to consider other diagnostic codes
# under the old schedule to determine whether the veteran is
# entitled to a rating in excess of 20 percent under any of
# them.
#
#
# Sentence 164: The medical evidence shows that there is no x-ray evidence of
# residuals of a fracture of the vertebra attributable to the
# service-connected low back disability.
#
#
# Sentence 165: The medical evidence
# also shows that the veteran does not have ankylosis of the
# lumbar spine.
#
#
# Sentence 166: Service connection is in effect for
# degenerative disc disease of the lumbar spine, but the
# medical evidence shows that the disc disease does not
# currently manifest any separately ratable compensable
# neurologic deficits.
#
#
# Sentence 167: Thus, the veteran is precluded from an
# evaluation under Diagnostic Codes 5285 and 5289 of the old
# schedule and Diagnostic Code 8520.
#
#
# Sentence 168: 38 C.F.R. � 4.71a,
# Diagnostic Codes 5285, 5289 (2003); 38 C.F.R. � 4.124a,
# Diagnostic Code 8520 (2005).
#
#
# Sentence 169: Accordingly, the Board concludes that the veteran is entitled
# to a higher initial rating of 20 percent, but not higher, for
# service-connected lumbosacral strain with lumbar disc disease
# under the old schedule for rating spine disabilities.
#
#
# Sentence 170: The Board now considers the veteran's service-connected low
# back disability under the schedule for rating spine
# disabilities as amended in August 2003, effective September
# 26, 2003.
#
#
# Sentence 171: Under the amended schedule, any associated
# objective neurologic abnormalities, including, but not
# limited to bowel or bladder impairment are to be evaluated
# separately under an appropriate diagnostic code.
#
#
# Sentence 172: 38 C.F.R.
# � 4.71a, General Rating Formula, Note 1 (2005).
#
#
# Sentence 173: Intervertebral disc syndrome is to be evaluated either under
# the General Rating Formula for Diseases and Injuries of the
# Spine or under the Formula for Rating Intervertebral Disc
# Syndrome Based on Incapacitating Episodes, whichever method
# results in the higher evaluation when all disabilities are
# combined under � 4.25.
#
#
# Sentence 174: Under the General Rating Formula for Diseases and Injuries of
# the Spine, with or without symptoms such as pain (whether or
# not it radiates), stiffness, or aching in the area of the
# spine affected by residuals of injury or disease, a 10
# percent rating is assigned for forward flexion of the
# thoracolumbar spine greater than 60 degrees but not greater
# than 85 degrees; or, combined range of motion of the
# thoracolumbar spine greater than 120 degrees but not greater
# than 235 degrees; or, muscle spasm, guarding, or localized
# tenderness not resulting in abnormal gait or abnormal spinal
# contour; or, vertebral body fracture with loss of 50 percent
# or more of the height.
#
#
# Sentence 175: 38 C.F.R. � 4.71a (2005).
#
#
# Sentence 176: A 20
# percent rating is assigned for forward flexion of the
# thoracolumbar spine greater than 30 degrees but not greater
# than 60 degrees; or, the combined range of motion of the
# thoracolumbar spine not greater than 120 degrees; or, muscle
# spasm or guarding severe enough to result in an abnormal gait
# or abnormal spinal contour such as scoliosis, reversed
# lordosis, or abnormal kyphosis.
#
#
# Sentence 177: Id.  A 40 percent rating is
# assigned for forward flexion of the thoracolumbar spine 30
# degrees or less; or, favorable ankylosis of the entire
# thoracolumbar spine.
#
#
# Sentence 178: Id.  A 50 percent rating is assigned
# for unfavorable ankylosis of the entire thoracolumbar spine.
#
#
# Sentence 179: Id.  A 100 percent rating is assigned for unfavorable
# ankylosis of the entire spine.
#
#
# Sentence 180: Id.
#
# The medical evidence shows that the veteran's low back
# disability is only productive of the criteria associated with
# a 10 percent rating for forward flexion to 85 degrees or
# more.
#
#
# Sentence 181: Therefore, the veteran is only entitled to a 10
# percent rating under the amended schedule for rating spine
# disabilities with respect to the orthopedic manifestations of
# the low back disability.
#
#
# Sentence 182: As for neurologic manifestations associated with the low back
# disability, the Board previously noted that the medical
# evidence shows that the disc disease of the lumbar spine does
# not currently manifest any separately ratable compensable
# neurologic deficits such that an evaluation under Diagnostic
# Code 8520 would be appropriate.
#
#
# Sentence 183: As for the Formula for Rating Intervertebral Disc Syndrome
# Based on Incapacitating Episodes, it would not be to the
# veteran's advantage for his disability to be evaluated there
# under.
#
#
# Sentence 184: There is no documented evidence that a physician
# prescribed the veteran bed rest and treatment for a certain
# duration of time at any time during the appeal period.
#
#
# Sentence 185: Moreover, even by the veteran's own description at the
# January 2004 VA examination, he does not experience
# incapacitating episodes having a total duration of at least 2
# weeks over the course of 12 months, which is the minimum
# criterion associated with a 20 percent rating under the
# formula.
#
#
# Sentence 186: Thus, evaluation of the veteran's low back
# disability on the basis of the total duration of
# incapacitating episodes over the course of 12 months would
# not be to his advantage.
#
#
# Sentence 187: The Board concludes that as between the old schedule for
# rating spine disabilities and the amended schedule for rating
# spine disabilities, evaluation of the veteran's low back
# disability under the old schedule results in a higher rating
# of 20 percent, and therefore, he is entitled to resolution of
# his claim there under.
#
#
# Sentence 188:
#
#
# Sentence 189: The veteran's low back disability has not been shown to be
# manifested by greater than the criteria associated with a 20
# percent rating during any portion of the appeal period.
#
#
# Sentence 190: Accordingly, a staged rating is not in order and a 20 percent
# rating is appropriate for the entire period of the veteran's
# appeal.
#
#
# Sentence 191: Fenderson v. West, 12 Vet. App.
#
#
# Sentence 192: 119 (1999).
#
#
# Sentence 193: An increased rating may also be granted on an extraschedular
# basis when it is demonstrated that the particular disability
# presents such an exceptional or unusual disability picture
# with such related factors as marked interference with
# employment or frequent periods of hospitalization as to
# render impractical the application of the regular schedular
# standards.
#
#
# Sentence 194: 38 C.F.R. � 3.321(b)(1) (2005).
#
#
# Sentence 195: The Board finds
# no evidence that the veteran's low back disability presented
# such an unusual or exceptional disability picture at any time
# so as to require consideration of an extraschedular
# evaluation pursuant to the provisions of 38 C.F.R. �
# 3.321(b)(1).
#
#
# Sentence 196: The veteran contends that he is precluded from certain types
# of employment involving heavy labor, but he also indicated
# that he was currently studying to enable him to find other
# types of employment-presumably, less labor intensive work or
# sedentary work.
#
#
# Sentence 197: More significantly, the veteran's contention
# is at odds with the objective medical evidence of record that
# shows that manifestations of his low back disability do not
# result in a marked functional impairment in a way or to a
# degree other than that addressed by VA's Rating Schedule.
#
#
# Sentence 198:
#
#
# Sentence 199: The schedular rating criteria are designed to compensate for
# average impairments in earning capacity resulting from
# service-connected disability in civil occupations.
#
#
# Sentence 200: 38
# U.S.C.A. � 1155 (West 2002).
#
#
# Sentence 201: Generally, the degrees of
# disability specified in the rating schedule are considered
# adequate to compensate for considerable loss of working time
# from exacerbations or illnesses proportionate to the severity
# of the several grades of disability.
#
#
# Sentence 202: 38 C.F.R. � 4.1 (2005).
#
#
# Sentence 203:
#
#
# Sentence 204: Consequently, the Board concludes that referral of this case
# for consideration of an extraschedular rating is not
# warranted.
#
#
# Sentence 205: Bagwell v. Brown, 9 Vet. App.
#
#
# Sentence 206: 337, 338-39 (1996);
# Floyd v. Brown, 9 Vet. App. 88, 96 (1996).
#
#
# Sentence 207:
#
#
# Sentence 208: ORDER
#
#
# Sentence 209: A higher initial rating of 20 percent for service-connected
# lumbosacral strain with lumbar disc disease is granted,
# subject to the law and regulations controlling the award of
# monetary benefits.
#
#
# Sentence 210: ____________________________________________
# John E. Ormond, Jr.
#
#
# Sentence 211: Veterans Law Judge, Board of Veterans' Appeals
#
#
#
#
#  Department of Veterans Affairs

# %% [markdown]
# ### Error analysis on an individual level

# %%
doc_id = '61aea55c97ad59b4cfc412af'

# %% [markdown]
# ##### Standard Spacy

# %%
# Test for a single document
nlp = spacy.load("en_core_web_sm")
gen_ann_span_standard = generate_ann_span_by_doc_with_spacy([doc_id], nlp)
len(gen_ann_span_standard[doc_id]['start'])
# gen_ann_span_standard

# For the standard spacy
closest_by_id_std = find_closest_start_point(
    [doc_id], 
    true_ann_span_by_doc, 
    gen_ann_span_standard
)


# For the standard spacy
print(f"Error analysis for the document {doc_id} with standard segmenter")
print("----------------------------------------------------------------------------------")
precision, recall, f1_score = calculate_error_metrics(
    [doc_id], 
    true_ann_span_by_doc, 
    gen_ann_span_standard, 
    closest_by_id_std
)

print(f'\nPrecision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')
# Out:
# Error analysis for the document 61aea55c97ad59b4cfc412af with standard segmenter
# ----------------------------------------------------------------------------------
#
# Precision: 0.62
# Recall: 0.56
# F1_score: 0.59

# %% [markdown]
# ##### Extended Spacy

# %%
# Test for a single document
nlp = spacy.load("en_core_web_sm")
# nlp.add_pipe("set_custom_boundaries_original", before="parser")
nlp.add_pipe("set_custom_boundaries", before="parser")
nlp.tokenizer.add_special_case('Vet. App.', [{ORTH: 'Vet. App.'}])
nlp.tokenizer.add_special_case('Fed. Cir.', [{ORTH: 'Fed. Cir.'}])

gen_ann_span_ext = generate_ann_span_by_doc_with_spacy([doc_id], nlp)
len(gen_ann_span_ext[doc_id]['start'])
# gen_ann_span_ext

# For the extended spacy
closest_by_id_ext = find_closest_start_point(
    [doc_id], 
    true_ann_span_by_doc, 
    gen_ann_span_ext
)


# For the extended spacy
print(f"Error analysis for the document {doc_id} with extended segmenter")
print("----------------------------------------------------------------------------------")
precision, recall, f1_score = calculate_error_metrics(
    [doc_id], 
    true_ann_span_by_doc, 
    gen_ann_span_ext, 
    closest_by_id_ext
)

print(f'\nPrecision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')
# Out:
# Error analysis for the document 61aea55c97ad59b4cfc412af with extended segmenter
# ----------------------------------------------------------------------------------
#
# Precision: 0.74
# Recall: 0.78
# F1_score: 0.76

# %% [markdown]
# ##### LUIMA SBD

# %%
gen_ann_span_luima = generate_ann_span_by_doc_with_luima([doc_id])
len(gen_ann_span_luima[doc_id]['start'])
# gen_ann_span_ext

# For the LUIMA
closest_by_id_luima = find_closest_start_point(
    [doc_id], 
    true_ann_span_by_doc, 
    gen_ann_span_luima
)


# For the LUIMA

print(f"Error analysis for the document {doc_id} with LUIMA segmenter")
print("----------------------------------------------------------------------------------")

precision, recall, f1_score = calculate_error_metrics(
    [doc_id], 
    true_ann_span_by_doc, 
    gen_ann_span_luima, 
    closest_by_id_luima
)

print(f'\nPrecision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')
# Out:
# Error analysis for the document 61aea55c97ad59b4cfc412af with LUIMA segmenter
# ----------------------------------------------------------------------------------
#
# Precision: 0.83
# Recall: 0.98
# F1_score: 0.90

# %% [markdown]
# ### Overall error metric analysis

# %% [markdown]
# ##### Error analysis for the standard segmenter

# %%
# Test for a single document
nlp = spacy.load("en_core_web_sm")
print("Splitting the documents")
gen_ann_span_standard = generate_ann_span_by_doc_with_spacy(train_doc_ids, nlp)


# Find closest neighbors
closest_by_id_std = find_closest_start_point(
    train_doc_ids, 
    true_ann_span_by_doc, 
    gen_ann_span_standard
)


# Error metrics
precision, recall, f1_score = calculate_error_metrics(
    train_doc_ids, 
    true_ann_span_by_doc, 
    gen_ann_span_standard, 
    closest_by_id_std
)
print("Error metrics using the standard segmenter:")
print(f'Precision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')
# Out:
# Splitting the documents
# Error metrics using the standard segmenter:
# Precision: 0.60
# Recall: 0.62
# F1_score: 0.61

# %% [markdown]
# ##### Error analysis for the extended segmenter

# %%
# Test for a single document
nlp = spacy.load("en_core_web_sm")
# nlp.add_pipe("set_custom_boundaries_original", before="parser")
nlp.add_pipe("set_custom_boundaries", before="parser")
nlp.tokenizer.add_special_case('Vet. App.', [{ORTH: 'Vet. App.'}])
nlp.tokenizer.add_special_case('Fed. Cir.', [{ORTH: 'Fed. Cir.'}])

print("Splitting the documents")
gen_ann_span_ext = generate_ann_span_by_doc_with_spacy(train_doc_ids, nlp)

# Find closest neighbors
closest_by_id_ext = find_closest_start_point(
    train_doc_ids, 
    true_ann_span_by_doc, 
    gen_ann_span_ext
)

# Error metrics
precision, recall, f1_score = calculate_error_metrics(
    train_doc_ids, 
    true_ann_span_by_doc, 
    gen_ann_span_ext, 
    closest_by_id_ext
)
print("Error metrics using the extended segmenter:")
print(f'Precision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')
# Out:
# Splitting the documents
# Error metrics using the extended segmenter:
# Precision: 0.71
# Recall: 0.77
# F1_score: 0.74

# %% [markdown]
# ##### Error analysis for the LUIMA segmenter

# %%
print("Splitting the documents")
gen_ann_span_luima = generate_ann_span_by_doc_with_luima(train_doc_ids)

# Find closest neighbors
closest_by_id_luima = find_closest_start_point(
    train_doc_ids, 
    true_ann_span_by_doc, 
    gen_ann_span_luima
)

# Error metrics
precision, recall, f1_score = calculate_error_metrics(
    train_doc_ids, 
    true_ann_span_by_doc, 
    gen_ann_span_luima, 
    closest_by_id_luima
)
print("Error metrics using the LUIMA SBD segmenter:")
print(f'Precision: {precision:.2f}\nRecall: {recall:.2f}\nF1_score: {f1_score:.2f}')
# Out:
# Splitting the documents
# Error metrics using the LUIMA SBD segmenter:
# Precision: 0.83
# Recall: 0.99
# F1_score: 0.90

# %% [markdown]
# ### Save the error metrics for all the documents

# %% [markdown]
# ##### Standard Spacy

# %%
nlp = spacy.load("en_core_web_sm")
error_metric_std_segmenter = []
for doc_id in tqdm(train_doc_ids):
    gen_ann_span_standard = generate_ann_span_by_doc_with_spacy([doc_id], nlp)
    # gen_ann_span_standard

    # For the standard spacy
    closest_by_id_std = find_closest_start_point(
        [doc_id], 
        true_ann_span_by_doc, 
        gen_ann_span_standard
    )

    precision, recall, f1_score = calculate_error_metrics(
        [doc_id], 
        true_ann_span_by_doc, 
        gen_ann_span_standard, 
        closest_by_id_std
    )
    
    em_doc = {
        'doc_id': doc_id,
        'precision': round(precision, 2),
        'recall': round(recall, 2),
        'f1_score': round(f1_score, 2)
    }
    error_metric_std_segmenter.append(em_doc)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 113/113 [00:52<00:00,  2.15it/s]

# %% [markdown]
# ##### Extended Spacy

# %%
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("set_custom_boundaries", before="parser")
nlp.tokenizer.add_special_case('Vet. App.', [{ORTH: 'Vet. App.'}])
nlp.tokenizer.add_special_case('Fed. Cir.', [{ORTH: 'Fed. Cir.'}])

error_metric_ext_segmenter = []
for doc_id in tqdm(train_doc_ids):
    gen_ann_span_ext = generate_ann_span_by_doc_with_spacy([doc_id], nlp)
    # gen_ann_span_standard

    # For the standard spacy
    closest_by_id_ext = find_closest_start_point(
        [doc_id], 
        true_ann_span_by_doc, 
        gen_ann_span_ext
    )

    precision, recall, f1_score = calculate_error_metrics(
        [doc_id], 
        true_ann_span_by_doc, 
        gen_ann_span_ext, 
        closest_by_id_ext
    )
    
    em_doc = {
        'doc_id': doc_id,
        'precision': round(precision, 2),
        'recall': round(recall, 2),
        'f1_score': round(f1_score, 2)
    }
    error_metric_ext_segmenter.append(em_doc)

# %% [markdown]
# ##### LUIMA SBD

# %%
error_metric_luima = []
for doc_id in tqdm(train_doc_ids):
    gen_ann_span_luima = generate_ann_span_by_doc_with_luima([doc_id])
    closest_by_id_luima = find_closest_start_point(
        [doc_id], 
        true_ann_span_by_doc, 
        gen_ann_span_luima
    )


    precision, recall, f1_score = calculate_error_metrics(
        [doc_id], 
        true_ann_span_by_doc, 
        gen_ann_span_luima, 
        closest_by_id_luima
    )
    
    em_doc = {
        'doc_id': doc_id,
        'precision': round(precision, 2),
        'recall': round(recall, 2),
        'f1_score': round(f1_score, 2)
    }
    error_metric_luima.append(em_doc)

# %%
error_metric_std_segmenter[0], error_metric_ext_segmenter[0], error_metric_luima[0]

# %%
df_std = pd.DataFrame(error_metric_std_segmenter)
df_ext = pd.DataFrame(error_metric_ext_segmenter)
df_lumia = pd.DataFrame(error_metric_luima)

# %%
df_std.sort_values('precision').head()

# %%
df_ext[df_ext['doc_id']=='61aea55e97ad59b4cfc412de'], \
df_ext[df_ext['doc_id']=='61aea55e97ad59b4cfc412f0'], \
df_ext[df_ext['doc_id']=='61aea55c97ad59b4cfc41299']

# %%
df_ext.iloc[17]

# %% [markdown]
# #### General observations:
# 1. Spacy segments a sentence whenever it comes across a fullstop. e.g:
# ##### Original sentence:
# Sentence 1: Citation Nr: 0721357
# Decision Date: 07/17/07    Archive Date: 08/02/07
#
# DOCKET NO.  05-13 724	)	DATE
# 	)
# 	)
# ##### Spacy segmented sentence:
# Sentence 1: Citation Nr: 0721357
# Decision Date: 07/17/07    Archive Date: 08/02/07
#
# DOCKET NO.
#
# 2. Citations are being broken down into sentences too many times
#
# #### Things to improve
# 1. not only splitting sentence on fullstop, but also for other occurances such as new lines.
# 2. Different section headers should be considered as a separate sentence.

# %% [markdown]
# REPRESENTATION
#
# ATTORNEY FOR THE BOARD
#
# **INTRODUCTION **
#
# FINDING OF FACT
#
# FINDINGS OF FACT
#
# CONCLUSION OF LAW
#
# REASONS AND BASES FOR FINDING AND CONCLUSION
#
# REASONS AND BASES FOR FINDINGS AND CONCLUSION
#
# ORDER

# %%
example_basic_1 = 'In sum, as the preponderance of the evidence is against the Veteran\'s claim, his appeal must be denied.'
example_cit_1 = 'Smith v. Gober, 14 Vet. App. 227 (2000), aff\'d 281 F.3d 1384 (Fed. Cir. 2002); Dela Cruz v. Principi, 15 Vet. App. 143 (2001); see also Quartuccio v. Principi, 16 Vet. App. 183 (2002).'
example_rule_1 = '"To establish a right to compensation for a present disability, a Veteran must show: "(1) the existence of a present disability; (2) in-service incurrence or aggravation of a disease or injury; and (3) a causal relationship between the present disability and the disease or injury incurred or aggravated during service"-the so-called "nexus" requirement."'
example_mixed_1 = 'In Dingess v. Nicholson, 19 Vet. App. 473 (2006), the U.S. Court of Appeals for Veterans Claims held that, upon receipt of an application for a service-connection claim, 38 U.S.C.A. � 5103(a) and 38 C.F.R. � 3.159(b) require VA to provide the claimant with notice that a disability rating and an effective date for the award of benefits will be assigned if service connection is awarded. '

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(example_cit_1)
for token in doc:
    print(token)

# %%
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("set_custom_boundaries", before="parser")
nlp.tokenizer.add_special_case('Vet. App.', [{ORTH: 'Vet. App.'}])
nlp.tokenizer.add_special_case('Fed. Cir.', [{ORTH: 'Fed. Cir.'}])
doc = nlp(example_cit_1)
list(doc.sents)
