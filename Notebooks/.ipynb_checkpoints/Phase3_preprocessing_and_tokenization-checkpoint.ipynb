# %%
import sys
sys.path.append(r"C:\Users\siyam\Desktop\Legal DS\project\venv\Lib\site-packages")
import os
from pathlib import Path
import json
import random
import numpy as np
import spacy


from tqdm import tqdm
import spacy
import json
import random
import re
import pandas as pd
import numpy as np
from copy import deepcopy
from sklearn import model_selection
from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
from spacy.symbols import ORTH
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import tree
import matplotlib.pyplot as plt
from spacy.language import Language
from luima_sbd import sbd_utils as luima
import seaborn as sns
import plotly.express as px
import math
# %matplotlib inline

# %% [markdown]
# # Phase 3.1: Splitting the unlabeled data

# %%
UNLABELED_DATA_PATH = Path("../Data/ldsi_w2021-20220221T223611Z-001/ldsi_w2021/unlabeled/unlabeled")
unlabeled_corpus = sorted(os.listdir(UNLABELED_DATA_PATH))
len(unlabeled_corpus)
# Out:
# 30000

# %%
test_file = open(UNLABELED_DATA_PATH/ Path('0603946.txt'), 'r').read().encode('latin-1', 'ignore')
test_file = test_file.decode('latin-1').strip()
len(luima.text2sentences(test_file, offsets=False))
# Out:
# 134

# %%
test_file = open(UNLABELED_DATA_PATH/ Path('0603946.txt'), 'r').read()
arr = bytes(test_file, 'utf-8')
arr = arr.decode('latin-1').strip()
len(luima.text2sentences(arr, offsets=False))
# Out:
# 135

# %%
def info(title):
    print(title)
    print('module name:', __name__)
    print('parent process:', os.getppid())
    print('process id:', os.getpid())

# %%
# unlab_segments_by_doc = []
# for file in tqdm(unlabeled_corpus[0:100]):
#     text = open(UNLABELED_DATA_PATH/file).read()
#     byte_text = bytes(text, 'utf-8')
#     text = byte_text.decode('latin-1').strip()
    
#     doc = luima.text2sentences(text, offsets=False)
    
#     seg_data = {
#         'doc_name': file,
#         'no_of_sentences': len(doc),
#         'sentences': doc
#     }
#     unlab_segments_by_doc.append(seg_data)

# import pickle
# with open(Path('../Data/')/'unlab_segments_by_doc', 'wb') as handle:
#     pickle.dump(unlab_segments_by_doc, handle)

# total_sentences = 0
# for seg in unlab_segments_by_doc:
#     total_sentences += seg['no_of_sentences']

# %%
# from multiprocessing import Process
# from multiprocessing import Pool
# import os
# import utils
# from time import perf_counter

# %%
# if __name__ == '__main__':
#     start = perf_counter()
#     with Pool(5) as p:
# #         print(p.map(f, [1, 2, 3]))
#         p.map(utils.segment_unlabeled_corpus, unlabeled_corpus[0:5])
#     end = perf_counter()
#     print(f"time needed for 5 files: {end-start} seconds")

# %%
import pickle
with open(Path('../Data/')/'unlab_segments_by_doc', 'rb') as handle:
    unlab_segments_by_doc = pickle.load(handle)

# %%
unlab_segments_by_doc[0]
# Out:
# {'doc_name': '0600090.txt',
#  'no_of_sentences': 127,
#  'sentences': ['Citation Nr: 0600090',
#   'Decision Date: 01/04/06',
#   'Archive Date: 01/19/06',
#   'DOCKET NO.  04-33 853',
#   'DATE',
#   'On appeal from the\nDepartment of Veterans Affairs (VA) Regional Office (RO) in \nTogus, Maine',
#   'THE ISSUE',
#   'Entitlement to service connection for post-traumatic stress \ndisorder (PTSD).',
#   'REPRESENTATION',
#   "Appellant represented by:\tMaine Veterans' Services",
#   'WITNESS AT HEARING ON APPEAL',
#   'Appellant',
#   'ATTORNEY FOR THE BOARD',
#   'C. L. Wasser, Counsel',
#   'INTRODUCTION',
#   'The veteran served on active duty from October 1969 to May \n1972.',
#   "This case comes to the Board of Veterans' Appeals (Board) on \nappeal from a March 2004 decision by the RO in Togus, Maine \nthat denied service connection for PTSD.",
#   'A personal hearing \nwas held before an RO hearing officer in June 2004.',
#   'A \nvideoconference hearing was held before the undersigned ',
#   'Veterans Law Judge in October 2005.',
#   'The veteran submitted additional pertinent evidence to the ',
#   'Board in October 2005.',
#   'As the veteran has waived RO review \nof this evidence, the Board will consider it.',
#   '38 C.F.R. ',
#   'Â§ 20.1304(c) (2005).',
#   'FINDINGS OF FACT',
#   'During service the veteran did not engage in combat with the \nenemy, and it is not shown by credible supporting evidence \nthat a stressor, which might lead to PTSD, occurred during \nservice.',
#   'CONCLUSION OF LAW',
#   'PTSD was not incurred in or aggravated by active service.',
#   '38',
#   'U.S.C.A. Â§ 1110 (West 2002); 38 C.F.R. Â§Â§ 3.303, 3.304 \n(2005).',
#   'REASONS AND BASES FOR FINDINGS AND CONCLUSION',
#   'VCAA',
#   'The Veterans Claims Assistance Act of 2000 (VCAA), Pub. L. ',
#   "No. 106-475, 114 Stat. 2096 (Nov. 9, 2000) (codified at \n38 U.S.C.A. Â§Â§ 5100, 5102, 5103, 5103A, 5106, 5107, and 5126 \n(West 2002) redefined VA's duty to assist the veteran in the \ndevelopment of a claim.",
#   'VA regulations for the \nimplementation of the VCAA were codified as amended at \n38 C.F.R. Â§Â§ 3.102, 3.156(a), 3.159, and 3.326(a) (2005).',
#   'The notice requirements of the VCAA require VA to notify the \nveteran of any evidence that is necessary to substantiate his \nclaim, as well as the evidence VA will attempt to obtain and \nwhich evidence he is responsible for providing.',
#   'Quartuccio \nv. Principi, 16 Vet. App. 183 (2002).',
#   'In Pelegrini v. Principi, 18 Vet. App. 112 (2004), the United \nStates Court of Appeals for Veterans Claims (hereinafter, \n"the Court") held, in part, that a VCAA notice, as required \nby 38 U.S.C.A. Â§ 5103(a), must be provided to a claimant \nbefore the initial unfavorable decision on a claim for VA \nbenefits by the agency of original jurisdiction (in this \ncase, the RO).',
#   'The Court also held, however, that providing \nthe VCAA notice to the claimant after the initial decision \ncould satisfy the requirements of the VCAA if the timing of \nthe notice was not prejudicial to the claimant.',
#   'Pelegrini, \n18 Vet. App. at 121.',
#   'As will be discussed below, the VCAA provisions have been \nconsidered and complied with.',
#   'There is no indication that \nthere is additional evidence to obtain, there is no \nadditional notice that should be provided, and there has been \na complete review of all the evidence without prejudice to \nthe appellant.',
#   'As such, there is no indication that there is \nany prejudice to the appellant by the order of the events in \nthis case.',
#   'See Mayfield v. Nicholson, 19 Vet. App. 103 \n(2005); Bernard v. Brown, 4 Vet. App. 384 (1993).',
#   'Any error \nin the sequence of events is not shown to have any effect on \nthe case or to cause injury to the claimant.',
#   'Consequently, \nthe Board concludes that any such error is harmless and does \nnot prohibit consideration of this matter on the merits.',
#   'See \nMayfield, supra; ATD Corp. v. Lydall, Inc., 159 F.3d 534, 549 \n(Fed. Cir. 1998).',
#   'In this case, in letters dated in September 2002, January \n2003, and October 2003, the RO provided notice to the veteran \nregarding what information and evidence is needed to \nsubstantiate the claim for service connection, as well as \nwhat information and evidence must be submitted by the \nveteran, what information and evidence will be obtained by \nVA, and the need for the veteran to advise VA of or submit \nany further evidence that pertains to the claim.',
#   'The veteran and his representative were also provided with a \ncopy of the appealed rating decision, as well as an August \n2004 Statement of the Case (SOC).',
#   'These documents provided \nthem with notice of the law and governing regulations, as \nwell as the reasons for the determinations made regarding his \nclaim.',
#   "By way of these documents, they also were \nspecifically informed of the cumulative evidence already \nhaving been previously provided to VA or obtained by VA on \nthe veteran's behalf.",
#   'Additionally, the SOC included a \nsummary of the relevant VCAA regulatory provisions of \n38 C.F.R. Â§ 3.159.',
#   'Therefore, the Board finds that the \nveteran was notified and aware of the evidence needed to \nsubstantiate this claim, the avenues through which he might \nobtain such evidence, and the allocation of responsibilities \nbetween himself and VA in obtaining such evidence.',
#   'Accordingly, there is no further duty to notify, and no \nprejudice to the veteran exists by deciding the claim.',
#   'The record also reflects that VA has made reasonable efforts \nto obtain relevant records adequately identified by the \nveteran.',
#   "Specifically, the information and evidence that \nhave been associated with the claims file includes the \nveteran's service medical records, service personnel records, \nand post-service medical records and examination reports.",
#   'Under the circumstances in this case, the veteran has \nreceived the notice and assistance contemplated by law and \nadjudication of the claim poses no risk of prejudice to the \nveteran.',
#   "See Mayfield, supra; Smith v. Gober, 14 Vet. App. \n227 (2000), aff'd 281 F.3d 1384 (Fed. Cir. 2002); Dela Cruz \nv. Principi, 15 Vet. App. 143 (2001) (VCAA does not require \nremand where VA thoroughly discussed factual determinations \nleading to conclusion and evidence of record provides \nplausible basis for factual conclusions, and where \ndevelopment of the evidence was as complete as was necessary \nfor a fair adjudication of the claims).",
#   'Law and Regulations',
#   'Service connection may be granted for disability resulting \nfrom disease or injury incurred in or aggravated by active \nservice.',
#   '38 U.S.C.A. Â§ 1110; 38 C.F.R. Â§ 3.303.',
#   'Service connection for PTSD requires medical evidence \ndiagnosing the condition \nin accordance with 38 C.F.R. Â§ 4.125(a) [i.e., under the \ncriteria of Diagnostic and Statistical Manual of Mental ',
#   "Disorders, Fourth Edition (DSM-IV)]; a link, established by \nmedical evidence, between the veteran's current symptoms and \nan \nin-service stressor; and credible supporting evidence that \nthe claimed in-service stressor occurred.",
#   "If a PTSD claim is \nbased on in-service personal assault, evidence from sources \nother than the veteran's service records may corroborate the \nveteran's account of the stressor incident.",
#   '38 C.F.R. Â§ \n3.304(f).',
#   'Analysis',
#   "The Board has reviewed all the evidence in the appellant's \nclaims file, which includes:  his contentions, including \nthose raised at June 2004 and October 2005 VA hearings; \nservice medical and personnel records; VA medical records; \nmedical records from a Vet Center; a private psychological \nevaluation; information from Fort Belvoir; and information \nfrom the National Personnel Records Center.",
#   'Although the ',
#   'Board has an obligation to provide adequate reasons and bases \nsupporting this decision, there is no requirement that the \nevidence submitted by the appellant or obtained on his behalf \nbe discussed in detail.',
#   "Rather, the Board's analysis below \nwill focus specifically on what evidence is needed to \nsubstantiate the claim and what the evidence in the claims \nfile shows, or fails to show, with respect to the claim.",
#   'See \nGonzales v. West, 218 F.3d 1378, 1380-81 (Fed. Cir. 2000) and ',
#   'Timberlake v. Gober, 14 Vet. App. 122, 128-30 (2000).',
#   'The veteran contends that he has PTSD due to a personal \nassault which occurred approximately between January and ',
#   'March 1970 while he was stationed at Fort Belvoir, Virginia.',
#   'He asserts that the incident involved both sexual and \nphysical assault, and that he does not know the name of the \nperpetrator, who was a cook at Fort Belvoir.',
#   'By a January \n2003 written statement and in subsequent testimony, he said \nthat during the attack, he was very drunk, and the \nperpetrator punched him in the mouth, and a tooth was \nloosened, cracked, or broken as a result.',
#   'He said that he \nwas later found by a soldier on guard duty, and was taken by \nmilitary police to receive medical treatment.',
#   'He later \nreceived counseling from a mental health professional, whom \nhe only told about the physical aspects of the assault.',
#   'The \ndoctor told him he would try to obtain a general discharge \nfor the veteran, but this did not occur.',
#   'After this \nincident, he went to his electronics school, and despite \nfailing this course, he was posted to Germany, where he \nremained for the remainder of his active duty service.',
#   'He \nstated that he began to drink heavily after this incident.',
#   'He said that the first time he ever told anyone about the \nsexual aspect of the assault was at his November 2002 VA \nexamination.',
#   "A review of the veteran's service medical records reflects \nthat in early January 1970, the veteran was brought to the \nemergency room at DeWitt Army Hospital at Fort Belvoir by \nmilitary police, who reported that the veteran was \nthreatening to kill somebody, and did not want to be around \nthe people in his barracks because he did not like them.",
#   'He \ndenied drinking and using drugs.',
#   'This treatment note does \nnot identify any trauma.',
#   'The examiner prescribed Valium.',
#   'The report noted that the veteran would be seen in the mental \nhygiene clinic in the morning.',
#   'There are no records of such \nfollow-up treatment.',
#   "On separation medical examination in \nJanuary 1972, the veteran's psychiatric system was listed as \nnormal.",
#   'The service medical records are entirely negative \nfor psychiatric treatment, and are negative for a diagnosis \nof a psychiatric disorder.',
#   'Service medical records are also \nnegative for treatment of facial injuries or dental trauma, \nand are negative for treatment of an assault.',
#   'Service personnel records do not include any reports from the \nmilitary police about the alleged incident.',
#   'The veteran\'s \nrecords show that he received promotions to E-3 in June 1970, \nand to E-4 in September 1970, and that he received a letter \nof appreciation in December 1971 for his "outstanding and \nconscientious ability to be a soldier...."',
#   'Multiple attempts \nto obtain additional service and personnel records have been \nunsuccessful.',
#   "At a November 2002 VA psychiatric examination, the examiner \nnoted that she had reviewed the veteran's claims file and \nservice medical records.",
#   'Other than seeing a psychiatrist in \nservice two or three times, the veteran said he had never \nreceived any outpatient or inpatient care for mental health \nreasons.',
#   "She summarized the veteran's description of the \nalleged in-service assault.",
#   'The veteran asserted that he had \nbecome an alcoholic because of this event.',
#   'He reported a \nsignificant alcohol history, and said he began to drink very \nheavily after separation from service.',
#   'The Axis I diagnosis \nwas alcoholism.',
#   'The examiner indicated that the veteran did \nnot display the signs and symptoms of someone suffering from \nPTSD because his sleep was not impaired, he had very little \nproblems with panic, and he denied flashbacks, nightmares or \nintrusive thoughts.',
#   'She said that the veteran did not \ndisplay symptoms of a mental disorder other than substance \nabuse, and this was unlikely to be due to the single event in \nservice.',
#   'VA medical records from a Vet Center dated from 2003 to 2004 \nreflect that the veteran was diagnosed with PTSD due to \nmilitary sexual trauma.',
#   "In February 2003, a counseling \ntherapist noted that the veteran's developmental history \nincluded no information which would provide an alternative \ndiagnosis or an etiology other than the military sexual \ntrauma he reportedly experienced in service.",
#   'A June 2003 private psychological evaluation from W. Paul, \nPh.D., reflects that the veteran was diagnosed with PTSD and \nrule out alcohol abuse.',
#   "Dr. Paul summarized the veteran's \nreported history of sexual abuse in service, and noted that \nthe veteran complained of symptoms including insomnia, \nexaggerated startle reactions, and flashbacks.",
#   'The medical evidence reflects a difference of opinion as to \nwhether the veteran currently has PTSD.',
#   'However, even \nassuming that there is a valid diagnosis of PTSD under the \ncriteria of DSM-IV, service connection for PTSD also requires \ncredible evidence of an in-service stressor.',
#   '38 C.F.R. Â§ \n3.304(f).',
#   "As to the existence of a stressor, a veteran's assertions of \nnon-combat service stressors are not sufficient to establish \ntheir occurrence.",
#   'Rather, his alleged service stressors must \nbe established by official service records or other credible \nsupporting evidence.',
#   '38 C.F.R. Â§ 3.304(f); Pentecost v. \nPrincipi, 16 Vet. App. 124 (2002); Fossie v. West, 12 Vet.',
#   'App. 1 (1998); Cohen v. Brown, 10 Vet. App. 128 (1997); Doran \nv. Brown, 6 Vet. App. 283 (1994).',
#   'There is no evidence which corroborates the occurrence of the \nstressor alleged by the veteran.',
#   "The Board is unable to find \nthat the veteran's alleged service stressor has been verified \nby official service records or other credible supporting \nevidence.",
#   'The weight of the credible evidence establishes that a \nstressor which might lead to PTSD did not occur in service.',
#   'Thus, regardless of diagnosis, service connection for PTSD \nmay not be granted.',
#   'The veteran may apply to reopen his \nclaim in the future, by submitting independent evidence to \ncorroborate a service stressor, or by submitting sufficiently \ndetailed information as would permit the VA to attempt \nstressor verification through the service department.',
#   'See 38 ',
#   'C.F.R. Â§ 3.159(c)(2).',
#   'As the preponderance of the evidence is against the claim for \nservice connection for PTSD, the benefit-of-the-doubt rule \ndoes not apply, and the claim must be denied.',
#   '38 U.S.C.A. Â§ \n5107(b); Gilbert v. Derwinski, 1 Vet. App. 49 (1990).',
#   'ORDER',
#   'Service connection for PTSD is denied.',
#   'K. A. BANFIELD',
#   "Veterans Law Judge, Board of Veterans' Appeals\n\n\n\n\n Department of Veterans Affairs"]}

# %%
df = pd.DataFrame(unlab_segments_by_doc)
df.head()
# Out:
#       doc_name  no_of_sentences  \
# 0  0600090.txt              127
# 1  0600091.txt              117
# 2  0600134.txt               45
# 3  0600163.txt              131
# 4  0600177.txt               61
#
#                                            sentences
# 0  [Citation Nr: 0600090, Decision Date: 01/04/06...
# 1  [Citation Nr: 0600091, Decision Date: 01/04/06...
# 2  [Citation Nr: 0600134, Decision Date: 01/04/06...
# 3  [Citation Nr: 0600163, Decision Date: 01/05/06...
# 4  [Citation Nr: 0600177, Decision Date: 01/05/06...

# %% [markdown]
# ##### Plotting with Plotly

# %%
# bin_width= 0.5
# # here you can choose your rounding method, I've chosen math.ceil
# nbins = math.ceil((df["no_of_sentences"].max() - df["no_of_sentences"].min()) / bin_width)
# fig = px.histogram(df, x="no_of_sentences", nbins=nbins,
#             width=1200, height=600,
#             labels={ # replaces default labels by column name
#                 "no_of_sentences": "Number of Sentences",
#             },
#             template="plotly_white")
# fig.update_yaxes(showgrid=True)
# fig.update_layout(title_text="Histogram of Number of Sentences in Each Document", title_x=0.5, font_size=18)
# fig.show()

# %% [markdown]
# ##### Plotting with seaborn

# %%
fig = plt.figure(figsize=(20, 10))
sns.histplot(data=df, x="no_of_sentences", bins=100)
plt.xlabel('Number of sentences', fontsize=25)
plt.ylabel('Count', fontsize=25)
plt.title('Histogram of number of sentences in 30000 unlabeled texts', fontsize=25)
plt.savefig('histogram of sentences with 100 bins.jpg')
plt.show()

# %% [markdown]
# ##### Plotting with Matplotlib

# %%
# fig = plt.figure(figsize=(20, 10))
# plt.hist(df['no_of_sentences'], bins=100, color='royalblue')
# plt.title('Histogram of number of sentences in 30000 unlabeled texts', fontsize=25)
# plt.xlabel('Number of sentences', fontsize=25)
# plt.ylabel('Count', fontsize=25)
# # plt.savefig('histogram of sentences with 100 bins.jpg')
# plt.show()

# %% [markdown]
# # Phase 3.2: Sentence-wise preprocessing

# %% [markdown]
# ### Tokenization

# %% [raw]
# POS	DESCRIPTION	EXAMPLES
# ADJ	adjective	*big, old, green, incomprehensible, first*
# ADP	adposition	*in, to, during*
# ADV	adverb	*very, tomorrow, down, where, there*
# AUX	auxiliary	*is, has (done), will (do), should (do)*
# CONJ	conjunction	*and, or, but*
# CCONJ	coordinating conjunction	*and, or, but*
# DET	determiner	*a, an, the*
# INTJ	interjection	*psst, ouch, bravo, hello*
# NOUN	noun	*girl, cat, tree, air, beauty*
# NUM	numeral	*1, 2017, one, seventy-seven, IV, MMXIV*
# PART	particle	*’s, not,*
# PRON	pronoun	*I, you, he, she, myself, themselves, somebody*
# PROPN	proper noun	*Mary, John, London, NATO, HBO*
# PUNCT	punctuation	*., (, ), ?*
# SCONJ	subordinating conjunction	*if, while, that*
# SYM	symbol	*$, %, §, ©, +, −, ×, ÷, =, :), 😝*
# VERB	verb	*run, runs, running, eat, ate, eating*
# X	other	*sfpksdpsxmsa*
# SPACE	space

# %%
# def tokenize(txt):
#     dirty_tokens = re.split(' +', txt)  # split words
#     # remove all non-alphanumerics
#     clean_tokens = [re.sub(r'\W', '', t).lower() 
#                     for t in dirty_tokens]
#     if '' in clean_tokens:  # remove empty tokens
#         clean_tokens.remove('')
#     return clean_tokens


# def tokenize_spans(spans):
#     for s in spans:
#         s['tokens_manual'] = tokenize(s['txt'])
        
        
# def build_vocabulary(spans):
#     vocab_counts = {}
#     for sd in spans:
#         for t in tokenize(sd['txt']):
#             if t in vocab_counts:
#                 vocab_counts[t] += 1
#             else:
#                 vocab_counts[t] = 1
#     return vocab_counts

# %%
def spacy_tokenize(txt):
    doc = nlp(txt)
    tokens = list(doc)
    clean_tokens = []
    for t in tokens:
#         print(f'{t.text} | {t.lemma_} | {t.pos_}')
        if t.pos_ == 'PUNCT':
#             print(t)
            pass
#         if t.pos_ == 'PART' and re.search(r'\'', t.text):
#             print(f"Special case: {t}")
        elif t.pos_ == 'NUM':
            clean_tokens.append(f'<NUM{len(t)}>')
        else:
            clean_tokens.append(t.lemma_.lower())
#     if ',' in clean_tokens:
#         clean_tokens.remove()
    return clean_tokens

def custom_spans_add_spacy_tokens(spans):
    for s in spans:
        s['tokens_spacy'] = spacy_tokenize(s['txt'])

# %%
def custom_spacy_tokenize_v2(txt):
    nlp.disable_pipes('parser')
    doc = nlp.pipe(txt, n_process=4)
    doc = nlp(txt)
    tokens = list(doc)
    clean_tokens = []
    for i in range(len(tokens)):
        
        t=tokens[i]
        t1=tokens[i]
#         print(f'{t.text} | {t.lemma_} | {t.pos_}')
#         print(t.pos_, t.text)

#         if "-" in t.text:
#             splitted_t = t.text.split("-")
#             for i in range(len(splitted_t)):
#                 clean_tokens.append(splitted_t[i])
            
        if(i!=len(tokens)-1):
            t1=tokens[i+1]
        if(t1!=t and t1.pos_=='PART' and re.search(r'\'', t1.text)):
#             print(t, t1)
            scrap = t.text+t1.text
            scrap = re.sub(r'\W','',scrap).lower()
            clean_tokens.append(scrap)
            i=i+1           
        elif t.pos_ == 'PUNCT':
            pass
        elif t.text in ('Vet. App.','Fed. Cir.'):
            lem=t.lemma_
            lem=lem.lower()
            clean_tokens.append(lem)
        elif (t.text[0].isalpha()==False and t.is_digit==False):
            if(t.is_upper==False):
                pass
            else:
                lem=t.lemma_
                lem=lem.lower()
                clean_tokens.append(lem)            
        elif t.pos_ == 'NUM':
            clean_tokens.append(f'<NUM{len(t)}>')
        else:
            lem=t.lemma_
            lem = re.sub(r'\W','',lem)
            lem=lem.lower()
            clean_tokens.append(lem)
            
    return clean_tokens

def spans_add_spacy_tokens(spans):
    for s in spans:
        s['tokens_spacy'] = spacy_tokenize(s['txt'])

# %%
a = "05/06/20"
re.search("^[0-9]{2}/[0-9]{2}/([0-9]{2}|[0-9]{4})$", a)
# Out:
# <re.Match object; span=(0, 8), match='05/06/20'>

# %%
def custom_spacy_tokenize(txt):
    nlp.disable_pipes('parser')
    doc = nlp.pipe(txt, n_process=4)
    doc = nlp(txt)
    tokens = list(doc)
    clean_tokens = []
    for i, token in enumerate(tokens):
#         print(f"token: {token} | {token.pos_}")
        if token.pos_ == 'PUNCT' and not re.search("^[0-9]{2}/[0-9]{2}/([0-9]{2}|[0-9]{4})$", token.text):
            pass
        
        elif token.pos_ == 'NUM':
            refined_token = re.sub(r'\W', '', token.text)
            clean_tokens.append(f'<NUM{len(refined_token)}>')
            
        elif token.text == "\'s" and token.pos_ == 'PART':
            pos_token = tokens[i-1].text + token.text
            
            refined_token = re.sub(r'\W', '', pos_token.lower())
            
            if refined_token.isnumeric():
                refined_token = f'<NUM{len(refined_token)}>'
                
            if not refined_token == "":
                clean_tokens.append(pos_token.lower())
                clean_tokens.remove(tokens[i-1].text.lower())
                   
        elif "-" in token.text:
            splitted_tokens = token.text.split("-")

            for sp_token in splitted_tokens:
                refined_token = re.sub(r'\W', '', sp_token.lower())
                if refined_token != "":
                    if refined_token.isnumeric():
                        refined_token = f'<NUM{len(refined_token)}>'
                    clean_tokens.append(refined_token)
        elif token.text in ("Vet. App.", "Fed. Cir."):
            clean_tokens.append(token.lemma_.lower())
#         elif "." in token.text and token.text in ("Vet. App.", "Fed. Cir."):
#             print(f"Special condition fulfilled: {token.text}")
#             splitted_tokens = token.text.split(".")

#             for sp_token in splitted_tokens:
#                 refined_token = re.sub(r'\W', '', sp_token.lower())
#                 if refined_token != "":
#                     if refined_token.isnumeric():
#                         refined_token = f'<NUM{len(refined_token)}>'
#                     clean_tokens.append(refined_token)
        else:
            refined_token = re.sub(r'\W', '', token.lemma_.lower())
#             print(f"refined token: {refined_token}")
            if re.search('\d+', refined_token) and re.search('[a-zA-Z]+', refined_token):
#                 print("Matched mixed")
                continue
            elif refined_token != "" and refined_token.isnumeric():
#                 print("Matched digit only")
                refined_token = f'<NUM{len(refined_token)}>'
                clean_tokens.append(refined_token)

            elif refined_token != "":
#                 print(f"Nothing matched, inserting {refined_token}")
                clean_tokens.append(refined_token)
                    
    return clean_tokens

def spans_add_spacy_tokens(spans):
    for s in spans:
        s['tokens_spacy'] = custom_spacy_tokenize(s['txt'])

# %% [markdown]
# #### Testing Spacy tokenizer on some example sentences

# %%
nlp = spacy.load("en_core_web_sm")
nlp.tokenizer.add_special_case('Vet. App.', [{ORTH: 'Vet. App.'}])
nlp.tokenizer.add_special_case('Fed. Cir.', [{ORTH: 'Fed. Cir.'}])

# %%
example_basic_1 = 'In sum, as the preponderance of the evidence is against the Veteran\'s claim, his appeal must be denied.'
example_cit_1 = 'Smith v. Gober, 14 Vet. App. 227 (2000), aff\'d 281 F.3d 1384 (Fed. Cir. 2002); Dela Cruz v. Principi, 15 Vet. App. 143 (2001); see also Quartuccio v. Principi, 16 Vet. App. 183 (2002).'
example_rule_1 = '"To establish a right to compensation for a present disability, a Veteran must show: "(1) the existence of a present disability; (2) in-service incurrence or aggravation of a disease or injury; and (3) a causal relationship between the present disability and the disease or injury incurred or aggravated during service"-the so-called "nexus" requirement."'
example_mixed_1 = 'In Dingess v. Nicholson, 19 Vet. App. 473 (2006), the U.S. Court of Appeals for Veterans Claims held that, upon receipt of an application for a service-connection claim, 38 U.S.C.A. � 5103(a) and 38 C.F.R. � 3.159(b) require VA to provide the claimant with notice that a disability rating and an effective date for the award of benefits will be assigned if service connection is awarded. '

# %%
print(example_basic_1, end="\n=============\n")
print(spacy_tokenize(example_basic_1 ), end="\n\n")
print(custom_spacy_tokenize(example_basic_1), end="\n\n")
print(custom_spacy_tokenize_v2(example_basic_1), end="\n\n")
# Out:
# In sum, as the preponderance of the evidence is against the Veteran's claim, his appeal must be denied.
# =============
# ['in', 'sum', 'as', 'the', 'preponderance', 'of', 'the', 'evidence', 'be', 'against', 'the', 'veteran', "'s", 'claim', 'his', 'appeal', 'must', 'be', 'deny']
#
# ['in', 'sum', 'as', 'the', 'preponderance', 'of', 'the', 'evidence', 'be', 'against', 'the', "veteran's", 'claim', 'his', 'appeal', 'must', 'be', 'deny']
#
# ['in', 'sum', 'as', 'the', 'preponderance', 'of', 'the', 'evidence', 'be', 'against', 'the', 'veterans', 'claim', 'his', 'appeal', 'must', 'be', 'deny']

# %%
print(example_cit_1, end="\n=============\n")
print(spacy_tokenize(example_cit_1 ), end="\n\n")
print(custom_spacy_tokenize(example_cit_1), end="\n\n")
print(custom_spacy_tokenize_v2(example_cit_1), end="\n\n")
# Out:
# Smith v. Gober, 14 Vet. App. 227 (2000), aff'd 281 F.3d 1384 (Fed. Cir. 2002); Dela Cruz v. Principi, 15 Vet. App. 143 (2001); see also Quartuccio v. Principi, 16 Vet. App. 183 (2002).
# =============
# ['smith', 'v.', 'gober', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', "aff'd", '<NUM3>', 'f.3d', '<NUM4>', 'fed. cir.', '<NUM4>', 'dela', 'cruz', 'v.', 'principi', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'see', 'also', 'quartuccio', 'v.', 'principi', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>']
#
# ['smith', 'v', 'gober', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'affd', '<NUM3>', '<NUM4>', 'fed. cir.', '<NUM4>', 'dela', 'cruz', 'v', 'principi', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'see', 'also', 'quartuccio', 'v', 'principi', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>']
#
# ['smith', 'v', 'gober', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'affd', '<NUM3>', 'f3d', '<NUM4>', 'fed. cir.', '<NUM4>', 'dela', 'cruz', 'v', 'principi', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'see', 'also', 'quartuccio', 'v', 'principi', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>']

# %%
print(example_rule_1, end="\n=============\n")
print(spacy_tokenize(example_rule_1 ), end="\n\n")
print(custom_spacy_tokenize(example_rule_1), end="\n\n")
print(custom_spacy_tokenize_v2(example_rule_1), end="\n\n")
# Out:
# "To establish a right to compensation for a present disability, a Veteran must show: "(1) the existence of a present disability; (2) in-service incurrence or aggravation of a disease or injury; and (3) a causal relationship between the present disability and the disease or injury incurred or aggravated during service"-the so-called "nexus" requirement."
# =============
# ['to', 'establish', 'a', 'right', 'to', 'compensation', 'for', 'a', 'present', 'disability', 'a', 'veteran', 'must', 'show', '1', 'the', 'existence', 'of', 'a', 'present', 'disability', '2', 'in', 'service', 'incurrence', 'or', 'aggravation', 'of', 'a', 'disease', 'or', 'injury', 'and', '3', 'a', 'causal', 'relationship', 'between', 'the', 'present', 'disability', 'and', 'the', 'disease', 'or', 'injury', 'incur', 'or', 'aggravate', 'during', 'service"-the', 'so', 'call', 'nexus', 'requirement']
#
# ['to', 'establish', 'a', 'right', 'to', 'compensation', 'for', 'a', 'present', 'disability', 'a', 'veteran', 'must', 'show', '<NUM1>', 'the', 'existence', 'of', 'a', 'present', 'disability', '<NUM1>', 'in', 'service', 'incurrence', 'or', 'aggravation', 'of', 'a', 'disease', 'or', 'injury', 'and', '<NUM1>', 'a', 'causal', 'relationship', 'between', 'the', 'present', 'disability', 'and', 'the', 'disease', 'or', 'injury', 'incur', 'or', 'aggravate', 'during', 'service', 'the', 'so', 'call', 'nexus', 'requirement']
#
# ['to', 'establish', 'a', 'right', 'to', 'compensation', 'for', 'a', 'present', 'disability', 'a', 'veteran', 'must', 'show', '1', 'the', 'existence', 'of', 'a', 'present', 'disability', '2', 'in', 'service', 'incurrence', 'or', 'aggravation', 'of', 'a', 'disease', 'or', 'injury', 'and', '3', 'a', 'causal', 'relationship', 'between', 'the', 'present', 'disability', 'and', 'the', 'disease', 'or', 'injury', 'incur', 'or', 'aggravate', 'during', 'servicethe', 'so', 'call', 'nexus', 'requirement']

# %%
print(example_mixed_1, end="\n=============\n")
print(spacy_tokenize(example_mixed_1 ), end="\n\n")
print(custom_spacy_tokenize(example_mixed_1), end="\n\n")
print(custom_spacy_tokenize_v2(example_mixed_1), end="\n\n")
# Out:
# In Dingess v. Nicholson, 19 Vet. App. 473 (2006), the U.S. Court of Appeals for Veterans Claims held that, upon receipt of an application for a service-connection claim, 38 U.S.C.A. � 5103(a) and 38 C.F.R. � 3.159(b) require VA to provide the claimant with notice that a disability rating and an effective date for the award of benefits will be assigned if service connection is awarded.
# =============
# ['in', 'dingess', 'v.', 'nicholson', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'the', 'u.s.', 'court', 'of', 'appeals', 'for', 'veterans', 'claims', 'hold', 'that', 'upon', 'receipt', 'of', 'an', 'application', 'for', 'a', 'service', 'connection', 'claim', '<NUM2>', 'u.s.c.a.', '�', '<NUM6>', 'and', '<NUM2>', 'c.f.r.', '�', '3.159(b', 'require', 'va', 'to', 'provide', 'the', 'claimant', 'with', 'notice', 'that', 'a', 'disability', 'rating', 'and', 'an', 'effective', 'date', 'for', 'the', 'award', 'of', 'benefit', 'will', 'be', 'assign', 'if', 'service', 'connection', 'be', 'award']
#
# ['in', 'dingess', 'v', 'nicholson', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'the', 'us', 'court', 'of', 'appeals', 'for', 'veterans', 'claims', 'hold', 'that', 'upon', 'receipt', 'of', 'an', 'application', 'for', 'a', 'service', 'connection', 'claim', '<NUM2>', 'usca', '<NUM5>', 'and', '<NUM2>', 'cfr', 'require', 'va', 'to', 'provide', 'the', 'claimant', 'with', 'notice', 'that', 'a', 'disability', 'rating', 'and', 'an', 'effective', 'date', 'for', 'the', 'award', 'of', 'benefit', 'will', 'be', 'assign', 'if', 'service', 'connection', 'be', 'award']
#
# ['in', 'dingess', 'v', 'nicholson', '<NUM2>', 'vet. app.', '<NUM3>', '<NUM4>', 'the', 'us', 'court', 'of', 'appeals', 'for', 'veterans', 'claims', 'hold', 'that', 'upon', 'receipt', 'of', 'an', 'application', 'for', 'a', 'service', 'connection', 'claim', '<NUM2>', 'usca', 'and', '<NUM2>', 'cfr', 'require', 'va', 'to', 'provide', 'the', 'claimant', 'with', 'notice', 'that', 'a', 'disability', 'rating', 'and', 'an', 'effective', 'date', 'for', 'the', 'award', 'of', 'benefit', 'will', 'be', 'assign', 'if', 'service', 'connection', 'be', 'award']

# %%
sp_text_1 = "38 C.F.R. § 3.303(d) (2005)."

print(sp_text_1, end="\n=============\n")
print(spacy_tokenize(sp_text_1 ), end="\n\n")
print(custom_spacy_tokenize(sp_text_1), end="\n\n")
print(custom_spacy_tokenize_v2(sp_text_1), end="\n\n")
# Out:
# 38 C.F.R. § 3.303(d) (2005).
# =============
# ['<NUM2>', 'c.f.r.', '§', '3.303(d', '<NUM4>']
#
# ['<NUM2>', 'cfr', '<NUM4>']
#
# ['<NUM2>', 'cfr', '<NUM4>']

# %%
sp_text_2 = "BOARD OF VETERANS APPEALS\nDEPARTMENT OF VETERANS AFFAIRS\nWASHINGTON, DC  20420"

print(sp_text_2, end="\n=============\n")
print(spacy_tokenize(sp_text_2 ), end="\n\n")
print(custom_spacy_tokenize(sp_text_2), end="\n\n")
print(custom_spacy_tokenize_v2(sp_text_2), end="\n\n")
# Out:
# BOARD OF VETERANS APPEALS
# DEPARTMENT OF VETERANS AFFAIRS
# WASHINGTON, DC  20420
# =============
# ['board', 'of', 'veterans', 'appeals', '\n', 'department', 'of', 'veterans', 'affairs', '\n', 'washington', 'dc', ' ', '<NUM5>']
#
# ['board', 'of', 'veterans', 'appeals', 'department', 'of', 'veterans', 'affairs', 'washington', 'dc', '<NUM5>']
#
# ['board', 'of', 'veterans', 'appeals', 'department', 'of', 'veterans', 'affairs', 'washington', 'dc', '<NUM5>']

# %%
sp_text_3 = "X-rays demonstrated \nminimal degenerative changes at the L5-S1."

print(sp_text_3, end="\n=============\n")
print(spacy_tokenize(sp_text_3 ), end="\n\n")
print(custom_spacy_tokenize(sp_text_3), end="\n\n")
print(custom_spacy_tokenize_v2(sp_text_3), end="\n\n")
# Out:
# X-rays demonstrated
# minimal degenerative changes at the L5-S1.
# =============
# ['x', '-', 'ray', 'demonstrate', '\n', 'minimal', 'degenerative', 'change', 'at', 'the', 'l5', 's1']
#
# ['x', 'ray', 'demonstrate', 'minimal', 'degenerative', 'change', 'at', 'the']
#
# ['x', 'ray', 'demonstrate', 'minimal', 'degenerative', 'change', 'at', 'the', 'l5', 's1']

# %%
sp_txt_4 = "Spacy's tokenizer requires special rules for producing 'state-of-the-art' tokens."

print(sp_txt_4, end="\n=============\n")
print(spacy_tokenize(sp_txt_4 ), end="\n\n")
print(custom_spacy_tokenize(sp_txt_4), end="\n\n")
print(custom_spacy_tokenize_v2(sp_txt_4), end="\n\n")
# Out:
# Spacy's tokenizer requires special rules for producing 'state-of-the-art' tokens.
# =============
# ['spacy', "'s", 'tokenizer', 'require', 'special', 'rule', 'for', 'produce', 'state', 'of', 'the', 'art', 'token']
#
# ["spacy's", 'tokenizer', 'require', 'special', 'rule', 'for', 'produce', 'state', 'of', 'the', 'art', 'token']
#
# ['spacys', 'tokenizer', 'require', 'special', 'rule', 'for', 'produce', 'state', 'of', 'the', 'art', 'token']

# %%
sp_txt_5 = "C.F.R. §§ 3.102, 3.303, 3.306, 3.310 (2005)."

print(sp_txt_5, end="\n=============\n")
print(spacy_tokenize(sp_txt_5 ), end="\n\n")
print(custom_spacy_tokenize(sp_txt_5), end="\n\n")
print(custom_spacy_tokenize_v2(sp_txt_5), end="\n\n")
# Out:
# C.F.R. §§ 3.102, 3.303, 3.306, 3.310 (2005).
# =============
# ['c.f.r.', '§', '§', '<NUM5>', '<NUM5>', '<NUM5>', '<NUM5>', '<NUM4>']
#
# ['cfr', '<NUM4>', '<NUM4>', '<NUM4>', '<NUM4>', '<NUM4>']
#
# ['cfr', '<NUM4>']

# %%
sp_text_6 = "Decision Date: 03/08/06"

print(sp_text_6, end="\n=============\n")
print(spacy_tokenize(sp_text_6 ), end="\n\n")
print(custom_spacy_tokenize(sp_text_6), end="\n\n")
print(custom_spacy_tokenize_v2(sp_text_6), end="\n\n")
# Out:
# Decision Date: 03/08/06
# =============
# ['decision', 'date']
#
# ['decision', 'date', '<NUM6>']
#
# ['decision', 'date']

# %%
sp_text_7 = "Archive Date: 06/16/06"

print(sp_text_7, end="\n=============\n")
print(spacy_tokenize(sp_text_7 ), end="\n\n")
print(custom_spacy_tokenize(sp_text_7), end="\n\n")
print(custom_spacy_tokenize_v2(sp_text_7), end="\n\n")
# Out:
# Archive Date: 06/16/06
# =============
# ['archive', 'date', '<NUM8>']
#
# ['archive', 'date', '<NUM6>']
#
# ['archive', 'date']

# %% [markdown]
# ### Test the tokenization of a single file

# %%
test_file = open(UNLABELED_DATA_PATH/ Path('0603946.txt'), 'r').read().encode('latin-1', 'ignore')
test_file = test_file.decode('latin-1').strip()
doc = luima.text2sentences(test_file, offsets=False)

spans = [{'txt': sent} for sent in doc]
spans_add_spacy_tokens(spans)

# %%
# token_save_file = 'tokenized_sentences_unlabeled.txt'
# file = open(token_save_file, 'w')
# dir(file)

# %% [markdown]
# ### Tokenize the whole unlabeled corpus and save it in a text file

# %%
spans = [{'txt': sent} for unlab_doc in unlab_segments_by_doc[0:5] for sent in unlab_doc['sentences']]

# %%
random.shuffle(spans)
spans
# Out:
# [{'txt': "By way of these documents, they also were \nspecifically informed of the cumulative evidence already \nhaving been previously provided to VA or obtained by VA on \nthe veteran's behalf."},
#  {'txt': 'The Board notes that the evidence of record subsequent to the '},
#  {'txt': 'See \nCollette v. Brown, 82 F.3d 389, 392 (1996); 38 U.S.C.A. Â§ \n1154(b) ; 38 C.F.R. Â§ 3.304(d).'},
#  {'txt': '38 U.S.C.A. Â§ 5108 (West 2002); 38 C.F.R. Â§ \n3.156(a) (2005).'},
#  {'txt': '38 U.S.C.A. Â§ 1110; 38 C.F.R. Â§ 3.303.'},
#  {'txt': 'Kutscherousky v. West, 12 Vet. App. 369 (1999).'},
#  {'txt': 'Clyburn v. West, 12 Vet. App. 296, \n303 (1999).'},
#  {'txt': 'He said that the first time he ever told anyone about the \nsexual aspect of the assault was at his November 2002 VA \nexamination.'},
#  {'txt': 'U.S.C.A. Â§ 1110 (West 2002); 38 C.F.R. Â§Â§ 3.303, 3.304 \n(2005).'},
#  {'txt': 'CONCLUSION OF LAW'},
#  {'txt': 'While the \nveteran is clearly competent to describe pain associated with \nthis feet, there is no indication that the veteran is \nmedically trained to offer any opinion on causation or the \nclaimed medical nexus.'},
#  {'txt': 'Two \nrequirements as to the sufficiency of a stressor are: 1) a \nperson must have been "exposed to a traumatic event" in \nwhich "the person experienced, witnessed or was confronted \nwith an event or events that involved actual or threatened \ndeath or serious injury, or a threat to the physical \nintegrity of self or others," and 2) "the person\'s response \n[must have] involved intense fear, helplessness or horror."'},
#  {'txt': '38 C.F.R. Â§ \n3.303(b).'},
#  {'txt': 'The Court also held, however, that providing \nthe VCAA notice to the claimant after the initial decision \ncould satisfy the requirements of the VCAA if the timing of \nthe notice was not prejudicial to the claimant.'},
#  {'txt': 'Vet.App. 183, 187 (2002).'},
#  {'txt': 'Quartuccio \nv. Principi, 16 Vet. App. 183 (2002).'},
#  {'txt': "Therefore, the \nveteran will not be prejudiced by the Board's adjudication of \nhis claim."},
#  {'txt': 'Examination \nrevealed that the veteran was tender to palpation about the \nlateral ankle joint in the vicinity of the calcaneofibular \nligament.'},
#  {'txt': 'These documents provided \nthem with notice of the law and governing regulations, as \nwell as the reasons for the determinations made regarding his \nclaim.'},
#  {'txt': 'Service connection for PTSD is denied.'},
#  {'txt': 'He later \nreceived counseling from a mental health professional, whom \nhe only told about the physical aspects of the assault.'},
#  {'txt': '38'},
#  {'txt': 'The pain was associated with \nsimilar pain which had begin two to three weeks earlier of \nthe left foot.'},
#  {'txt': 'The RO shall schedule a hearing at the \nRO, as requested, before a Veterans Law \nJudge at the earliest available \nopportunity, in accordance with \napplicable procedures, and notify the \nveteran of the date and time thereof.'},
#  {'txt': 'Appellant represented by:\tTexas Veterans Commission'},
#  {'txt': 'A personal hearing \nwas held before an RO hearing officer in June 2004.'},
#  {'txt': 'VCAA'},
#  {'txt': 'The diagnosis was "History stress fractures \nbilateral tarsonavicular."'},
#  {'txt': 'More recently, in an \nOctober 2004 statement in support of claim, the veteran \nwrites that his combat experiences during the Korean '},
#  {'txt': 'Pelegrini, \n18 Vet. App. at 121.'},
#  {'txt': 'He also states in his letters that \nhe thinks about wartime and his comrades who disappeared in \ncombat, and dreams about dead people.'},
#  {'txt': 'Entitlement to service connection for bilateral ingrown \ntoenail disability.'},
#  {'txt': 'March 1970 while he was stationed at Fort Belvoir, Virginia.'},
#  {'txt': 'The appellant has the right to submit additional evidence and \nargument on the matter or matters the Board has remanded.'},
#  {'txt': 'Service connection for PTSD requires medical evidence \ndiagnosing the condition, a relation (established by medical \nevidence) between current symptoms and an inservice stressor, \nand credible supporting evidence that the claimed inservice \nstressor(s) occurred.'},
#  {'txt': 'Applicable law provides that \nservice connection will be granted if it is shown that the \nveteran suffers from disability resulting from an injury \nsuffered or disease contracted in line of duty, or for \naggravation of a preexisting injury suffered or disease \ncontracted in line of duty, in the active military, naval, or \nair service.'},
#  {'txt': "For these reasons, \nthe VA examiner's report must be given greater weight than \nthat of the fee-based physician."},
#  {'txt': 'INTRODUCTION'},
#  {'txt': 'While the entire VCAA notice in this case was not provided \nprior to the initial AOJ adjudication, notice was provided by \nthe AOJ prior to the transfer and certification of the case \nto the Board, and the content of the notice fully complied \nwith the requirements of 38 U.S.C. Â§ 5103(a) and 38 C.F.R. '},
#  {'txt': 'The veteran subsequently again requested service connection \nfor ingrown toenail disability.'},
#  {'txt': 'This may \nbe accomplished by affirmatively showing inception or \naggravation during service, or through application of \nstatutory presumptions.'},
#  {'txt': 'Specifically, it is not at least as \nlikely as not that the current complaints \ncorrelate with or are secondary to the \nprior talonavicular pathology.'},
#  {'txt': 'FINDINGS OF FACT'},
#  {'txt': 'During his military service, \naccording to the veteran, he served in the Korean Conflict'},
#  {'txt': 'X-rays of the ankles were \nessentially negative for any abnormality.'},
#  {'txt': 'The \ndoctor told him he would try to obtain a general discharge \nfor the veteran, but this did not occur.'},
#  {'txt': "Veterans Law Judge, Board of Veterans' Appeals\n\n\n\n\n Department of Veterans Affairs"},
#  {'txt': 'The Veterans Claims Assistance Act of 2000 (VCAA), Pub. L. '},
#  {'txt': 'Duties to notify and assist'},
#  {'txt': 'During service the veteran did not engage in combat with the \nenemy, and it is not shown by credible supporting evidence \nthat a stressor, which might lead to PTSD, occurred during \nservice.'},
#  {'txt': 'In a claim for VA compensation benefits received in April \n2002 (the same month of his discharge from service), the \nveteran referenced heel pain and ingrown toenails.'},
#  {'txt': 'Combat Infantryman Badge (CIB).'},
#  {'txt': '38 C.F.R. Â§ 20.1100(b) (2005).'},
#  {'txt': '38 U.S.C.A. Â§ \n1154(b); 38 C.F.R. Â§ 3,304(d).'},
#  {'txt': 'Given that the \nveteran has continually complained of his bilateral ingrown \ntoenail disability and filed a claim as soon as he was \nreleased from service, and in light of the current medical \nevidence of the claimed disability, the Board finds that the \nrecord shows a continuity of pertinent symptomatology to link \nthe disability to service.'},
#  {'txt': 'Â§ 3.159(b) the VCAA notifications of record essentially \nsatisfied the notice requirements by: (1)'},
#  {'txt': 'Rather, his alleged service stressors must \nbe established by official service records or other credible \nsupporting evidence.'},
#  {'txt': 'Thus, \nservice connection for bilateral ingrown toenail disability \nis warranted.'},
#  {'txt': 'Consequently, \nthe Board concludes that any such error is harmless and does \nnot prohibit consideration of this matter on the merits.'},
#  {'txt': 'ATTORNEY FOR THE BOARD'},
#  {'txt': 'Accordingly, there is no further duty to notify, and no \nprejudice to the veteran exists by deciding the claim.'},
#  {'txt': 'VA medical records from a Vet Center dated from 2003 to 2004 \nreflect that the veteran was diagnosed with PTSD due to \nmilitary sexual trauma.'},
#  {'txt': 'Service connection may also be granted for any \ndisease diagnosed after discharge, when all the evidence, \nincluding that pertinent to service, establishes that the \ndisease was incurred in service.'},
#  {'txt': "New and material evidence having been submitted, the \nveteran's application to reopen the claim of entitlement to \nservice connection for bilateral navicular tarsal stress \nfracture is reopened."},
#  {'txt': 'The veteran has not indicated that there are \noutstanding relevant records pertaining to his claim.'},
#  {'txt': '38 C.F.R. Â§ 3.303(d).'},
#  {'txt': 'The \nclaims file reflects no record of the veteran having \nwithdrawn his request for a hearing or any other reason for \nthe case having been returned to the Board without a hearing.'},
#  {'txt': 'Consistent with 38 U.S.C.A. Â§ 5103(a) and 38 C.F.R. '},
#  {'txt': 'DOCKET NO.  04-33 853'},
#  {'txt': 'Decision Date: 01/04/06'},
#  {'txt': '38 U.S.C.A. Â§Â§ 5103, 5103A; 38 C.F.R. Â§ 3.159.'},
#  {'txt': 'In September 2004, the Board remanded the case to the RO for \nscheduling of a Travel Board hearing.'},
#  {'txt': 'The preponderance of the evidence fails to reflect that the \nveteran suffers from PTSD arising from active duty.'},
#  {'txt': "This case comes before the Board of Veterans' Appeals (Board) \non appeal from a December 2002 rating decision of the \nDepartment of Veterans Affairs (VA) Regional Office (RO) in \nHouston, Texas."},
#  {'txt': 'While the veteran has a CIB, the preponderance of the \nevidence is against the claim for service connection for '},
#  {'txt': "No. 106-475, 114 Stat. 2096 (Nov. 9, 2000) (codified at \n38 U.S.C.A. Â§Â§ 5100, 5102, 5103, 5103A, 5106, 5107, and 5126 \n(West 2002) redefined VA's duty to assist the veteran in the \ndevelopment of a claim."},
#  {'txt': 'Analysis'},
#  {'txt': 'After removal of \nthe cast the veteran had persistent right foot pain and the \nveteran was placed on a couple of days bedrest.'},
#  {'txt': "The fee-based physician further \nstated  that the veteran was exposed to combat experiences, \nbut identifies the incident during the veteran's Fort \nClayton, Panama tour-of-duty as the principal PTSD stressor."},
#  {'txt': "As to VA's duty to assist, copies of veteran's service \nmedical records, which were charred, are in the file, as are \ncopies of his personnel file."},
#  {'txt': 'The veteran had active military service from November 1950 to \nDecember 1954.'},
#  {'txt': 'Board notes that there is no contrary medical opinion of \nrecord.'},
#  {'txt': 'Timberlake v. Gober, 14 Vet. App. 122, 128-30 (2000).'},
#  {'txt': 'After this \nincident, he went to his electronics school, and despite \nfailing this course, he was posted to Germany, where he \nremained for the remainder of his active duty service.'},
#  {'txt': 'Â§Â§ 3.303, 3.307, 3.309 (2005).'},
#  {'txt': '38'},
#  {'txt': '3.'},
#  {'txt': 'Under the VCAA, VA has a duty to \nnotify the veteran of any information and evidence needed to \nsubstantiate and complete a claim, and of what part of that \nevidence is to be provided by the claimant and what part VA \nwill attempt to obtain for the claimant.'},
#  {'txt': 'REASONS AND BASES FOR FINDINGS AND CONCLUSION'},
#  {'txt': 'In these letters, the veteran does \nnot state that there were threats of bodily harm, serious \ninjury, or fear for life.'},
#  {'txt': 'DOCKET NO.  03-32 007'},
#  {'txt': "The RO did not adjudicate the veteran's claim \nuntil he reiterated his claim in May 2003."},
#  {'txt': "Dr. Paul summarized the veteran's \nreported history of sexual abuse in service, and noted that \nthe veteran complained of symptoms including insomnia, \nexaggerated startle reactions, and flashbacks."},
#  {'txt': 'A May 2005 RO letter informed the veteran that, in all \nlikelihood, his hearing would be scheduled for August 2005, \nwhich would allow him sufficient time to obtain additional \nevidence and appoint another representative.'},
#  {'txt': 'Service connection for PTSD is denied.'},
#  {'txt': 'Material evidence means existing evidence that, by \nitself or when considered with previous evidence of record, \nrelates to an unestablished fact necessary to substantiate \nthe claim.'},
#  {'txt': 'Lathan \nv. Brown, 7 Vet. App. 359, 365 (1995).'},
#  {'txt': 'DOCKET NO.  04-30 883'},
#  {'txt': 'PTSD.'},
#  {'txt': 'He said that he \nwas later found by a soldier on guard duty, and was taken by \nmilitary police to receive medical treatment.'},
#  {'txt': 'THE ISSUE'},
#  {'txt': 'The veteran submitted additional pertinent evidence to the '},
#  {'txt': 'The veteran states that \nhis disciplinary experience in Fort Clayton, Panama in which \nhe was ultimately reduced in rank from E-7 to E-3, was the \nworst thing that ever happened to him and that he dreams \nabout this incident constantly.'},
#  {'txt': 'Entitlement to service connection for disability manifested \nby bilateral ingrown toenails is warranted.'},
#  {'txt': 'Â§ 5108; 38 C.F.R. Â§ 3.156.'},
#  {'txt': 'Multiple attempts \nto obtain additional service and personnel records have been \nunsuccessful.'},
#  {'txt': "A January 2004 statement from the veteran's brother indicated \nthat the veteran had difficulties with his feet ever since \nleaving the military."},
#  {'txt': 'October 1983 rating decision includes a June 2003 VA \nexamination that was not of record at the time of the October \n1983 rating decision.'},
#  {'txt': "Bilateral ingrown toenail disability was incurred in the \nveteran's active duty service."},
#  {'txt': 'Additionally, the SOC included a \nsummary of the relevant VCAA regulatory provisions of \n38 C.F.R. Â§ 3.159.'},
#  {'txt': 'ORDER'},
#  {'txt': 'See 38 '},
#  {'txt': 'REMAND'},
#  {'txt': 'The notice requirements of the VCAA require VA to notify the \nveteran of any evidence that is necessary to substantiate his \nclaim, as well as the evidence VA will attempt to obtain and \nwhich evidence he is responsible for providing.'},
#  {'txt': 'Physical examination revealed no \nattenuation of the ankle ligaments and no abnormalities were \nnoted.'},
#  {'txt': 'Accordingly, the case is REMANDED for the following:'},
#  {'txt': 'I.'},
#  {'txt': 'In his January 2002 separation examination, the \nfeet were evaluated as clinically normal.'},
#  {'txt': 'WITNESS AT HEARING ON APPEAL'},
#  {'txt': 'A claimant may reopen a finally adjudicated claim by \nsubmitting new and material evidence.'},
#  {'txt': 'Antalgia \nfor the left lower extremity as likely as \nnot is secondary to the tibial pain with \na prior history of fracture and repair.'},
#  {'txt': 'See 38 U.S.C.A. Â§Â§ 5109B, 7112 (West Supp. 2005).'},
#  {'txt': 'ATTORNEY FOR THE BOARD'},
#  {'txt': 'DATE'},
#  {'txt': 'The veteran filed a \nnotice of disagreement in April 2004.'},
#  {'txt': '38 C.F.R. '},
#  {'txt': '38 U.S.C.A. Â§ 5107(b); Gilbert v. \nDerwinski, 1 Vet. App. 49 (1990).'},
#  {'txt': "In November 2005, the RO returned the case to the Board \nwithout rescheduling the veteran's Travel Board hearing."},
#  {'txt': 'This claim must be afforded expeditious treatment.'},
#  {'txt': 'Mental health records are in \nthe claims file, as well as a March 2004 VA mental health \nassessment.'},
#  {'txt': 'Service medical records are also \nnegative for treatment of facial injuries or dental trauma, \nand are negative for treatment of an assault.'},
#  {'txt': 'By rating decision in November 2002, the RO denied \ncompensation benefits for various claimed disorders, \nincluding heel disability, but did not address the ingrown \ntoenail claim.'},
#  {'txt': "Board of Veterans' Appeals is appealable to the United States"},
#  {'txt': '38 U.S.C.A. Â§ 5107; '},
#  {'txt': 'The CIB is indicative of participation in combat and, if an \ninjury or disease is alleged to have been incurred or \naggravated in combat, such occurrence or aggravation may be \nshown by satisfactory lay evidence, consistent with the \ncircumstances, conditions, or hardships of combat, even if \nthere is no official record of the incident.'},
#  {'txt': 'On appeal from the\nDepartment of Veterans Affairs Medical and Regional Office'},
#  {'txt': 'FINDINGS OF FACT'},
#  {'txt': 'Board in October 2005.'},
#  {'txt': 'In Pelegrini v. Principi, 18 Vet. App. 112 (2004), the United \nStates Court of Appeals for Veterans Claims (hereinafter, \n"the Court") held, in part, that a VCAA notice, as required \nby 38 U.S.C.A. Â§ 5103(a), must be provided to a claimant \nbefore the initial unfavorable decision on a claim for VA \nbenefits by the agency of original jurisdiction (in this \ncase, the RO).'},
#  {'txt': 'March 2003 report that there was insufficient evidence to \nsupport a diagnosis for PTSD.'},
#  {'txt': 'Although the '},
#  {'txt': 'Law and Regulations'},
#  {'txt': '38 U.S.C.A. Â§ \n5107(b); Gilbert v. Derwinski, 1 Vet. App. 49 (1990).'},
#  {'txt': 'A June 2003 private psychological evaluation from W. Paul, \nPh.D., reflects that the veteran was diagnosed with PTSD and \nrule out alcohol abuse.'},
#  {'txt': "The claims file includes  the report of a January 2003 mental \nhealth assessment for VA purposes in which a fee-based \nphysician noted that the veteran's principal diagnosis was "},
#  {'txt': 'The veteran \nwas not anxious, distressed, or depressed when expressing his \nexperiences in Korea, nor did he report feelings of intense \nfear, helplessness, or horror at the time when he was \nexperiencing events in the Army.'},
#  {'txt': 'Therefore, the Board finds that the \nveteran was notified and aware of the evidence needed to \nsubstantiate this claim, the avenues through which he might \nobtain such evidence, and the allocation of responsibilities \nbetween himself and VA in obtaining such evidence.'},
#  {'txt': 'There are no records of such \nfollow-up treatment.'},
#  {'txt': 'The criteria for service connection for PTSD have not been \nmet.'},
#  {'txt': 'As indicated, this examiner \nfound the veteran did not have PTSD, and indeed, that he had \nno Axis I psychiatric diagnosis.'},
#  {'txt': 'This \n"fourth element" of the notice requirement comes from the \nlanguage of 38 C.F.R. Â§ 3.159(b)(1).'},
#  {'txt': 'VA regulations for the \nimplementation of the VCAA were codified as amended at \n38 C.F.R. Â§Â§ 3.102, 3.156(a), 3.159, and 3.326(a) (2005).'},
#  {'txt': 'In October 2002 the veteran filed an application to reopen \nthis claim.'},
#  {'txt': 'Gilbert v. Derwinski, 1 Vet. App. 49 (1990).'},
#  {'txt': 'However, it is not bound to accept \nany one opinion (whether from a VA examiner, private \nphysician, or other source) concerning the merits of a claim.'},
#  {'txt': 'ATTORNEY FOR THE BOARD'},
#  {'txt': 'As the claim was filed after this \ndate, the new version (cited below) applies in this case.'},
#  {'txt': 'Entitlement to service connection for post-traumatic stress \ndisorder.'},
#  {'txt': 'To the extent that the veteran believes that he meets the \nrequirements for service connection disability for PTSD, the '},
#  {'txt': 'He had no focal tenderness nor limitation in the \nvicinity of the talus navicular or the articulation involving \nthose bones about the medial aspect of either foot.'},
#  {'txt': 'Entitlement to service connection for bilateral navicular \ntarsal stress fracture is denied.'},
#  {'txt': 'DOCKET NO.  04-27 112'},
#  {'txt': 'In light of the favorable decision \nas it relates to the issue of entitlement to service \nconnection for bilateral ingrown toenail disability, no \ndiscussion of VCAA compliance is necessary as there has been \nno detriment to the veteran as a result of any failure to \nmeet VCAA notice and assistance requirements.'},
#  {'txt': 'The \nveteran has not made the RO or the Board aware of any \nadditional evidence that needs to be obtained in order to \nfairly decide the appeal.'},
#  {'txt': 'See \nGonzales v. West, 218 F.3d 1378, 1380-81 (Fed. Cir. 2000) and '},
#  {'txt': 'Espiritu v. \nDerwinski, 2 Vet. App. 492 (1992).'},
#  {'txt': 'When the preponderance of evidence is \nagainst a claim, it must be denied.'},
#  {'txt': 'Where the determinative issue involves \nmedical causation or a medical diagnosis, competent medical \nevidence is required.'},
#  {'txt': 'The service medical records are entirely negative \nfor psychiatric treatment, and are negative for a diagnosis \nof a psychiatric disorder.'},
#  {'txt': 'A claim which is \nthe subject of a prior final decision may be reopened if new \nand material evidence is presented or secured.'},
#  {'txt': 'The veteran'},
#  {'txt': 'Board notes that as a layman, he has no competence to give a \nmedical opinion on the diagnosis of a condition.'},
#  {'txt': 'He \ndenied drinking and using drugs.'},
#  {'txt': 'The only other pertinent post service medical evidence is a \nJuly 2003 VA examination report in which the examiner stated \nthat the veteran had mild bilateral ingrown toenails of the \nhallux, with no current infection.'},
#  {'txt': 'Court of Appeals for Veterans Claims.'},
#  {'txt': 'REASONS AND BASES FOR FINDINGS AND CONCLUSION'},
#  {'txt': '1.'},
#  {'txt': 'Further, \nin his contemporaneous medical history, the veteran expressly \ndenied having any foot trouble.'},
#  {'txt': 'REASONS AND BASES FOR FINDINGS AND CONCLUSIONS'},
#  {'txt': 'On appeal from the\nDepartment of Veterans Affairs Regional Office in Muskogee, \nOklahoma'},
#  {'txt': "At a November 2002 VA psychiatric examination, the examiner \nnoted that she had reviewed the veteran's claims file and \nservice medical records."},
#  {'txt': 'Board has an obligation to provide adequate reasons and bases \nsupporting this decision, there is no requirement that the \nevidence submitted by the appellant or obtained on his behalf \nbe discussed in detail.'},
#  {'txt': "The June 2003 VA examination, coupled \nwith the veteran's November 2005 Board hearing testimony, \nraises a reasonable possibility of substantiating this claim, \nand the Board finds that the evidence is new and material \nunder 38 C.F.R. Â§ 3.156."},
#  {'txt': 'Service connection may also be \ngranted for any disease diagnosed after discharge, when all \nthe evidence, including that pertinent to service, \nestablishes that the disease was incurred in service.'},
#  {'txt': 'If there is no \nshowing of a resulting chronic condition during service, then \na showing of continuity of symptomatology after service is \nrequired to support a finding of chronicity.'},
#  {'txt': 'By a January \n2003 written statement and in subsequent testimony, he said \nthat during the attack, he was very drunk, and the \nperpetrator punched him in the mouth, and a tooth was \nloosened, cracked, or broken as a result.'},
#  {'txt': 'Citation Nr: 0600090'},
#  {'txt': "Disorders, Fourth Edition (DSM-IV)]; a link, established by \nmedical evidence, between the veteran's current symptoms and \nan \nin-service stressor; and credible supporting evidence that \nthe claimed in-service stressor occurred."},
#  {'txt': 'The Axis I diagnosis \nwas alcoholism.'},
#  {'txt': 'U.S.C.A. Â§ 1131; 38 C.F.R. Â§ 3.303.'},
#  {'txt': "Veterans Law Judge, Board of Veterans' Appeals\n\n\n\n\n Department of Veterans Affairs"},
#  {'txt': 'Center in Wichita, Kansas'},
#  {'txt': "He followed up this request with a telephone \nrequest, and the undersigned Veterans Law Judge granted the \nveteran's request to reschedule the hearing."},
#  {'txt': "In short, the June 2003 VA \nphysician's opinion is supported by the medical history and \nwas given following an examination of the veteran, and the "},
#  {'txt': 'Service connection for PTSD requires medical evidence \ndiagnosing the condition \nin accordance with 38 C.F.R. Â§ 4.125(a) [i.e., under the \ncriteria of Diagnostic and Statistical Manual of Mental '},
#  {'txt': 'INTRODUCTION'},
#  {'txt': 'On appeal from the\nDepartment of Veterans Affairs (VA) Regional Office (RO) in \nTogus, Maine'},
#  {'txt': 'DSM-IV at 427-28.'},
#  {'txt': 'Furthermore, the VA examiner concluded, through objective \nfindings that the veteran is well-developed, well-nourished, \nhas adequate hygiene, is coherent and logical, has no \nlooseness of association or disorganized speech, has no \nevidence of delusions or hallucinations, has no phobias or \npanic attacks, and that his affect is broad, euthymic and \nappropriate.'},
#  {'txt': '38 U.S.C.A. Â§ 1110; 38 C.F.R. Â§ 3.303.'},
#  {'txt': 'Bilateral ingrown toenail disability was manifested during \nactive duty service.'},
#  {'txt': 'K. A. BANFIELD'},
#  {'txt': 'An unappealed October 1983 rating decision denied \nentitlement to service connection for bilateral navicular \ntarsal stress fracture.'},
#  {'txt': 'The veteran may apply to reopen his \nclaim in the future, by submitting independent evidence to \ncorroborate a service stressor, or by submitting sufficiently \ndetailed information as would permit the VA to attempt \nstressor verification through the service department.'},
#  {'txt': 'A diagnosis of PTSD must meet all diagnostic criteria \nas stated in the Diagnostic and Statistical Manual of Mental \nDisorders (DSM-IV), published by the American Psychiatric'},
#  {'txt': 'Moreover, in his report, \nthe VA examiner noted that there is no evidence of in-service \nor post-service psychiatric treatment or hospitalization.'},
#  {'txt': 'This remand is in the \nnature of a preliminary order and does not constitute a \ndecision of the Board on the merits of your appeal.'},
#  {'txt': '38'},
#  {'txt': "A review of the veteran's service medical records reflects \nthat in early January 1970, the veteran was brought to the \nemergency room at DeWitt Army Hospital at Fort Belvoir by \nmilitary police, who reported that the veteran was \nthreatening to kill somebody, and did not want to be around \nthe people in his barracks because he did not like them."},
#  {'txt': 'The appeal is \ngranted.'},
#  {'txt': "In this regard, the \nveteran's service and VA medical records are associated with \nthe claims file, as well as a VA examination that addressed \nthe veteran's contentions concerning this appeal."},
#  {'txt': 'Archive Date: 01/19/06'},
#  {'txt': "She summarized the veteran's description of the \nalleged in-service assault."},
#  {'txt': 'Archive Date: 01/19/06'},
#  {'txt': 's possession that pertains to the claim.'},
#  {'txt': 'Appeals (Board) on appeal from a rating decision of the '},
#  {'txt': 'Quartuccio v. Principi, 16 Vet. App. 183 (2002).'},
#  {'txt': "This case comes to the Board of Veterans' Appeals (Board) on \nappeal from a March 2004 decision by the RO in Togus, Maine \nthat denied service connection for PTSD."},
#  {'txt': 'K. A. BANFIELD'},
#  {'txt': "This matter comes before the Board of Veterans' Appeals \n(Board) on appeal from a September 2003 rating decision by a "},
#  {'txt': 'Regional Office (RO) of the Department of Veterans Affairs \n(VA).'},
#  {'txt': 'Hayes v. Brown, 5 Vet. App. 60 at 69 (1993).'},
#  {'txt': 'J. N. Moats, Associate Counsel'},
#  {'txt': 'The examiner prescribed Valium.'},
#  {'txt': "VA's duty to notify was satisfied in several letters sent to \nthe veteran in February 2003, which collectively contained \nall four elements required by Pelegrini II."},
#  {'txt': "The Board will first address VA's notice and duty to assist \nrequirements."},
#  {'txt': "Veterans Law Judge, Board of Veterans' Appeals\n\n\n\n\n Department of Veterans Affairs"},
#  {'txt': "The veteran's service medical \nrecords show treatment for ingrown toenails while in service."},
#  {'txt': 'The veteran asserts through undated, written statements, \nwhich account for his military experiences  in October 1954, \nand through a written statement filed in October 2004 that he \nsuffers from PTSD due to a series of disciplinary actions \nagainst him while stationed in Fort Clayton, Panama, and his \ncombat experiences in the Korean Conflict.'},
#  {'txt': "This case comes to the Board of Veteran's Appeals (Board) \nfrom a March 2004 rating decision."},
#  {'txt': "The Board has reviewed all the evidence in the appellant's \nclaims file, which includes:  his contentions, including \nthose raised at June 2004 and October 2005 VA hearings; \nservice medical and personnel records; VA medical records; \nmedical records from a Vet Center; a private psychological \nevaluation; information from Fort Belvoir; and information \nfrom the National Personnel Records Center."},
#  {'txt': 'W.T. SNYDER, Associate Counsel'},
#  {'txt': "DSM-IV requires that a person's response to the \nstressor involve intense fear, helplessness, or horror."},
#  {'txt': 'Essentially, "service \nconnection" is proven by evidence establishing that a \nparticular injury or disease resulting in disability was \nincurred coincident with active duty military service, or if \npreexisting such service, was aggravated therein.'},
#  {'txt': 'The veteran has been provided with every \nopportunity to submit evidence and argument in support of \nthis claim, and to respond to VA notices.'},
#  {'txt': 'However, in his \ncontemporaneous medical history, the veteran stated that he \nhad foot trouble, including ingrown toenails.'},
#  {'txt': 'DATE'},
#  {'txt': 'Appellant'},
#  {'txt': 'The assessment was right tarsal navicular \nstress fracture with delayed healing.'},
#  {'txt': "The veteran's claim of service connection for bilateral \nnavicular tarsal stress fracture was originally denied by an \nunappealed October 1983 rating decision."},
#  {'txt': 'This case has been advanced on the \ndocket.'},
#  {'txt': "On separation medical examination in \nJanuary 1972, the veteran's psychiatric system was listed as \nnormal."},
#  {'txt': 'On appeal from the\nDepartment of Veterans Affairs Regional Office in Houston, \nTexas'},
#  {'txt': 'The fee-based physician diagnosed the veteran as having PTSD \nafter only one visit with him.'},
#  {'txt': 'ORDER'},
#  {'txt': 'At a June 2003 VA examination of the feet, the veteran \ncomplained of circumferential ankle joint pain primarily \nabout the anterior margin and about the vicinity of the \nfibular collateral ligaments of both ankles.'},
#  {'txt': "Specifically, the information and evidence that \nhave been associated with the claims file includes the \nveteran's service medical records, service personnel records, \nand post-service medical records and examination reports."},
#  {'txt': 'FINDING OF FACT'},
#  {'txt': "This matter initially came before the Board of Veterans'"},
#  {'txt': "The law \nrequires that all claims that are remanded by the Board of \nVeterans' Appeals or by the United States Court of Appeals \nfor Veterans Claims for additional development or other \nappropriate action must be handled in an expeditious manner."},
#  {'txt': 'The medical evidence reflects a difference of opinion as to \nwhether the veteran currently has PTSD.'},
#  {'txt': 'Appellant represented by:\tBlinded Veterans Association'},
#  {'txt': 'On appeal from the\nDepartment of Veterans Affairs (VA) Regional Office (RO) in \nSan Juan, the Commonwealth of Puerto Rico'},
#  {'txt': 'Â§ 3.159(b).'},
#  {'txt': 'FINDING OF FACT'},
#  {'txt': "Evidence received since the October 1983 rating decision \nis new and material, and the veteran's claim of service \nconnection for bilateral navicular tarsal stress fracture is \nreopened."},
#  {'txt': 'Findings reported on a March 1983 Physical Evaluation Board \n(PEB) indicate that the veteran had sharp right foot pain \nbeginning in October 1982.'},
#  {'txt': 'A follow-up \nbone scan showed more intense focal activity in the right \ntarsal navicular than on the previous scan.'},
#  {'txt': 'He \nstated that he began to drink heavily after this incident.'},
#  {'txt': 'David S. Nelson, Counsel'},
#  {'txt': 'A disability related to bilateral navicular tarsal stress \nfracture was not incurred in or aggravated by active service.'},
#  {'txt': 'Travel Board hearing was scheduled for October 24, 2005.'},
#  {'txt': "Veterans Law Judge, Board of Veterans' Appeals\n\nUnder 38 U.S.C.A. Â§ 7252 (West 2002), only a decision of the "},
#  {'txt': "Appellant represented by:\tMaine Veterans' Services"},
#  {'txt': 'Archive Date: 01/19/06'},
#  {'txt': "In its \ndecision, the Board may favor one expert's opinion over \nanother as long as an adequate statement of reasons and basis \nis given."},
#  {'txt': '38 C.F.R. Â§ 3.156(a).'},
#  {'txt': 'REPRESENTATION'},
#  {'txt': '38 C.F.R. Â§ 3.304(f); Pentecost v. \nPrincipi, 16 Vet. App. 124 (2002); Fossie v. West, 12 Vet.'},
#  {'txt': 'There was no mention of ingrown toenails.'},
#  {'txt': 'Therefore, the Board finds that \nall relevant evidence necessary for an equitable disposition \nof the appeal has been obtained.'},
#  {'txt': "The report cited specific \nknowledge of veteran's medical, mental, military, and \nrelevant personal history."},
#  {'txt': 'Citation Nr: 0600134'},
#  {'txt': 'The RO decisions issued in connection \nwith the appeal have notified the veteran of the evidence \nconsidered as well as the pertinent laws and regulations.'},
#  {'txt': 'In \nearly October 2005, the RO received a letter from the veteran \nwhich requested a rescheduling of the hearing due to his \nscheduled surgery in late October 2005 and other medical \nappointments.'},
#  {'txt': 'He took no medication nor wore \nany orthopedic devices.'},
#  {'txt': 'ORDER'},
#  {'txt': 'Veterans Affairs (VA).'},
#  {'txt': '2.'},
#  {'txt': 'This treatment note does \nnot identify any trauma.'},
#  {'txt': 'As the veteran has waived RO review \nof this evidence, the Board will consider it.'},
#  {'txt': 'II.'},
#  {'txt': 'Decision Date: 01/05/06'},
#  {'txt': 'Citation Nr: 0600177'},
#  {'txt': '38 C.F.R. Â§ 3.303(a).'},
#  {'txt': 'The veteran had been diagnosed with a tarsal \nnavicular stress fracture of the left foot and had been \nplaced in a short-leg cast on the left foot two to three \nweeks prior.'},
#  {'txt': "The primary cause of this patient 's \nongoing complaints would appear to be \nrelated to recurrent inversion episodes \nof the ankles (sprains) with residual \npathology attributable to those sprains \nand associated with what may be \ncontributory tibial varum without \ncorrelation to his prior history of \ntalonavicular pathology/stress fractures."},
#  {'txt': 'VA also has a duty to assist a claimant in obtaining evidence \nnecessary to substantiate a claim.'},
#  {'txt': 'Section 1154(b) allows combat veterans, in certain \ncircumstances, to use lay evidence to establish the \noccurrence of a disease or injury in service.'},
#  {'txt': '"give us everything you got pertaining to your claim."'},
#  {'txt': "The RO denied the veteran's claim because it considered the \nveteran's condition to be a congenital or developmental \ndefect."},
#  {'txt': 'See Soyini v. Derwinski, 1 Vet. App. 540, 546 (1991); Sabonis \nv. Brown, 6 Vet. App. 426, 430 (1994).'},
#  {'txt': 'A bone scan showed an increased uptake of \nradiopharmaceutical on the left and right.'},
#  {'txt': 'Any error \nin the sequence of events is not shown to have any effect on \nthe case or to cause injury to the claimant.'},
#  {'txt': 'He further stated that the veteran was not able to \nspecify and describe in detail a severe traumatic event \nexperienced in combat, and that the experiences the veteran \ndescribed were unpleasant, but not traumatic.'},
#  {'txt': '38 U.S.C.A. Â§Â§ 1110, 1154, 5107 (West 2002 & Supp. \n2005); 38 C.F.R. 3.303, 3.304 (2005).'},
#  {'txt': "Veterans Law Judge, Board of Veterans' Appeals\n\n\n\n\n Department of Veterans Affairs"},
#  {'txt': 'The (RO) issued a \nstatement of the case in June 2004, and the veteran perfected \nhis appeal in July 2004.'},
#  {'txt': "As to the existence of a stressor, a veteran's assertions of \nnon-combat service stressors are not sufficient to establish \ntheir occurrence."},
#  {'txt': 'The medical evidence reveals no disability related to \nresiduals of bilateral navicular tarsal stress fracture noted \nduring service.'},
#  {'txt': "Further, the \nprobative value of a medical opinion is generally based on \nthe scope of the examination, as well as the relative merits \nof the expert's qualifications and analytical assessments."},
#  {'txt': 'Thus, regardless of diagnosis, service connection for PTSD \nmay not be granted.'},
#  {'txt': 'However, even \nassuming that there is a valid diagnosis of PTSD under the \ncriteria of DSM-IV, service connection for PTSD also requires \ncredible evidence of an in-service stressor.'},
#  {'txt': 'CONCLUSION OF LAW'},
#  {'txt': "As the preponderance of the evidence is against the veteran's \nclaim, the benefit-of-the-doubt rule is not applicable, and \nthe claim must be denied."},
#  {'txt': '38 U.S.C.A. Â§ \n5103(a); 38 C.F.R. Â§ 3.159(b)(1); Quartuccio v. Principi, 16 '},
#  {'txt': 'See \nMayfield, supra; ATD Corp. v. Lydall, Inc., 159 F.3d 534, 549 \n(Fed. Cir. 1998).'},
#  {'txt': 'In support of his appeal, \nthe veteran has submitted copies of medical literature \nregarding the nature and causes of ingrown toenails.'},
#  {'txt': 'Â§ 20.1304(c) (2005).'},
#  {'txt': 'The weight of the credible evidence establishes that a \nstressor which might lead to PTSD did not occur in service.'},
#  {'txt': 'Guerrieri v. Brown, 4 Vet. App. 467 at 470-71 (1993).'},
#  {'txt': 'ATTORNEY FOR THE BOARD'},
#  {'txt': '38'},
#  {'txt': 'As the preponderance of the evidence is against the claim for \nservice connection for PTSD, the benefit-of-the-doubt rule \ndoes not apply, and the claim must be denied.'},
#  {'txt': 'Service incurrence for certain chronic diseases, \nsuch as arthritis, will be presumed if it becomes manifest to \na compensable degree within the year after service.'},
#  {'txt': 'Where chronicity of a disease is not shown in service, \nservice connection may yet be established by showing \ncontinuity of symptomatology between the currently claimed \ndisability and a condition noted in service, 38 C.F.R. Â§ \n3.303(b).'},
#  {'txt': 'Service connection may be granted for disability resulting \nfrom disease or injury incurred in or aggravated by active \nservice.'},
#  {'txt': 'In this case, in letters dated in September 2002, January \n2003, and October 2003, the RO provided notice to the veteran \nregarding what information and evidence is needed to \nsubstantiate the claim for service connection, as well as \nwhat information and evidence must be submitted by the \nveteran, what information and evidence will be obtained by \nVA, and the need for the veteran to advise VA of or submit \nany further evidence that pertains to the claim.'},
#  {'txt': 'Therefore, \nnotwithstanding Pelegrini v. Principi, 18 Vet. App. 112 \n(2004), to decide the appeal would not be prejudicial error \nto the claimant, as the Board finds that the notification \nrequirements of the VCAA have been satisfied.'},
#  {'txt': '"PTSD chronic severe."'},
#  {'txt': 'A veteran may also establish service connection if \nall of the evidence, including that pertaining to service, \nshows that a disease first diagnosed after service was \nincurred in service.'},
#  {'txt': 'DATE'},
#  {'txt': 'If there is \nno showing of a resulting chronic condition during service, \nthen a showing of continuity of symptomatology after service \nis required to support a finding of chronicity.'},
#  {'txt': "Evidence received subsequent to the October 1983 rating \ndecision raises a reasonable possibility of substantiating \nthe veteran's service connection for bilateral navicular \ntarsal stress fracture."},
#  {'txt': 'A bone scan \nrevealed an impression of increased activity diffusely to the \ntarsal regions compatible with either acute or chronic \ntrauma, and, diffuse periosteal reaction of the tibial \nshafts-possibly representing subperiosteal hemorrhages, \nhypertrophic pulmonary osteoarthropathy, etc.'},
#  {'txt': 'C.F.R. Â§ 3.159(c)(2).'},
#  {'txt': 'VA has a duty under the VCAA to notify a claimant and any \nrepresentative of the information and evidence needed to \nsubstantiate a claim.'},
#  {'txt': 'INTRODUCTION'},
#  {'txt': '38 U.S.C.A. Â§ 7105 (West 2002).'},
#  {'txt': 'ORDER'},
#  {'txt': 'When seeking VA service connection disability compensation, \nthe veteran must establish that a current disability results \nfrom disease or injury incurred while in or aggravated by \nservice, 38 U.S.C.A. Â§ 1110.'},
#  {'txt': 'See Espiritu v. Derwinksi, 2 Vet. '},
#  {'txt': 'There is no evidence which corroborates the occurrence of the \nstressor alleged by the veteran.'},
#  {'txt': 'The \nveteran was medically discharged shortly thereafter.'},
#  {'txt': "As such, the Board will review the \nveteran's claim on a de novo basis."},
#  {'txt': 'Id.'},
#  {'txt': 'C.F.R. Â§ 3.303(d).'},
#  {'txt': 'Section 1154(b) serves only to relax the \nevidentiary burden to establish occurrence of a disease or \ninjury in service.'},
#  {'txt': 'However, there is no medical evidence of record to \nsupport this conclusion.'},
#  {'txt': 'WITNESS AT HEARING ON APPEAL'},
#  {'txt': 'In November 2005 the veteran testified during a \nvideoconference hearing before the undersigned Veterans Law \nJudge; a transcript of that hearing is of record.'},
#  {'txt': 'DOCKET NO.  04-15 631'},
#  {'txt': 'VA has satisfied its duties to notify and assist, and \nadditional development efforts would serve no useful purpose.'},
#  {'txt': "The Board finds that the preponderance of the evidence is \nagainst the veteran's claim."},
#  {'txt': "Moreover, his report was \ngeneral and vague, and was not specific as to veteran's past \nand current mental state."},
#  {'txt': "While the service medical \nrecords indicate that the veteran had bilateral navicular \ntarsal stress fractures at the time of his discharge from \nservice, a VA physician (June 2003) has opined that the \nveteran's current complaints of pain in the feet are not \nrelated to the bilateral navicular tarsal stress fracture \nnoted during service."},
#  {'txt': 'That an injury occurred \nin service alone is not enough; there must be chronic \ndisability resulting from that injury.'},
#  {'txt': 'MICHAEL E. KILCOYNE'},
#  {'txt': 'As will be discussed below, the VCAA provisions have been \nconsidered and complied with.'},
#  {'txt': "The Board notes that the June 2003 VA physician rendered his \nopinion only after reviewing the veteran's claims file, \nexamining the veteran, and referencing clinical findings from \nthe veteran's medical history."},
#  {'txt': '38 U.S.C.A. Â§Â§ 1110, 5107 \n(West 2002); 38 C.F.R. Â§ 3.303 (2005).'},
#  {'txt': '3.'},
#  {'txt': 'Other than seeing a psychiatrist in \nservice two or three times, the veteran said he had never \nreceived any outpatient or inpatient care for mental health \nreasons.'},
#  {'txt': 'The appeal is REMANDED to the RO via the Appeals Management \nCenter (AMC) in Washington, DC.'},
#  {'txt': 'Service connection will be granted if it is shown that the \nveteran suffers from disability resulting from an injury \nsuffered or disease contracted in line of duty, or for \naggravation of a preexisting injury suffered or disease \ncontracted in line of duty, in active military service.'},
#  {'txt': 'At the September 2005 Board hearing, the veteran remarked \nthat his "shins" continued to bother him after service.'},
#  {'txt': 'She said that the veteran did not \ndisplay symptoms of a mental disorder other than substance \nabuse, and this was unlikely to be due to the single event in \nservice.'},
#  {'txt': 'He reported a \nsignificant alcohol history, and said he began to drink very \nheavily after separation from service.'},
#  {'txt': 'In \naddition, a letter sent in November 2002 and September 2004 \nnoted the substance of the VCAA, including the type of \nevidence necessary to establish entitlement to the benefits \nsought and whether the veteran or VA bore the burden of \nproducing or obtaining that evidence or information.'},
#  {'txt': 'C. L. Wasser, Counsel'},
#  {'txt': '38 C.F.R. Â§ \n3.304(f).'},
#  {'txt': 'The report noted that the veteran would be seen in the mental \nhygiene clinic in the morning.'},
#  {'txt': 'New evidence means \nexisting evidence not previously submitted to agency decision \nmakers.'},
#  {'txt': 'Owens v. Brown, 7 Vet. App. 429 at 434 (1995).'},
#  {'txt': 'The veteran filed his initial claim for ingrown toenail \ndisability as soon as he was discharged from active service \nin April 2002.'},
#  {'txt': 'The veteran served on active duty from August 1982 to April \n1983.'},
#  {'txt': 'V. L. Jordan'},
#  {'txt': 'The veteran had active duty service from April 1998 to April \n2002.'},
#  {'txt': 'The veteran had active service from February 1968 to November \n1969.'},
#  {'txt': 'Decision Date: 01/04/06'},
#  {'txt': 'Katherine King-Walker'},
#  {'txt': 'A notice of disagreement was received in October 2003, \na statement of the case was issued in May 2004, and a \nsubstantive appeal was received in July 2004.'},
#  {'txt': 'Citation Nr: 0600163'},
#  {'txt': 'The veteran stated \nthat pain from his feet prevented him from obtaining certain \nemployment.'},
#  {'txt': 'Pelegrini v. \nPrincipi, 18 Vet. App. 112, 120-21 (2004) (Pelegrini II).'},
#  {'txt': 'There is no indication that \nthere is additional evidence to obtain, there is no \nadditional notice that should be provided, and there has been \na complete review of all the evidence without prejudice to \nthe appellant.'},
#  {'txt': 'Archive Date: 01/19/06'},
#  {'txt': 'The veteran \ninitially requested a Board hearing, but this request was \nsubsequently withdrawn in August 2004.'},
#  {'txt': 'In a September 2004 letter, which was received be the RO in \nOctober 2004, the veteran requested a postponement of his \nthen-as-yet unscheduled hearing.'},
#  {'txt': 'Accordingly, the preponderance of the evidence is against \nfinding that the veteran currently has PTSD that is related \nto active duty.'},
#  {'txt': 'THE ISSUE'},
#  {'txt': 'Entitlement to service connection for post-traumatic stress \ndisorder (PTSD).'},
#  {'txt': 'New and material evidence can be neither \ncumulative nor redundant of the evidence of record at the \ntime of the last prior final denial of the claim sought to be \nreopened, and must raise a reasonable possibility of \nsubstantiating the claim.'},
#  {'txt': "Rather, the Board's analysis below \nwill focus specifically on what evidence is needed to \nsubstantiate the claim and what the evidence in the claims \nfile shows, or fails to show, with respect to the claim."},
#  {'txt': 'At a September 1983 VA examination the veteran complained of \ndiscomfort in both ankles.'},
#  {'txt': 'That an \ninjury occurred in service alone is not enough; there must be \nchronic disability resulting from that injury.'},
#  {'txt': 'On November 9, 2000, the President signed into law the VCAA, \nwhich has been codified at 38 U.S.C.A. Â§Â§ 5100, 5102, 5103, \n5103A, 5106, 5107, 5126.'},
#  {'txt': "Proper notice must be provided to a claimant before the \ninitial unfavorable agency or original jurisdiction (AOJ) \ndecision on a claim for VA benefits and must: (1) inform the \nclaimant about the information and evidence not of record \nthat is necessary to substantiate the claim; (2) inform the \nclaimant about the information and evidence that VA will seek \nto provide; (3) inform the claimant about the information and \nevidence the claimant is expected to provide; and (4) request \nor tell the claimant to provide any evidence in the claimant'"},
#  {'txt': 'The record also reflects that VA has made reasonable efforts \nto obtain relevant records adequately identified by the \nveteran.'},
#  {'txt': '2.'},
#  {'txt': 'The examiner indicated that the veteran did \nnot display the signs and symptoms of someone suffering from \nPTSD because his sleep was not impaired, he had very little \nproblems with panic, and he denied flashbacks, nightmares or \nintrusive thoughts.'},
#  {'txt': "Accordingly, factors to consider when comparing and analyzing \nexpert medical opinions include, but are not limited to: 1) \nthe basis for the physician's opinion, 2) the physician's \nknowledge of the veteran's accurate medical and personal \nrelevant history, 3) the length of time the physician has \ntreated the veteran, 4) the physician's experience and \nexpertise, and 5) degree of specificity and of certainty of \nthe physician's opinion."},
#  {'txt': "Thereafter, the \nRO adjudicated the veteran's claim in a March 2004 rating \ndecision."},
#  {'txt': 'The veteran mentioned that he did not seek care for his \nankles prior to the late 1990s because he did not know he \ncould receive such treatment from VA.'},
#  {'txt': 'Whether new and material evidence has been submitted to \nreopen a claim of entitlement to service connection for \nbilateral navicular tarsal stress fracture.'},
#  {'txt': 'PTSD was not incurred in or aggravated by active service.'},
#  {'txt': 'INTRODUCTION'},
#  {'txt': '"However, the \nprovisions of Â§ 1154(b) do not provide a substitute for \nmedical-nexus evidence..."'},
#  {'txt': '38 U.S.C.A. Â§ 1110; 38 C.F.R. Â§Â§ \n3.303, 3.304(f).'},
#  {'txt': 'ALAN S. PEEVY'},
#  {'txt': "Furthermore, it is unclear whether \nveteran's claims file, medical records or mental history were \nreviewed during his assessment."},
#  {'txt': 'The veterans DD-214 and service medical records confirm that \nhe served on active duty from November 1950 to December 1954, \nthat he received the National Defense Service Medal and the '},
#  {'txt': 'C.F.R. Â§Â§ 3.307, 3.309.'},
#  {'txt': 'Era from April 1951 to February 1952.'},
#  {'txt': "For example, the VA examiner \nstates that the veteran's claims file, service medical \nrecords, and the fee-based physician's report were reviewed."},
#  {'txt': "Further, there is a current diagnosis of bilateral ingrown \ntoenails; and based on continuing symptomatology, a link \nbetween the veteran's current disability and service."},
#  {'txt': 'Association.'},
#  {'txt': 'He further elaborates about \nhis disciplinary experience in Fort Clayton as very \ndisturbing, and that he dreams about the incident and cannot \nput it out of his mind.'},
#  {'txt': 'July 2001 service medical \nrecords showed that an ingrown toenail was still bothering \nthe veteran.'},
#  {'txt': 'The veteran served on active duty from October 1969 to May \n1972.'},
#  {'txt': 'VA will notify you if \nfurther action is required on your part.'},
#  {'txt': 'See 38 U.S.C.A. Â§Â§ 5102, 5103, 5103A, 5107; 38 \nC.F.R. Â§Â§ 3.102, 3.156(a), 3.159, 3.326(a).'},
#  {'txt': 'App. 1 (1998); Cohen v. Brown, 10 Vet. App. 128 (1997); Doran \nv. Brown, 6 Vet. App. 283 (1994).'},
#  {'txt': 'The veteran was \nreplaced in a short-leg walking cast of the right foot for a \ncouple of weeks.'},
#  {'txt': 'An April 2005 AMC letter \ninformed the veteran that his remanded appeal was being \ntransferred to the RO so that a hearing could be scheduled.'},
#  {'txt': 'It was further noted \nthat a tarsal navicular stress fracture required 3-6 months \nof rehabilitation before returning to full activity.'},
#  {'txt': 'Under the circumstances in this case, the veteran has \nreceived the notice and assistance contemplated by law and \nadjudication of the claim poses no risk of prejudice to the \nveteran.'},
#  {'txt': 'A September 2005 RO letter informed the veteran that his '},
#  {'txt': 'He asserts that the incident involved both sexual and \nphysical assault, and that he does not know the name of the \nperpetrator, who was a cook at Fort Belvoir.'},
#  {'txt': 'The veteran contends that he has PTSD due to a personal \nassault which occurred approximately between January and '},
#  {'txt': "The veteran's February 1998 entrance examination showed \nabnormal feet, but this was noted to be because of mild pes \nplanus."},
#  {'txt': 'Entitlement to service connection for post-traumatic stress \ndisorder (PTSD).'},
#  {'txt': 'CONCLUSION OF LAW'},
#  {'txt': "See Mayfield, supra; Smith v. Gober, 14 Vet. App. \n227 (2000), aff'd 281 F.3d 1384 (Fed. Cir. 2002); Dela Cruz \nv. Principi, 15 Vet. App. 143 (2001) (VCAA does not require \nremand where VA thoroughly discussed factual determinations \nleading to conclusion and evidence of record provides \nplausible basis for factual conclusions, and where \ndevelopment of the evidence was as complete as was necessary \nfor a fair adjudication of the claims)."},
#  {'txt': 'VA treatment records dated from July 1998 to September 2002 \nreflect that the veteran sustained an open left tibia-fibula \nfracture following an October 1999 motorcycle accident.'},
#  {'txt': "Informing the \nappellant about the information and evidence not of record \nthat is necessary to substantiate the claim; (2) informing \nthe appellant about the information and evidence the VA will \nseek to provide; (3) informing the appellant about the \ninformation and evidence the claimant was expected to \nprovide; and (4) informing the appellant to provide any \nevidence in the appellant's possession that pertains to the \nclaim, or something to the effect that the claimant should "},
#  {'txt': '38 U.S.C.A. Â§Â§ 1101, 1110, 1131, 5107 (West 2002); 38 C.F.R. '},
#  {'txt': 'Claim for service connection for PTSD'},
#  {'txt': 'The veteran is claiming service connection for his bilateral \ningrown toenail disability.'},
#  {'txt': 'Decision Date: 01/05/06'},
#  {'txt': "In February 2003, a counseling \ntherapist noted that the veteran's developmental history \nincluded no information which would provide an alternative \ndiagnosis or an etiology other than the military sexual \ntrauma he reportedly experienced in service."},
#  {'txt': '38 U.S.C.A.'},
#  {'txt': 'The Veterans Claims Assistance Act of 2000 (VCAA) provides \nthat VA will make reasonable efforts to notify a claimant of \nthe relevant evidence necessary to substantiate a claim for \nbenefits under laws administered by the VA.'},
#  {'txt': 'REPRESENTATION'},
#  {'txt': 'REASONS AND BASES FOR FINDING AND CONCLUSION'},
#  {'txt': 'Conflict, as well as his experience in Panama are causes of \nhis PTSD.'},
#  {'txt': 'ATTORNEY FOR THE BOARD'},
#  {'txt': 'INTRODUCTION'},
#  {'txt': 'The October 1983 rating decision denying service \nconnection for bilateral navicular tarsal stress fracture is \nfinal.'},
#  {'txt': '1.'},
#  {'txt': '38 C.F.R. Â§ \n3.304(f).'},
#  {'txt': 'DATE'},
#  {'txt': "App. 492, 494-495 (1992) (laypersons may be competent to \nprovide an eyewitness account of a veteran's visible \nsymptoms, but they are not capable of offering opinions as to \nmedical matters)."},
#  {'txt': 'Decision Date: 01/04/06'},
#  {'txt': 'A \nvideoconference hearing was held before the undersigned '},
#  {'txt': 'The veteran asserted that he had \nbecome an alcoholic because of this event.'},
#  {'txt': 'The veteran and his representative were also provided with a \ncopy of the appealed rating decision, as well as an August \n2004 Statement of the Case (SOC).'},
#  {'txt': 'Service medical \nrecords are negative for any mental health complaints or \ndiagnoses.'},
#  {'txt': 'The Board notes that there has been a regulatory \nchange with respect to the definition of new and material \nevidence, which applies prospectively to all claims made on \nor after August 29, 2001.'},
#  {'txt': 'Grottveit v. Brown, 5 Vet. App. 91, 93 \n(1993).'},
#  {'txt': '38 C.F.R. Â§ \n3.303(b).'},
#  {'txt': 'In contrast,  a VA mental health examiner concluded in a '},
#  {'txt': 'THE ISSUE'},
#  {'txt': "If a PTSD claim is \nbased on in-service personal assault, evidence from sources \nother than the veteran's service records may corroborate the \nveteran's account of the stressor incident."},
#  {'txt': 'Veterans Law Judge in October 2005.'},
#  {'txt': 'The VCAA also \nrequires the VA to assist a claimant in obtaining that \nevidence.'},
#  {'txt': 'THE ISSUE'},
#  {'txt': 'In addition, after interviewing the veteran, \nthe VA examiner concluded that although the veteran reports \nan occasional disturbance in his night sleep, he does not \nreport nightmares, intrusive recurrent thoughts, nor avoidant \nbehavior related to extreme traumatic experiences in the \nmilitary.'},
#  {'txt': "An October 2002 rating decision \ndenied the veteran's claim, and he perfected an appeal."},
#  {'txt': 'The veteran\'s \nrecords show that he received promotions to E-3 in June 1970, \nand to E-4 in September 1970, and that he received a letter \nof appreciation in December 1971 for his "outstanding and \nconscientious ability to be a soldier...."'},
#  {'txt': "The Board has considered the veteran's statements (and his \nbrother's January 2004 statement) and hearing testimony \nrelating to his belief that his current disorders of the feet \nare related to his problems during service."},
#  {'txt': 'The veteran asked for a local hearing in a July 2004 letter, \nbut withdrew this request in an October 2004 written \nstatement.'},
#  {'txt': 'Archive Date: 01/19/06'},
#  {'txt': 'Muskogee, Oklahoma, Regional Office (RO) of the Department of '},
#  {'txt': "The Board is unable to find \nthat the veteran's alleged service stressor has been verified \nby official service records or other credible supporting \nevidence."},
#  {'txt': '"Satisfactory evidence" is \ncredible evidence, and such evidence may be rebutted only \nwith clear and convincing evidence to the contrary.'},
#  {'txt': 'The examiner did not \noffer an opinion about whether the disorder was congenital or \ndevelopmental.'},
#  {'txt': 'CONCLUSIONS OF LAW'},
#  {'txt': 'DATE'},
#  {'txt': 'When weighing medical evidence, the Board must consider \nprofessional opinions.'},
#  {'txt': "The VA examiner's report was very detailed and well written \nto include, citations of specific knowledge of veteran's \nmedical, mental and relevant personal history, specific \nnotations of veterans relevant active duty military history, \nreview of veteran's claims file, and specific notations of \nevery aspect of the actual assessment."},
#  {'txt': 'In a series of undated, written letters (translated in \nJanuary 2005), the veteran writes about his military \nexperiences during October 1954.'},
#  {'txt': 'As such, there is no indication that there is \nany prejudice to the appellant by the order of the events in \nthis case.'},
#  {'txt': 'Service personnel records do not include any reports from the \nmilitary police about the alleged incident.'},
#  {'txt': 'THE ISSUE'},
#  {'txt': 'Consequently, lay \nassertions of medical diagnosis cannot constitute evidence \nupon which to grant a claim for service connection.'},
#  {'txt': '38 C.F.R. Â§ 3.303(d).'},
#  {'txt': 'See Mayfield v. Nicholson, 19 Vet. App. 103 \n(2005); Bernard v. Brown, 4 Vet. App. 384 (1993).'},
#  {'txt': 'Citation Nr: 0600091'},
#  {'txt': 'REPRESENTATION'},
#  {'txt': 'The \nassessment portion of the examination was as follows:'}]

# %%
# %time custom_spans_add_spacy_tokens(spans)
# Out:
# CPU times: total: 2.05 s
# Wall time: 2.05 s

# %%
for unlabeled_file in unlabeled_corpus:
    # Read the file
    text = open(UNLABELED_DATA_PATH/unlabeled_file, 'r').read().encode('latin-1', 'ignore')
    text = text.decode('latin-1')
    
    # Sentencize with LUIMA
    doc = luima.text2sentences(DOC, offsets=False)
    
    # Create a text span with the sentences
    spans = []
    text_span = []

# %%
token_save_file = 'tokenized_sentences_unlabeled.txt'
file = open(token_save_file, 'w')
random.seed(42)
random.shuffle(spans)
for i, span in enumerate(spans):
    for pos, token in enumerate(span['tokens_spacy']):
        if pos == 0:
            file.write(token)
        else:
            file.write(" " + token)
        
    file.write("\n")
#     print(f"{i+1}. {span['txt'].ljust(len(span['txt']))} | {span['tokens_spacy']}", end="\n\n")

# %% [raw]
# ##### Observations
# 1. Sometimes converting the date into number, sometimes not.
# "Decision Date: 03/08/06 | ['decision', 'Date']", "Archive Date: 06/16/06 | ['Archive', 'Date', '<NUM8>']"
#
# 2. Not removing the '\n' characters.
# BOARD OF VETERANS APPEALS
# DEPARTMENT OF VETERANS AFFAIRS
# WASHINGTON, DC  20420 | ['BOARD', 'of', 'VETERANS', 'APPEALS', '\n', 'DEPARTMENT', 'of', 'VETERANS', 'AFFAIRS', '\n', 'WASHINGTON', 'DC', ' ', '<NUM5>']
#
# 3. Capitalizations need to be handled and all should be made lower case.
#
# 4. Should we keep symbols like this? "§§"
#
# 5. "70. X-rays demonstrated
# minimal degenerative changes at the L5-S1. | ['X', '-', 'ray', 'demonstrate', '\n', 'minimal', 'degenerative', 'change', 'at', 'the', 'L5', 'S1']"
#
# Should the L5-S1 things be kept?
#
# 6. Should Roman numbers be simplified as well? e.g: 97. II. | ['II']
#
# 7. Numbering not consistent, e.g: 105. 38 C.F.R. § 3.303(d) (2005). | ['<NUM2>', 'C.F.R.', '§', '3.303(d', '<NUM4>']
#
# 8. Vet. App. should be a single token unlike the produced, e.g: 127. Gilbert, 1 Vet. App. at 54. | ['Gilbert', '<NUM1>', 'Vet', '.', 'App', 'at', '<NUM2>']
#
# 9. 133. James L. March | ['James', 'L.', 'March']
